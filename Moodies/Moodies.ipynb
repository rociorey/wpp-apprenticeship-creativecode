# %%
# import libraries needed
import pandas as pd
from stop_words import get_stop_words
from nltk.corpus import stopwords
import random
import nltk
import math

# %%
# setting the path to our file
path = 'netflixMoviesData.csv'
# convert our csv file to a pandas DataFrame
# converters allows pandas to know that abilities is a list, not a string
movieData = pd.read_csv(path)

# %%
movieData
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# 5834                Ole Bornedal
# 5835                         NaN
# 5836        Sorin Dan Mihalcescu
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5832  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5833  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5834  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5835                                                NaN
# 5836  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country         date_added  release_year rating  \
# 0                  South Korea  November 30, 2019          2019  TV-14
# 1                          NaN  November 30, 2019          2019   TV-G
# 2                        India  November 30, 2019          2019  TV-14
# 3     France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4       Canada, United Kingdom                NaN          2019   TV-Y
# ...                        ...                ...           ...    ...
# 5832             United States   November 1, 2010          1987     NR
# 5833             United States  November 18, 2009          2009  TV-14
# 5834                   Denmark        May 5, 2009          2007     NR
# 5835             United States   February 4, 2008          2007  TV-MA
# 5836             United States    January 1, 2008          2006     NR
#
#        duration                                          listed_in  \
# 0      1 Season  International TV Shows, Korean TV Shows, Roman...
# 1        67 min                Documentaries, International Movies
# 2       135 min             Comedies, Dramas, International Movies
# 3       106 min   Dramas, Independent Movies, International Movies
# 4     2 Seasons                                           Kids' TV
# ...         ...                                                ...
# 5832     84 min                         Cult Movies, Horror Movies
# 5833     29 min                                      Horror Movies
# 5834    104 min                       Dramas, International Movies
# 5835   1 Season                       Stand-Up Comedy & Talk Shows
# 5836     81 min              Dramas, Independent Movies, Thrillers
#
#                                             description     type
# 0     Brought together by meaningful meals in the pa...  TV Show
# 1     From Sierra de las Minas to Esquipulas, explor...    Movie
# 2     A goofy copywriter unwittingly convinces the I...    Movie
# 3     Arranged to marry a rich man, young Ada is cru...    Movie
# 4     Lovable pug Chip starts kindergarten, makes ne...  TV Show
# ...                                                 ...      ...
# 5832  This collection cherry-picks trailers, forgott...    Movie
# 5833  After committing suicide, a washed-up rocker r...    Movie
# 5834  When he causes a car accident that leaves a yo...    Movie
# 5835  In each episode, four celebrities join host Jo...  TV Show
# 5836  While covering a story in New York City, a Sea...    Movie
#
# [5837 rows x 12 columns]

# %%
#Creating variables for the movie's titles and descriptions

movieTitles = movieData.title
movieDescriptions = movieData.description

# %%
#Testing the description
movieDescriptions[10]
# Out:
# "After an expensive night out, two flatmates get tangled in an overnight misadventure to recover their rent money to pay their dead landlord's daughter."

# %%
#Working out how many unique titles there are in the dataset
len(movieTitles.unique())
# Out:
# 5780

# %%
# establishing a base line for our algorithm
humanAccuracy = 1/5780
#print(humanAccuracy)
roundedHumanAccuracy = round(humanAccuracy, 4)
strHumanAccuracy = str(roundedHumanAccuracy)
print(strHumanAccuracy)
# Out:
# 0.0002

# %%
#Function that creates the features through the movies' descriptions
def movies_features(movieDescript):
    # stopwords list is all lowercase so we need to match
    #print(type(movieDescript))
    descriptions = movieDescript.lower()
    words = descriptions.split()
    keywords = [x for x in words if x not in get_stop_words('english','spanish')]
    while len(keywords) < 3:
        keywords.append('None')
    return {'first_keyword': keywords[0], 'second_keyword': keywords[1], 'third_keyword': keywords[2]}
    

movies_features('After an expensive night out, two flatmates get tangled in an overnight misadventure to recover')
# Out:
# {'first_keyword': 'expensive',
#  'second_keyword': 'night',
#  'third_keyword': 'out,'}

# %%
#Creating tuples for the movie descriptions and titles
zipped_features = zip(movieDescriptions,movieTitles)

# %%
# Creating feature sets for each of the elements in my zipped variable
featuresets = [(movies_features(x), y) for x, y in zipped_features ]
featuresets
# Out:
# [({'first_keyword': 'brought',
#    'second_keyword': 'together',
#    'third_keyword': 'meaningful'},
#   'Chocolate'),
#  ({'first_keyword': 'sierra', 'second_keyword': 'de', 'third_keyword': 'las'},
#   'Guatemala: Heart of the Mayan World'),
#  ({'first_keyword': 'goofy',
#    'second_keyword': 'copywriter',
#    'third_keyword': 'unwittingly'},
#   'The Zoya Factor'),
#  ({'first_keyword': 'arranged',
#    'second_keyword': 'marry',
#    'third_keyword': 'rich'},
#   'Atlantics'),
#  ({'first_keyword': 'lovable',
#    'second_keyword': 'pug',
#    'third_keyword': 'chip'},
#   'Chip and Potato'),
#  ({'first_keyword': 'nollywood',
#    'second_keyword': 'star',
#    'third_keyword': 'ramsey'},
#   'Crazy people'),
#  ({'first_keyword': 'romance,',
#    'second_keyword': 'mystery',
#    'third_keyword': 'adventure'},
#   'I Lost My Body'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'times',
#    'third_keyword': 'iconic'},
#   'Kalushi: The Story of Solomon Mahlangu'),
#  ({'first_keyword': 'compelling',
#    'second_keyword': 'show',
#    'third_keyword': 'tells'},
#   'La Reina del Sur'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'mooching',
#    'third_keyword': 'friends'},
#   'Lagos Real Fake Life'),
#  ({'first_keyword': 'expensive',
#    'second_keyword': 'night',
#    'third_keyword': 'out,'},
#   'Payday'),
#  ({'first_keyword': 'everything',
#    'second_keyword': 'love',
#    'third_keyword': '"sugar'},
#   'Sugar Rush Christmas'),
#  ({'first_keyword': 'nursing',
#    'second_keyword': 'broken',
#    'third_keyword': 'heart,'},
#   'The Accidental Spy'),
#  ({'first_keyword': 'quirky',
#    'second_keyword': 'fashion',
#    'third_keyword': 'student'},
#   'The Charming Stepmom'),
#  ({'first_keyword': 'colonel',
#    'second_keyword': 'uncovers',
#    'third_keyword': 'controversial'},
#   'The Island'),
#  ({'first_keyword': 'blockbusters',
#    'second_keyword': 'brought',
#    'third_keyword': 'us'},
#   'The Movies That Made Us'),
#  ({'first_keyword': 'widowed',
#    'second_keyword': 'radio',
#    'third_keyword': 'dj'},
#   'Holiday Rush'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'levius',
#    'third_keyword': 'rises'},
#   'Levius'),
#  ({'first_keyword': 'four',
#    'second_keyword': 'comedians',
#    'third_keyword': 'brazil'},
#   'Lugar de Mulher'),
#  ({'first_keyword': 'struggling',
#    'second_keyword': 'la',
#    'third_keyword': 'musician'},
#   'Merry Happy Whatever'),
#  ({'first_keyword': 'burned',
#    'second_keyword': 'taken',
#    'third_keyword': 'granted,'},
#   'Mythomaniac'),
#  ({'first_keyword': 'ready-to-retire',
#    'second_keyword': 'safecracker',
#    'third_keyword': 'nick,'},
#   'The Score'),
#  ({'first_keyword': 'investigative',
#    'second_keyword': 'docuseries',
#    'third_keyword': 'shows'},
#   'Broken'),
#  ({'first_keyword': 'action-packed',
#    'second_keyword': 'drama',
#    'third_keyword': 'based'},
#   'Defiance'),
#  ({'first_keyword': 'caste',
#    'second_keyword': 'differences',
#    'third_keyword': 'throw'},
#   'Evvarikee Cheppoddu'),
#  ({'first_keyword': 'journey',
#    'second_keyword': 'back',
#    'third_keyword': 'time'},
#   'Little Singham: Mahabali'),
#  ({'first_keyword': 'traumatic',
#    'second_keyword': 'event,',
#    'third_keyword': 'two'},
#   'The Body Remembers When the World Broke Open'),
#  ({'first_keyword': 'hit', 'second_keyword': 'man', 'third_keyword': 'frank'},
#   'The Irishman'),
#  ({'first_keyword': 'comedian',
#    'second_keyword': 'mike',
#    'third_keyword': 'birbiglia'},
#   'Mike Birbiglia: The New One'),
#  ({'first_keyword': 'christmas',
#    'second_keyword': 'eve',
#    'third_keyword': 'pitchfork'},
#   'Super Monsters Save Christmas'),
#  ({'first_keyword': 'peaceful',
#    'second_keyword': 'lives',
#    'third_keyword': 'residents'},
#   'The Crime'),
#  ({'first_keyword': 'ice',
#    'second_keyword': 'crystal',
#    'third_keyword': 'frosty'},
#   'True: Winter Wishes'),
#  ({'first_keyword': 'assortment',
#    'second_keyword': 'talent',
#    'third_keyword': 'takes'},
#   'Zona Rosa'),
#  ({'first_keyword': 'businesswoman',
#    'second_keyword': 'debra',
#    'third_keyword': "newell's"},
#   'Dirty John'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'fulfill',
#    'third_keyword': 'father’s'},
#   'Pranaam'),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'extensive',
#    'third_keyword': 'interviews,'},
#   'What the F* Is Going On?'),
#  ({'first_keyword': 'accident',
#    'second_keyword': 'leaves',
#    'third_keyword': 'recollection'},
#   'Awake'),
#  ({'first_keyword': 'storm',
#    'second_keyword': 'wrecks',
#    'third_keyword': 'ship,'},
#   'Popeye'),
#  ({'first_keyword': 'trying',
#    'second_keyword': 'go',
#    'third_keyword': 'straight,'},
#   'Shot Caller'),
#  ({'first_keyword': 'born',
#    'second_keyword': 'supernatural',
#    'third_keyword': 'strength,'},
#   'Strong Girl Bong-soon'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'adventures',
#    'third_keyword': 'wilbur'},
#   "Charlotte's Web"),
#  ({'first_keyword': 'officers',
#    'second_keyword': 'taylor',
#    'third_keyword': 'zavala'},
#   'End of Watch'),
#  ({'first_keyword': 'vietnam',
#    'second_keyword': "war's",
#    'third_keyword': 'horrors'},
#   'Hamburger Hill'),
#  ({'first_keyword': 'nine',
#    'second_keyword': 'continents',
#    'third_keyword': 'face'},
#   'Once Upon A Time In Lingjian Mountain'),
#  ({'first_keyword': 'based',
#    'second_keyword': 'h.g.',
#    'third_keyword': 'wells'},
#   'The Time Machine'),
#  ({'first_keyword': 'thrust',
#    'second_keyword': 'violent',
#    'third_keyword': 'home'},
#   'Brother'),
#  ({'first_keyword': 'gets',
#    'second_keyword': 'angry,',
#    'third_keyword': 'middle'},
#   'Dino Girl Gauko'),
#  ({'first_keyword': 'eight',
#    'second_keyword': 'stories',
#    'third_keyword': 'celebrating'},
#   "Dolly Parton's Heartstrings"),
#  ({'first_keyword': 'girls',
#    'second_keyword': 'ōarai',
#    'third_keyword': 'high'},
#   'Girls und Panzer der Film'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'sisters',
#    'third_keyword': 'discover'},
#   'High Seas'),
#  ({'first_keyword': 'mike',
#    'second_keyword': 'birbiglia',
#    'third_keyword': 'performs'},
#   'Mike Birbiglia: What I Should Have Said Was Nothing: Tales from My Secret Public Journal'),
#  ({'first_keyword': '"nailed',
#    'second_keyword': 'it!"',
#    'third_keyword': 'holiday'},
#   'Nailed It! Holiday!'),
#  ({'first_keyword': 'ride',
#    'second_keyword': 'along',
#    'third_keyword': 'police'},
#   'Narcoworld: Dope Stories'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'guardian',
#    'third_keyword': '"angelus"'},
#   "Nobody's Looking"),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'interviews',
#    'third_keyword': 'vintage'},
#   'Shelby American'),
#  ({'first_keyword': 'peer',
#    'second_keyword': 'lives',
#    'third_keyword': 'young'},
#   'Singapore Social'),
#  ({'first_keyword': 'extraordinary',
#    'second_keyword': 'discovery',
#    'third_keyword': 'inspires'},
#   'The Dragon Prince'),
#  ({'first_keyword': 'queen',
#    'second_keyword': 'poppy',
#    'third_keyword': 'welcomes'},
#   'Trolls: The Beat Goes On!'),
#  ({'first_keyword': 'board',
#    'second_keyword': "russia's",
#    'third_keyword': 'first'},
#   'K-19: The Widowmaker'),
#  ({'first_keyword': 'making',
#    'second_keyword': 'deal',
#    'third_keyword': 'supernatural'},
#   'Mortel'),
#  ({'first_keyword': 'medieval',
#    'second_keyword': 'magic',
#    'third_keyword': 'sends'},
#   'The Knight Before Christmas'),
#  ({'first_keyword': 'lifelong',
#    'second_keyword': 'friends',
#    'third_keyword': 'roz'},
#   'Adore'),
#  ({'first_keyword': 'living',
#    'second_keyword': 'roof,',
#    'third_keyword': 'group'},
#   'Bangkok Buddies'),
#  ({'first_keyword': 'escape',
#    'second_keyword': 'stress',
#    'third_keyword': 'fame,'},
#   'Be Somebody'),
#  ({'first_keyword': 'realizing',
#    'second_keyword': 'boob',
#    'third_keyword': 'tube'},
#   'Beavis and Butt-head Do America'),
#  ({'first_keyword': "ladies'",
#    'second_keyword': 'man',
#    'third_keyword': 'robin'},
#   "Bebe's Kids"),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'charts',
#    'third_keyword': 'rise'},
#   'Bikram: Yogi, Guru, Predator'),
#  ({'first_keyword': 'lazarus',
#    'second_keyword': 'finds',
#    'third_keyword': 'rae'},
#   'Black Snake Moan'),
#  ({'first_keyword': 'lethal',
#    'second_keyword': 'virus',
#    'third_keyword': 'spreads'},
#   'Carriers'),
#  ({'first_keyword': 'village',
#    'second_keyword': "landlord's",
#    'third_keyword': 'daughter'},
#   'Dorasaani'),
#  ({'first_keyword': 'riveting',
#    'second_keyword': 'crime',
#    'third_keyword': 'doc'},
#   'Dream/Killer'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'community',
#    'third_keyword': 'college'},
#   'Evolution'),
#  ({'first_keyword': 'grieving',
#    'second_keyword': 'mother',
#    'third_keyword': 'karen'},
#   'Eye for an Eye'),
#  ({'first_keyword': 'christmas',
#    'second_keyword': 'reunion',
#    'third_keyword': 'becomes'},
#   'Holiday Secrets'),
#  ({'first_keyword': 'andy',
#    'second_keyword': 'samberg',
#    'third_keyword': 'stars'},
#   'Hot Rod'),
#  ({'first_keyword': 'olsen',
#    'second_keyword': 'twins',
#    'third_keyword': 'put'},
#   'It Takes Two'),
#  ({'first_keyword': 'lorena',
#    'second_keyword': 'ramírez',
#    'third_keyword': "mexico's"},
#   'Lorena, Light-Footed Woman'),
#  ({'first_keyword': 'years,', 'second_keyword': 'come', 'third_keyword': 'go'},
#   'Love, Rosie'),
#  ({'first_keyword': 'self-trained',
#    'second_keyword': 'engineer',
#    'third_keyword': 'risks'},
#   'Mallesham'),
#  ({'first_keyword': 'epic',
#    'second_keyword': 'spaghetti',
#    'third_keyword': 'western,'},
#   'Once Upon a Time in the West'),
#  ({'first_keyword': 'average-guy',
#    'second_keyword': 'kirk',
#    'third_keyword': 'starts'},
#   "She's Out of My League"),
#  ({'first_keyword': 'socially',
#    'second_keyword': 'awkward',
#    'third_keyword': 'catholic'},
#   'Superstar'),
#  ({'first_keyword': '3-d',
#    'second_keyword': 'motion',
#    'third_keyword': 'capture'},
#   'The Adventures of Tintin'),
#  ({'first_keyword': 'spooky',
#    'second_keyword': 'grisly,',
#    'third_keyword': 'thriller'},
#   'The Devil Inside'),
#  ({'first_keyword': 'following',
#    'second_keyword': "friend's",
#    'third_keyword': 'suicide'},
#   'The First Wives Club'),
#  ({'first_keyword': 'authorities',
#    'second_keyword': 'find',
#    'third_keyword': 'drowned'},
#   'The Gift'),
#  ({'first_keyword': 'hired',
#    'second_keyword': 'rescue',
#    'third_keyword': 'flagging'},
#   'The Goods: Live Hard, Sell Hard'),
#  ({'first_keyword': 'washed-up',
#    'second_keyword': 'professional',
#    'third_keyword': 'quarterback'},
#   'The Longest Yard'),
#  ({'first_keyword': 'raised',
#    'second_keyword': 'ashram',
#    'third_keyword': 'india,'},
#   'The Love Guru'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'attorney',
#    'third_keyword': 'scrappy'},
#   'The Rainmaker'),
#  ({'first_keyword': 'backwater',
#    'second_keyword': 'iowa',
#    'third_keyword': 'town,'},
#   "What's Eating Gilbert Grape"),
#  ({'first_keyword': '4-year-old',
#    'second_keyword': 'son',
#    'third_keyword': 'murdered,'},
#   'Who Killed Little Gregory?'),
#  ({'first_keyword': 'working',
#    'second_keyword': 'treacherous',
#    'third_keyword': 'conditions,'},
#   'World Trade Center'),
#  ({'first_keyword': 'divorced',
#    'second_keyword': 'writer',
#    'third_keyword': 'gets'},
#   'Young Adult'),
#  ({'first_keyword': 'father',
#    'second_keyword': 'eight',
#    'third_keyword': 'mother'},
#   'Yours, Mine and Ours'),
#  ({'first_keyword': 'political',
#    'second_keyword': 'cartoonist,',
#    'third_keyword': 'crime'},
#   'Zodiac'),
#  ({'first_keyword': 'comes',
#    'second_keyword': 'bride,',
#    'third_keyword': 'got'},
#   'Iliza Shlesinger: Unveiled'),
#  ({'first_keyword': 'ditching',
#    'second_keyword': 'domestic',
#    'third_keyword': 'life'},
#   'Miss Culinary'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'santiago',
#    'third_keyword': 'artemis,'},
#   'No Time for Shame'),
#  ({'first_keyword': 'wardrobe',
#    'second_keyword': 'malfunction',
#    'third_keyword': 'goes'},
#   'Candy Online'),
#  ({'first_keyword': 'drama',
#    'second_keyword': 'follows',
#    'third_keyword': 'political'},
#   'The Crown'),
#  ({'first_keyword': 'hollywood',
#    'second_keyword': 'stuntman',
#    'third_keyword': 'getaway'},
#   'Drive'),
#  ({'first_keyword': 'decades',
#    'second_keyword': 'nuclear',
#    'third_keyword': 'war,'},
#   'Iron Sky: The Coming Race'),
#  ({'first_keyword': "america's",
#    'second_keyword': 'beloved',
#    'third_keyword': 'ventriloquist'},
#   'Jeff Dunham: All Over the Map'),
#  ({'first_keyword': 'beginning',
#    'second_keyword': '20th',
#    'third_keyword': 'century,'},
#   'Suffragette'),
#  ({'first_keyword': 'determined',
#    'second_keyword': 'save',
#    'third_keyword': 'amazon'},
#   'The Green Inferno'),
#  ({'first_keyword': 'encountering',
#    'second_keyword': 'long',
#    'third_keyword': 'separation,'},
#   'At the Dolphin Bay'),
#  ({'first_keyword': '1980s',
#    'second_keyword': 'tokyo,',
#    'third_keyword': 'enigmatic'},
#   'Earthquake Bird'),
#  ({'first_keyword': 'remote',
#    'second_keyword': 'areas',
#    'third_keyword': 'amazon'},
#   'El sendero de la anaconda'),
#  ({'first_keyword': "mía's",
#    'second_keyword': 'vacation',
#    'third_keyword': 'dad'},
#   'GO! The Unforgettable Party'),
#  ({'first_keyword': 'pampered',
#    'second_keyword': 'kind-hearted',
#    'third_keyword': 'average'},
#   'Guna 369'),
#  ({'first_keyword': 'world-weary',
#    'second_keyword': 'man’s',
#    'third_keyword': 'self-imposed'},
#   'House Arrest'),
#  ({'first_keyword': 'unfiltered,',
#    'second_keyword': 'intimate',
#    'third_keyword': 'docuseries,'},
#   "I'm with the Band: Nasty Cherry"),
#  ({'first_keyword': 'chance',
#    'second_keyword': 'encounter',
#    'third_keyword': 'la,'},
#   'Inheritors'),
#  ({'first_keyword': 'gorging',
#    'second_keyword': 'sugary',
#    'third_keyword': 'snacks,'},
#   'K-On!'),
#  ({'first_keyword': 'seniors',
#    'second_keyword': 'sakuragaoka',
#    'third_keyword': 'high'},
#   'K-on! the movie'),
#  ({'first_keyword': 'selfish',
#    'second_keyword': 'postman',
#    'third_keyword': 'reclusive'},
#   'Klaus'),
#  ({'first_keyword': 'chance',
#    'second_keyword': 'encounter',
#    'third_keyword': 'ends'},
#   'La Robe De Mariee Des Cieux'),
#  ({'first_keyword': 'anna',
#    'second_keyword': 'chooses',
#    'third_keyword': 'february'},
#   'Leap Year'),
#  ({'first_keyword': 'beloved',
#    'second_keyword': "children's",
#    'third_keyword': 'book'},
#   'Llama Llama'),
#  ({'first_keyword': 'unfortunate',
#    'second_keyword': 'accident',
#    'third_keyword': 'alters'},
#   'My MVP Valentine'),
#  ({'first_keyword': 'refined',
#    'second_keyword': 'young',
#    'third_keyword': 'joseon'},
#   'My Sassy Girl'),
#  ({'first_keyword': 'trio',
#    'second_keyword': 'filmmakers',
#    'third_keyword': 'treks'},
#   'SunGanges'),
#  ({'first_keyword': 'intense',
#    'second_keyword': 'rivalry',
#    'third_keyword': 'henry'},
#   'The 24 Hour War'),
#  ({'first_keyword': 'band',
#    'second_keyword': 'misfit',
#    'third_keyword': 'rich'},
#   'The Club'),
#  ({'first_keyword': 'lonely',
#    'second_keyword': 'teenager',
#    'third_keyword': 'skips'},
#   'The Garden of Words'),
#  ({'first_keyword': 'trapped',
#    'second_keyword': 'island',
#    'third_keyword': 'destroyed'},
#   'The Stranded'),
#  ({'first_keyword': 'minds',
#    'second_keyword': 'behind',
#    'third_keyword': "history's"},
#   'The Toys That Made Us'),
#  ({'first_keyword': 'fateful',
#    'second_keyword': 'domestic',
#    'third_keyword': 'clash,'},
#   'The Yard'),
#  ({'first_keyword': 'spirited',
#    'second_keyword': 'high',
#    'third_keyword': 'school'},
#   'Westside Story'),
#  ({'first_keyword': 'intimate',
#    'second_keyword': 'documentary',
#    'third_keyword': 'follows'},
#   'Clarence Clemons: Who Do I Think I Am?'),
#  ({'first_keyword': 'irrepressible',
#    'second_keyword': 'french',
#    'third_keyword': 'comedian'},
#   'Fadily Camara : La plus drôle de tes copines'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'leaps',
#    'third_keyword': 'page'},
#   'My Dear Warrior'),
#  ({'first_keyword': 'docuseries,',
#    'second_keyword': 'soccer',
#    'third_keyword': 'great'},
#   'Maradona in Mexico'),
#  ({'first_keyword': 'chief',
#    'second_keyword': 'staff',
#    'third_keyword': 'national'},
#   'Chief of Staff'),
#  ({'first_keyword': 'kids',
#    'second_keyword': 'rule',
#    'third_keyword': 'place'},
#   'Harvey Street Kids'),
#  ({'first_keyword': 'comedian',
#    'second_keyword': 'jeff',
#    'third_keyword': 'garlin'},
#   'Jeff Garlin: Our Man In Chicago'),
#  ({'first_keyword': 'stream-of-consciousness',
#    'second_keyword': 'drama',
#    'third_keyword': 'centers'},
#   'A Single Man'),
#  ({'first_keyword': 'cusp',
#    'second_keyword': 'graduation,',
#    'third_keyword': 'accounting'},
#   'Put Your Head on My Shoulder'),
#  ({'first_keyword': 'near-death',
#    'second_keyword': 'trip',
#    'third_keyword': 'home,'},
#   'Submission'),
#  ({'first_keyword': 'traumatized',
#    'second_keyword': 'combat,',
#    'third_keyword': 'newly'},
#   'To Be of Service'),
#  ({'first_keyword': 'every',
#    'second_keyword': 'sunday,',
#    'third_keyword': 'hasan'},
#   'Patriot Act with Hasan Minhaj'),
#  ({'first_keyword': 'cohabiting',
#    'second_keyword': 'couple',
#    'third_keyword': '20s'},
#   'Little Things'),
#  ({'first_keyword': 'tackling',
#    'second_keyword': 'different',
#    'third_keyword': 'mysteries'},
#   'Busted!'),
#  ({'first_keyword': 'attack',
#    'second_keyword': 'pearl',
#    'third_keyword': 'harbor'},
#   'Greatest Events of WWII in Colour'),
#  ({'first_keyword': 'road', 'second_keyword': 'trip', 'third_keyword': 'save'},
#   'Green Eggs and Ham'),
#  ({'first_keyword': 'determined',
#    'second_keyword': 'get',
#    'third_keyword': 'fiancée'},
#   'Hit & Run'),
#  ({'first_keyword': 'snowstorm',
#    'second_keyword': 'hits',
#    'third_keyword': 'small'},
#   'Let It Snow'),
#  ({'first_keyword': 'mehdi',
#    'second_keyword': 'gets',
#    'third_keyword': 'prison,'},
#   'Paradise Beach'),
#  ({'first_keyword': 'deck',
#    'second_keyword': 'halls',
#    'third_keyword': 'sugar,'},
#   'The Great British Baking Show: Holidays'),
#  ({'first_keyword': 'surrendering',
#    'second_keyword': 'bogotá',
#    'third_keyword': 'police,'},
#   'Wild District'),
#  ({'first_keyword': 'reporter',
#    'second_keyword': 'must',
#    'third_keyword': 'hunt'},
#   'U Turn'),
#  ({'first_keyword': 'small-town',
#    'second_keyword': 'louisiana',
#    'third_keyword': 'minister'},
#   'Burning Cane'),
#  ({'first_keyword': 'hit',
#    'second_keyword': 'hard',
#    'third_keyword': 'lehman'},
#   'SCAMS'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'kingdoms',
#    'third_keyword': 'struggle'},
#   'Shadow'),
#  ({'first_keyword': 'luccas',
#    'second_keyword': 'gi',
#    'third_keyword': 'heading'},
#   'Luccas Neto in: Summer Camp'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'millennials',
#    'third_keyword': 'copes'},
#   'Millennials'),
#  ({'first_keyword': 'earn',
#    'second_keyword': 'cash,',
#    'third_keyword': 'roommates'},
#   'Sam & Cat'),
#  ({'first_keyword': 'snl',
#    'second_keyword': 'alumnus',
#    'third_keyword': 'subversive'},
#   'Seth Meyers: Lobby Baby'),
#  ({'first_keyword': 'soldier',
#    'second_keyword': 'adora',
#    'third_keyword': 'finds'},
#   'She-Ra and the Princesses of Power'),
#  ({'first_keyword': 'budding',
#    'second_keyword': 'teen',
#    'third_keyword': 'psychopath'},
#   'The End of the F***ing World'),
#  ({'first_keyword': 'verge',
#    'second_keyword': 'divorce,',
#    'third_keyword': 'middle-aged'},
#   'The Lovers'),
#  ({'first_keyword': 'student',
#    'second_keyword': 'reticent',
#    'third_keyword': 'teen'},
#   'Tune in for Love'),
#  ({'first_keyword': 'beloved',
#    'second_keyword': 'secret',
#    'third_keyword': 'agent'},
#   'Undercover Brother 2'),
#  ({'first_keyword': 'remake',
#    'second_keyword': 'korean',
#    'third_keyword': 'thriller,'},
#   'Voice'),
#  ({'first_keyword': "hilary's",
#    'second_keyword': 'plan',
#    'third_keyword': 'hire'},
#   'A Holiday Engagement'),
#  ({'first_keyword': 'twentysomething',
#    'second_keyword': 'georgia',
#    'third_keyword': 'pines'},
#   'Christmas Crush'),
#  ({'first_keyword': 'finding',
#    'second_keyword': 'letter',
#    'third_keyword': 'mailed'},
#   'Dear Santa'),
#  ({'first_keyword': 'years',
#    'second_keyword': 'segregation',
#    'third_keyword': 'forced'},
#   'District 9'),
#  ({'first_keyword': 'graduating,',
#    'second_keyword': 'four',
#    'third_keyword': 'college'},
#   'Kicking and Screaming'),
#  ({'first_keyword': 'south',
#    'second_keyword': 'london,',
#    'third_keyword': 'tradition'},
#   'Meet the Adebanjos'),
#  ({'first_keyword': 'people',
#    'second_keyword': 'dedicated',
#    'third_keyword': 'rejecting'},
#   'Minimalism: A Documentary About the Important Things'),
#  ({'first_keyword': 'taken',
#    'second_keyword': 'custody,',
#    'third_keyword': 'murder'},
#   'Oththa Seruppu Size 7'),
#  ({'first_keyword': 'cleveland',
#    'second_keyword': 'grandfather',
#    'third_keyword': 'brought'},
#   'The Devil Next Door'),
#  ({'first_keyword': 'motley',
#    'second_keyword': 'crew',
#    'third_keyword': 'bank'},
#   'Takers'),
#  ({'first_keyword': 'led',
#    'second_keyword': 'seventh-grader',
#    'third_keyword': 'c.j.,'},
#   '100 Things to do Before High School'),
#  ({'first_keyword': 'live-action',
#    'second_keyword': 'adventure,',
#    'third_keyword': 'gang'},
#   'A Fairly Odd Summer'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'cheerleader',
#    'third_keyword': 'bella'},
#   'Bella and the Bulldogs'),
#  ({'first_keyword': 'big', 'second_keyword': 'time', 'third_keyword': 'rush'},
#   'Big Time Movie'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'sally',
#    'third_keyword': 'hurst'},
#   "Don't Be Afraid of the Dark"),
#  ({'first_keyword': 'eccentric',
#    'second_keyword': 'game',
#    'third_keyword': 'designer'},
#   'Escape from Mr. Lemoncello’s Library'),
#  ({'first_keyword': 'arnold',
#    'second_keyword': 'crew',
#    'third_keyword': 'win'},
#   'Hey Arnold! The Jungle Movie'),
#  ({'first_keyword': 'century-old',
#    'second_keyword': 'curse',
#    'third_keyword': 'bad'},
#   'Jinxed'),
#  ({'first_keyword': 'trio',
#    'second_keyword': 'siblings',
#    'third_keyword': 'gets'},
#   'LEGENDS OF THE HIDDEN TEMPLE'),
#  ({'first_keyword': 'shy',
#    'second_keyword': 'teen',
#    'third_keyword': 'transfers'},
#   'Liar, Liar, Vampire'),
#  ({'first_keyword': 'weekend',
#    'second_keyword': 'beach-house',
#    'third_keyword': 'debauchery'},
#   'Shark Night'),
#  ({'first_keyword': 'high',
#    'second_keyword': 'school',
#    'third_keyword': 'girl-geek'},
#   'The Boy Who Cried Werewolf'),
#  ({'first_keyword': 'school',
#    'second_keyword': 'principal',
#    'third_keyword': 'gets'},
#   'The Massively Mixed-Up Middle School Mystery'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'singer',
#    'third_keyword': 'tori'},
#   'Victorious'),
#  ({'first_keyword': 'stylist,',
#    'second_keyword': 'hair',
#    'third_keyword': 'designer'},
#   '100% Hotter'),
#  ({'first_keyword': 'tasked',
#    'second_keyword': 'escorting',
#    'third_keyword': 'prosecution'},
#   '16 Blocks'),
#  ({'first_keyword': 'one',
#    'second_keyword': 'high',
#    'third_keyword': 'school'},
#   '187'),
#  ({'first_keyword': 'residents',
#    'second_keyword': 'isolated',
#    'third_keyword': 'town'},
#   'A Remarkable Tale'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'astronauts',
#    'third_keyword': 'attempt'},
#   'A Year In Space'),
#  ({'first_keyword': 'future',
#    'second_keyword': 'regeneration',
#    'third_keyword': 'technology'},
#   'Ad Vitam'),
#  ({'first_keyword': 'neo-nazi',
#    'second_keyword': 'gets',
#    'third_keyword': 'sent'},
#   'American History X'),
#  ({'first_keyword': 'time',
#    'second_keyword': 'passes',
#    'third_keyword': 'tension'},
#   'American Son'),
#  ({'first_keyword': 'gentle',
#    'second_keyword': 'businessman',
#    'third_keyword': 'forced'},
#   'Anger Management'),
#  ({'first_keyword': 'recovered',
#    'second_keyword': 'cockpit',
#    'third_keyword': 'footage'},
#   'Apache Warrior'),
#  ({'first_keyword': 'teen',
#    'second_keyword': 'autism',
#    'third_keyword': 'spectrum'},
#   'Atypical'),
#  ({'first_keyword': 'roberts',
#    'second_keyword': 'family',
#    'third_keyword': 'heads'},
#   'Barbie Dreamhouse Adventures: Go Team Roberts'),
#  ({'first_keyword': 'comedian',
#    'second_keyword': 'billy',
#    'third_keyword': 'eichner'},
#   'Billy on the Street'),
#  ({'first_keyword': 'reality',
#    'second_keyword': 'series',
#    'third_keyword': 'follows'},
#   'Bondi Rescue'),
#  ({'first_keyword': 'elizabeth',
#    'second_keyword': 'taylor',
#    'third_keyword': 'won'},
#   'Butterfield 8'),
#  ({'first_keyword': 'members',
#    'second_keyword': 'southern',
#    'third_keyword': 'clan'},
#   'Cat on a Hot Tin Roof'),
#  ({'first_keyword': 'stranded',
#    'second_keyword': 'school',
#    'third_keyword': 'holiday'},
#   'Christmas Break-In'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'girls',
#    'third_keyword': 'realize'},
#   'Christmas in the Heartland'),
#  ({'first_keyword': 'christmas',
#    'second_keyword': 'just',
#    'third_keyword': 'around'},
#   'Christmas Survival'),
#  ({'first_keyword': 'maladjusted',
#    'second_keyword': 'high',
#    'third_keyword': 'school'},
#   'CLANNAD'),
#  ({'first_keyword': "stylin'",
#    'second_keyword': 'special',
#    'third_keyword': 'agent'},
#   'Cleopatra Jones'),
#  ({'first_keyword': 'mild-mannered',
#    'second_keyword': 'janitor',
#    'third_keyword': 'duped'},
#   'Code Name: The Cleaner'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'physician',
#    'third_keyword': 'beautiful'},
#   'Doctor Zhivago'),
#  ({'first_keyword': 'notorious',
#    'second_keyword': 'thief',
#    'third_keyword': 'allies'},
#   'Drive'),
#  ({'first_keyword': 'blitzen',
#    'second_keyword': 'suddenly',
#    'third_keyword': 'retires,'},
#   'Elliot the Littlest Reindeer'),
#  ({'first_keyword': 'recruited',
#    'second_keyword': 'british',
#    'third_keyword': 'agent,'},
#   'Enter the Dragon'),
#  ({'first_keyword': 'entrepreneur',
#    'second_keyword': 'prone',
#    'third_keyword': 'partying'},
#   'Euphoria'),
#  ({'first_keyword': 'terrorists',
#    'second_keyword': 'hijack',
#    'third_keyword': '747'},
#   'Executive Decision'),
#  ({'first_keyword': 'tough',
#    'second_keyword': 'homicide',
#    'third_keyword': 'cop'},
#   'Fallen'),
#  ({'first_keyword': 'sportswriter',
#    'second_keyword': 'samoan',
#    'third_keyword': 'lawyer'},
#   'Fear and Loathing in Las Vegas'),
#  ({'first_keyword': 'documentary,',
#    'second_keyword': 'survivors',
#    'third_keyword': 'recall'},
#   'Fire in Paradise'),
#  ({'first_keyword': 'pulp-fiction',
#    'second_keyword': 'sci-fi',
#    'third_keyword': 'classic,'},
#   'Forbidden Planet'),
#  ({'first_keyword': 'tired',
#    'second_keyword': 'dealing',
#    'third_keyword': 'boyfriends'},
#   'Getting Played'),
#  ({'first_keyword': "gigi's",
#    'second_keyword': 'avant-garde',
#    'third_keyword': 'french'},
#   'Gigi'),
#  ({'first_keyword': 'witty',
#    'second_keyword': 'whodunit,',
#    'third_keyword': 'wealthy'},
#   'Gosford Park'),
#  ({'first_keyword': 'car',
#    'second_keyword': 'crash,',
#    'third_keyword': 'criminal'},
#   'Gothika'),
#  ({'first_keyword': 'john',
#    'second_keyword': 'travolta',
#    'third_keyword': 'olivia'},
#   'Grease'),
#  ({'first_keyword': 'helena',
#    'second_keyword': 'gains',
#    'third_keyword': 'love'},
#   'Hache'),
#  ({'first_keyword': 'inspired',
#    'second_keyword': 'championship',
#    'third_keyword': 'match'},
#   'Haikyu!!'),
#  ({'first_keyword': 'relive',
#    'second_keyword': 'greatest',
#    'third_keyword': 'moments'},
#   'Harlem Globetrotters: The Team That Changed the World'),
#  ({'first_keyword': 'bffs',
#    'second_keyword': 'wesley',
#    'third_keyword': 'georgie'},
#   'Hello Ninja'),
#  ({'first_keyword': 'hazardous',
#    'second_keyword': 'highways',
#    'third_keyword': "canada's"},
#   'Highway Thru Hell'),
#  ({'first_keyword': 'husband',
#    'second_keyword': 'abruptly',
#    'third_keyword': 'ends'},
#   'Holiday in the Wild'),
#  ({'first_keyword': 'home',
#    'second_keyword': 'holidays,',
#    'third_keyword': 'broke'},
#   'Holly Star'),
#  ({'first_keyword': 'aging',
#    'second_keyword': 'lothario',
#    'third_keyword': 'gets'},
#   'How to Be a Latin Lover'),
#  ({'first_keyword': 'dray',
#    'second_keyword': 'lives',
#    'third_keyword': 'life'},
#   'How to Be a Player'),
#  ({'first_keyword': 'end',
#    'second_keyword': 'apartheid,',
#    'third_keyword': 'newly'},
#   'Invictus'),
#  ({'first_keyword': 'jimi',
#    'second_keyword': "hendrix's",
#    'third_keyword': 'family,'},
#   'Jimi Hendrix'),
#  ({'first_keyword': 'wealthy,',
#    'second_keyword': 'despicable',
#    'third_keyword': 'businessman'},
#   "King's Ransom"),
#  ({'first_keyword': 'motley',
#    'second_keyword': 'crew',
#    'third_keyword': 'apocalypse'},
#   'Legion'),
#  ({'first_keyword': 'pedro',
#    'second_keyword': 'marries',
#    'third_keyword': 'sister,'},
#   'Like Water for Chocolate'),
#  ({'first_keyword': 'steering',
#    'second_keyword': 'clear',
#    'third_keyword': 'convention,'},
#   'Listen Up! The Lives of Quincy Jones'),
#  ({'first_keyword': '23rd',
#    'second_keyword': 'century,',
#    'third_keyword': 'inhabitants'},
#   "Logan's Run"),
#  ({'first_keyword': 'black',
#    'second_keyword': 'comedy,',
#    'third_keyword': 'english'},
#   'Lolita'),
#  ({'first_keyword': 'urban',
#    'second_keyword': 'romantic',
#    'third_keyword': 'comedy'},
#   'Love Jones'),
#  ({'first_keyword': 'high',
#    'second_keyword': 'schooler',
#    'third_keyword': 'yuta'},
#   'Love, Chunibyo & Other Delusions!'),
#  ({'first_keyword': 'woman',
#    'second_keyword': 'joins',
#    'third_keyword': 'janitorial'},
#   'Mad Money'),
#  ({'first_keyword': 'keep',
#    'second_keyword': 'boys',
#    'third_keyword': 'line,'},
#   'Maid-Sama!'),
#  ({'first_keyword': 'fact',
#    'second_keyword': 'meets',
#    'third_keyword': 'fiction'},
#   'Mars'),
#  ({'first_keyword': 'terraformed',
#    'second_keyword': 'post-disaster',
#    'third_keyword': 'mars,'},
#   'Mobile Suit Gundam: Iron-Blooded Orphans'),
#  ({'first_keyword': 'tv',
#    'second_keyword': 'news',
#    'third_keyword': 'reporter'},
#   'Money Talks'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'friends',
#    'third_keyword': 'uncover'},
#   'Monster House'),
#  ({'first_keyword': 'marlon',
#    'second_keyword': 'brando',
#    'third_keyword': 'gives'},
#   'Mutiny on the Bounty'),
#  ({'first_keyword': 'ignacio',
#    'second_keyword': 'learns',
#    'third_keyword': "orphanage's"},
#   'Nacho Libre'),
#  ({'first_keyword': 'parody',
#    'second_keyword': 'lethal',
#    'third_keyword': 'weapon'},
#   "National Lampoon's Loaded Weapon 1"),
#  ({'first_keyword': 'frank',
#    'second_keyword': 'sinatra',
#    'third_keyword': 'leads'},
#   "Ocean's Eleven"),
#  ({'first_keyword': 'fictionalized',
#    'second_keyword': 'account',
#    'third_keyword': 'three'},
#   'Paid in Full'),
#  ({'first_keyword': 'fab', 'second_keyword': 'five', 'third_keyword': 'touch'},
#   "Queer Eye: We're in Japan!"),
#  ({'first_keyword': 'jim',
#    'second_keyword': 'stark',
#    'third_keyword': 'arrives'},
#   'Rebel Without a Cause'),
#  ({'first_keyword': 'april',
#    'second_keyword': "frank's",
#    'third_keyword': 'marriage'},
#   'Revolutionary Road'),
#  ({'first_keyword': 'woman',
#    'second_keyword': 'thrilled',
#    'third_keyword': 'find'},
#   "Rosemary's Baby"),
#  ({'first_keyword': 'law',
#    'second_keyword': 'student',
#    'third_keyword': 'befriends'},
#   'Rounders'),
#  ({'first_keyword': 'visit',
#    'second_keyword': 'bronx',
#    'third_keyword': 'help'},
#   'Rumble in the Bronx'),
#  ({'first_keyword': 'fleeing',
#    'second_keyword': 'family',
#    'third_keyword': 'business'},
#   'Santa Girl'),
#  ({'first_keyword': 'man',
#    'second_keyword': 'returns',
#    'third_keyword': 'home'},
#   'Sling Blade'),
#  ({'first_keyword': '1950s',
#    'second_keyword': 'harlem,',
#    'third_keyword': 'three'},
#   'Sparkle'),
#  ({'first_keyword': 'seemingly',
#    'second_keyword': 'invincible',
#    'third_keyword': 'spider-man'},
#   'Spider-Man 3'),
#  ({'first_keyword': 'epic',
#    'second_keyword': 'documentary,',
#    'third_keyword': 'last-surviving'},
#   'Spitfire: The Plane that Saved the World'),
#  ({'first_keyword': 'brennan',
#    'second_keyword': 'dale',
#    'third_keyword': 'might'},
#   'Step Brothers'),
#  ({'first_keyword': 'get', 'second_keyword': 'away', 'third_keyword': 'thug'},
#   'Superfly'),
#  ({'first_keyword': 'ten',
#    'second_keyword': 'queens',
#    'third_keyword': 'must'},
#   'The Boulet Brothers Dragula'),
#  ({'first_keyword': 'new', 'second_keyword': 'york', 'third_keyword': 'city'},
#   'The Brave One'),
#  ({'first_keyword': 'progressive',
#    'second_keyword': 'new',
#    'third_keyword': "minister's"},
#   'The Christmas Candle'),
#  ({'first_keyword': 'depression-era',
#    'second_keyword': 'new',
#    'third_keyword': 'orleans,'},
#   'The Cincinnati Kid'),
#  ({'first_keyword': 'nektons',
#    'second_keyword': 'family',
#    'third_keyword': 'underwater'},
#   'The Deep'),
#  ({'first_keyword': 'nicholas',
#    'second_keyword': 'receives',
#    'third_keyword': 'unusual'},
#   'The Game'),
#  ({'first_keyword': 'world', 'second_keyword': 'war', 'third_keyword': 'ii,'},
#   'The Great Raid'),
#  ({'first_keyword': 'de', 'second_keyword': 'la', 'third_keyword': 'mora'},
#   'The House of Flowers Presents: The Funeral'),
#  ({'first_keyword': 'wayward',
#    'second_keyword': 'prince',
#    'third_keyword': 'hal'},
#   'The King'),
#  ({'first_keyword': 'private',
#    'second_keyword': 'eye',
#    'third_keyword': 'joe'},
#   'The Last Boy Scout'),
#  ({'first_keyword': 'gravity-defying',
#    'second_keyword': 'boy',
#    'third_keyword': 'raised'},
#   'The Man Without Gravity'),
#  ({'first_keyword': 'computer',
#    'second_keyword': 'hacker',
#    'third_keyword': 'learns'},
#   'The Matrix'),
#  ({'first_keyword': 'crew',
#    'second_keyword': 'must',
#    'third_keyword': 'protect'},
#   'The Matrix Reloaded'),
#  ({'first_keyword': 'final',
#    'second_keyword': 'installment',
#    'third_keyword': 'matrix'},
#   'The Matrix Revolutions'),
#  ({'first_keyword': 'carrying',
#    'second_keyword': 'prison',
#    'third_keyword': 'sentences,'},
#   'The Old Thieves: The Legend of Artegios'),
#  ({'first_keyword': 'law',
#    'second_keyword': 'student',
#    'third_keyword': 'darby'},
#   'The Pelican Brief'),
#  ({'first_keyword': 'government',
#    'second_keyword': 'spy',
#    'third_keyword': 'hospitalized,'},
#   'The Tuxedo'),
#  ({'first_keyword': 'spotlight',
#    'second_keyword': 'shines',
#    'third_keyword': 'iconic'},
#   'Thelonious Monk: Straight, No Chaser'),
#  ({'first_keyword': 'grabbleapple',
#    'second_keyword': 'harvest',
#    'third_keyword': 'season'},
#   'True: Grabbleapple Harvest'),
#  ({'first_keyword': 'moments',
#    'second_keyword': 'arrives',
#    'third_keyword': 'spain'},
#   'Vantage Point'),
#  ({'first_keyword': 'josé',
#    'second_keyword': 'olaya,',
#    'third_keyword': 'spanish'},
#   'Vientos de agua'),
#  ({'first_keyword': 'mysterious',
#    'second_keyword': 'classmate',
#    'third_keyword': 'leads'},
#   'We Are the Wave'),
#  ({'first_keyword': 'spoiled',
#    'second_keyword': 'girl',
#    'third_keyword': 'pushes'},
#   'Wild Child'),
#  ({'first_keyword': 'introspective',
#    'second_keyword': 'rockumentary',
#    'third_keyword': 'follows'},
#   'Zoé: Panoramas'),
#  ({'first_keyword': 'looking',
#    'second_keyword': 'survive',
#    'third_keyword': 'world'},
#   'Zombieland'),
#  ({'first_keyword': 'argentine',
#    'second_keyword': 'comedian',
#    'third_keyword': 'grego'},
#   'Grego Rossello: Disculpe las molestias'),
#  ({'first_keyword': 'ohma',
#    'second_keyword': 'tokita',
#    'third_keyword': 'enters'},
#   'KENGAN ASHURA'),
#  ({'first_keyword': 'patrons',
#    'second_keyword': 'otherwise',
#    'third_keyword': 'mundane'},
#   'Midnight Diner: Tokyo Stories'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'nefarious',
#    'third_keyword': 'schemes'},
#   'Nowhere Man'),
#  ({'first_keyword': 'holiday',
#    'second_keyword': 'stay',
#    'third_keyword': 'hotel'},
#   'Sleepless Society: Bedtime Wishes'),
#  ({'first_keyword': 'college',
#    'second_keyword': 'student',
#    'third_keyword': 'psychic'},
#   'Bring It On, Ghost'),
#  ({'first_keyword': 'delve',
#    'second_keyword': 'delectable',
#    'third_keyword': 'world'},
#   'Flavorful Origins'),
#  ({'first_keyword': 'early',
#    'second_keyword': '1990s,',
#    'third_keyword': 'love'},
#   'Mehandi Circus'),
#  ({'first_keyword': 'head',
#    'second_keyword': 'real',
#    'third_keyword': 'estate'},
#   'Tomorrow with You'),
#  ({'first_keyword': 'detective',
#    'second_keyword': 'finds',
#    'third_keyword': '30'},
#   'Tunnel'),
#  ({'first_keyword': 'first',
#    'second_keyword': 'stand-up',
#    'third_keyword': 'special,'},
#   'Arsenio Hall: Smart & Classy'),
#  ({'first_keyword': 'talk',
#    'second_keyword': 'show',
#    'third_keyword': 'straight'},
#   'Shine On with Reese'),
#  ({'first_keyword': 'aaron',
#    'second_keyword': 'paul,',
#    'third_keyword': 'vince'},
#   'The Road to El Camino: Behind the Scenes of El Camino: A Breaking Bad Movie'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'captures',
#    'third_keyword': 'joy'},
#   'A 3 Minute Hug'),
#  ({'first_keyword': 'alex',
#    'second_keyword': 'trebek',
#    'third_keyword': 'hosts'},
#   'Jeopardy!'),
#  ({'first_keyword': 'ancient',
#    'second_keyword': 'sport',
#    'third_keyword': 'traditionally'},
#   'Little Miss Sumo'),
#  ({'first_keyword': 'six',
#    'second_keyword': 'hopeful',
#    'third_keyword': 'friends'},
#   'Wait, My Youth'),
#  ({'first_keyword': 'shy',
#    'second_keyword': 'college',
#    'third_keyword': 'student'},
#   'A Little Thing Called First Love'),
#  ({'first_keyword': 'star',
#    'second_keyword': 'player',
#    'third_keyword': 'dies'},
#   'The Last Whistle'),
#  ({'first_keyword': 'based',
#    'second_keyword': 'memoirs',
#    'third_keyword': 'author'},
#   'A Tale of Love and Darkness'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'friends',
#    'third_keyword': 'making'},
#   'Assimilate'),
#  ({'first_keyword': 'meet',
#    'second_keyword': 'beloved',
#    'third_keyword': 'sitcom'},
#   'BoJack Horseman'),
#  ({'first_keyword': 'honest',
#    'second_keyword': 'lawyer',
#    'third_keyword': 'reaches'},
#   'Brotherhood'),
#  ({'first_keyword': 'educational',
#    'second_keyword': 'series',
#    'third_keyword': 'tiny'},
#   'ChuChu TV Kids Songs, Learning Videos & Bedtime Stories'),
#  ({'first_keyword': 'secrets',
#    'second_keyword': 'bubble',
#    'third_keyword': 'surface'},
#   'Consequences\xa0'),
#  ({'first_keyword': '1970s',
#    'second_keyword': 'la,',
#    'third_keyword': 'struggling'},
#   'Dolemite Is My Name'),
#  ({'first_keyword': 'four',
#    'second_keyword': 'intrepid',
#    'third_keyword': 'impulsive'},
#   'Drug Squad: Costa del Sol'),
#  ({'first_keyword': 'teen',
#    'second_keyword': 'siblings',
#    'third_keyword': 'hayley'},
#   'Greenhouse Academy'),
#  ({'first_keyword': 'extraordinary',
#    'second_keyword': 'life',
#    'third_keyword': 'beloved'},
#   'It Takes a Lunatic'),
#  ({'first_keyword': 'dramatization',
#    'second_keyword': 'tells',
#    'third_keyword': 'story'},
#   'Monzón: A Knockout Blow'),
#  ({'first_keyword': '"king',
#    'second_keyword': 'bollywood"',
#    'third_keyword': 'shah'},
#   'My Next Guest with David Letterman and Shah Rukh Khan'),
#  ({'first_keyword': 'fun',
#    'second_keyword': 'funny',
#    'third_keyword': 'competition'},
#   'Nailed It! France'),
#  ({'first_keyword': 'competition',
#    'second_keyword': 'show,',
#    'third_keyword': 'novice'},
#   'Nailed It! Spain'),
#  ({'first_keyword': 'monstrous',
#    'second_keyword': 'frights',
#    'third_keyword': 'meet'},
#   'Prank Encounters'),
#  ({'first_keyword': 'mysterious',
#    'second_keyword': 'woman',
#    'third_keyword': 'saves'},
#   'Rattlesnake'),
#  ({'first_keyword': 'pressured',
#    'second_keyword': 'marry',
#    'third_keyword': 'nice'},
#   'The Awakening of Motti Wolkenbruch'),
#  ({'first_keyword': 'acting',
#    'second_keyword': 'coach',
#    'third_keyword': 'sandy'},
#   'The Kominsky Method'),
#  ({'first_keyword': 'magical',
#    'second_keyword': 'world',
#    'third_keyword': 'inter-clan'},
#   'The Untamed'),
#  ({'first_keyword': 'world',
#    'second_keyword': 'mystery',
#    'third_keyword': 'little'},
#   'Booba'),
#  ({'first_keyword': 'living',
#    'second_keyword': 'best',
#    'third_keyword': 'life'},
#   'Daybreak'),
#  ({'first_keyword': 'affectionate',
#    'second_keyword': 'documentary',
#    'third_keyword': 'looks'},
#   'Echo in the Canyon'),
#  ({'first_keyword': 'wedding',
#    'second_keyword': 'malaysian',
#    'third_keyword': 'village'},
#   'Revenge of the Pontianak'),
#  ({'first_keyword': 'ex-con',
#    'second_keyword': 'just',
#    'third_keyword': 'getting'},
#   'American Heist'),
#  ({'first_keyword': 'chef',
#    'second_keyword': 'david',
#    'third_keyword': 'chang'},
#   'Breakfast, Lunch & Dinner'),
#  ({'first_keyword': 'ruffling',
#    'second_keyword': 'majestic',
#    'third_keyword': 'feathers'},
#   'Dancing with the Birds'),
#  ({'first_keyword': 'spin-off,',
#    'second_keyword': 'martial',
#    'third_keyword': 'arts'},
#   'Master Z: The Ip Man Legacy'),
#  ({'first_keyword': 'hired',
#    'second_keyword': 'gun',
#    'third_keyword': 'second'},
#   "Hunter's Prayer"),
#  ({'first_keyword': 'passing',
#    'second_keyword': 'dog,',
#    'third_keyword': 'long-widowed'},
#   "I'll See You in My Dreams"),
#  ({'first_keyword': 'jenny',
#    'second_keyword': "slate's",
#    'third_keyword': 'first'},
#   'Jenny Slate: Stage Fright'),
#  ({'first_keyword': 'friends',
#    'second_keyword': 'visit',
#    'third_keyword': 'vandalized'},
#   'The Texas Chainsaw Massacre'),
#  ({'first_keyword': 'bike',
#    'second_keyword': 'messenger',
#    'third_keyword': 'falls'},
#   'Tracers'),
#  ({'first_keyword': 'man',
#    'second_keyword': 'cured',
#    'third_keyword': 'leprosy'},
#   'يوم الدين'),
#  ({'first_keyword': 'sketchy',
#    'second_keyword': 'arms',
#    'third_keyword': 'transaction'},
#   'Free Fire'),
#  ({'first_keyword': 'kaal', 'second_keyword': 'back', 'third_keyword': '–'},
#   'Little Singham: Kaal Ki Tabaahi'),
#  ({'first_keyword': 'streetwise',
#    'second_keyword': 'cop',
#    'third_keyword': 'teams'},
#   'Men in Black'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'fierce',
#    'third_keyword': 'mothers'},
#   'Moms at War'),
#  ({'first_keyword': 'crew',
#    'second_keyword': 'trapped',
#    'third_keyword': 'aboard'},
#   'The Command'),
#  ({'first_keyword': 'girlfriend',
#    'second_keyword': 'wins',
#    'third_keyword': 'miss'},
#   '10 Days in Sun City'),
#  ({'first_keyword': 'heroic',
#    'second_keyword': 'health',
#    'third_keyword': 'workers'},
#   '93 Days'),
#  ({'first_keyword': 'fed',
#    'second_keyword': 'families',
#    'third_keyword': 'classmates,'},
#   'Baby'),
#  ({'first_keyword': 'desperate',
#    'second_keyword': 'parents',
#    'third_keyword': 'tow,'},
#   'Eli'),
#  ({'first_keyword': 'teacher',
#    'second_keyword': 'turns',
#    'third_keyword': 'dubious'},
#   'In My Country'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'interior',
#    'third_keyword': 'designers'},
#   'Interior Design Masters'),
#  ({'first_keyword': 'twinkle,',
#    'second_keyword': 'mia,',
#    'third_keyword': 'jacus'},
#   'Little Baby Bum: Nursery Rhyme Friends'),
#  ({'first_keyword': 'burned',
#    'second_keyword': 'life,',
#    'third_keyword': 'miles'},
#   'Living with Yourself'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'people',
#    'third_keyword': 'meets'},
#   'Love, Surreal and Odd'),
#  ({'first_keyword': 'steven',
#    'second_keyword': 'rinella',
#    'third_keyword': 'scrounges'},
#   'MeatEater'),
#  ({'first_keyword': 'decorating',
#    'second_keyword': 'home',
#    'third_keyword': 'devouring'},
#   'Mighty Little Bheem: Diwali'),
#  ({'first_keyword': 'jin',
#    'second_keyword': 'dragon',
#    'third_keyword': 'monster'},
#   'MONKART'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'fashion',
#    'third_keyword': "designer's"},
#   'New Money'),
#  ({'first_keyword': 'find',
#    'second_keyword': 'therapy',
#    'third_keyword': 'dog,'},
#   'Seventeen'),
#  ({'first_keyword': 'find',
#    'second_keyword': 'fun',
#    'third_keyword': 'adventure'},
#   'Spirit Riding Free: Pony Tales'),
#  ({'first_keyword': 'doubting',
#    'second_keyword': 'future',
#    'third_keyword': 'nun,'},
#   'Tatu'),
#  ({'first_keyword': 'documentary,',
#    'second_keyword': 'alex',
#    'third_keyword': 'trusts'},
#   'Tell Me Who I Am'),
#  ({'first_keyword': 'dark',
#    'second_keyword': 'comedy,',
#    'third_keyword': 'wealthy'},
#   'The House of Flowers'),
#  ({'first_keyword': 'widow',
#    'second_keyword': 'gets',
#    'third_keyword': 'swindled'},
#   'The Laundromat'),
#  ({'first_keyword': 'reclusive,',
#    'second_keyword': 'socially',
#    'third_keyword': 'awkward'},
#   'Toon'),
#  ({'first_keyword': 'eradicating',
#    'second_keyword': 'disease',
#    'third_keyword': 'selecting'},
#   'Unnatural Selection'),
#  ({'first_keyword': 'pampered',
#    'second_keyword': 'heir',
#    'third_keyword': 'must'},
#   'Up North'),
#  ({'first_keyword': 'hoping',
#    'second_keyword': 'good',
#    'third_keyword': 'making'},
#   'Upstarts'),
#  ({'first_keyword': 'now',
#    'second_keyword': 'lecturer',
#    'third_keyword': 'edinburgh,'},
#   'Verses of Love 2'),
#  ({'first_keyword': 'mysterious',
#    'second_keyword': 'box',
#    'third_keyword': 'arrives'},
#   'Chosen'),
#  ({'first_keyword': 'moving',
#    'second_keyword': 'beijing',
#    'third_keyword': 'mother,'},
#   'The Karate Kid'),
#  ({'first_keyword': 'learn',
#    'second_keyword': 'secret',
#    'third_keyword': 'plot'},
#   'THE UNLISTED'),
#  ({'first_keyword': 'sound',
#    'second_keyword': 'director',
#    'third_keyword': 'suddenly'},
#   'Another Miss Oh'),
#  ({'first_keyword': 'shocked',
#    'second_keyword': 'friend',
#    'third_keyword': 'embraces'},
#   'Ghosts of Sugar Land'),
#  ({'first_keyword': 'fans,',
#    'second_keyword': 'experts',
#    'third_keyword': 'creators'},
#   'League of Legends Origins'),
#  ({'first_keyword': 'korea’s',
#    'second_keyword': 'beloved',
#    'third_keyword': 'comedian'},
#   'Park Na-rae: Glamour Warning'),
#  ({'first_keyword': 'facing',
#    'second_keyword': 'major',
#    'third_keyword': 'changes,'},
#   'Second 20s'),
#  ({'first_keyword': 'single',
#    'second_keyword': 'mother',
#    'third_keyword': 'twin'},
#   'Sinister 2'),
#  ({'first_keyword': 'special',
#    'second_keyword': 'forces',
#    'third_keyword': 'trainer'},
#   'The Game Changers'),
#  ({'first_keyword': "cop's",
#    'second_keyword': 'fiancée',
#    'third_keyword': 'jewelry'},
#   'Black Money Love'),
#  ({'first_keyword': 'detective',
#    'second_keyword': 'cold',
#    'third_keyword': 'murder'},
#   'Dark Crimes'),
#  ({'first_keyword': 'determined',
#    'second_keyword': 'trace',
#    'third_keyword': 'ancestral'},
#   'Homeland'),
#  ({'first_keyword': 'argentina',
#    'second_keyword': 'colombia,',
#    'third_keyword': 'stunning'},
#   'Magical Andes'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'breed',
#    'third_keyword': 'secret'},
#   'Power Rangers Beast Morphers'),
#  ({'first_keyword': 'band',
#    'second_keyword': 'young',
#    'third_keyword': 'warriors'},
#   'Saint Seiya'),
#  ({'first_keyword': 'quebecois',
#    'second_keyword': 'comedy',
#    'third_keyword': 'star'},
#   'Martin Matte: La vie, la mort...eh la la..!'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'brothers',
#    'third_keyword': '–'},
#   'Street Flow'),
#  ({'first_keyword': 'father',
#    'second_keyword': 'dies',
#    'third_keyword': 'husband'},
#   'The Lies Within'),
#  ({'first_keyword': "mother's",
#    'second_keyword': 'plan',
#    'third_keyword': 'find'},
#   'Bygones Be Bygones'),
#  ({'first_keyword': 'fugitive',
#    'second_keyword': 'jesse',
#    'third_keyword': 'pinkman'},
#   'El Camino: A Breaking Bad Movie'),
#  ({'first_keyword': 'wife',
#    'second_keyword': 'injured',
#    'third_keyword': 'daughter'},
#   'Fractured'),
#  ({'first_keyword': 'real',
#    'second_keyword': 'people',
#    'third_keyword': 'sit'},
#   'Haunted'),
#  ({'first_keyword': 'bullied',
#    'second_keyword': 'teenager',
#    'third_keyword': 'turns'},
#   'Insatiable'),
#  ({'first_keyword': 'matriarch',
#    'second_keyword': 'bent',
#    'third_keyword': 'lavish'},
#   'The Bling Lagosians'),
#  ({'first_keyword': 'con',
#    'second_keyword': 'man',
#    'third_keyword': 'would-be'},
#   'The Forest of Love'),
#  ({'first_keyword': 'parisian',
#    'second_keyword': 'elsa',
#    'third_keyword': 'gets'},
#   'The Hook Up Plan'),
#  ({'first_keyword': 'back',
#    'second_keyword': 'childhood',
#    'third_keyword': 'home'},
#   'The Influence'),
#  ({'first_keyword': 'series',
#    'second_keyword': 'magical',
#    'third_keyword': 'missions,'},
#   'YooHoo to the Rescue'),
#  ({'first_keyword': 'yearning',
#    'second_keyword': 'earn',
#    'third_keyword': 'title'},
#   'Beyblade Burst Turbo'),
#  ({'first_keyword': 'singer-songwriter',
#    'second_keyword': 'gen',
#    'third_keyword': 'hoshino'},
#   'GEN HOSHINO STADIUM TOUR “POP VIRUS”'),
#  ({'first_keyword': 'suddenly',
#    'second_keyword': 'broke,',
#    'third_keyword': 'formerly'},
#   "Schitt's Creek"),
# ...
#   'Sugar Rush'),
#  ({'first_keyword': 'world', 'second_keyword': 'war', 'third_keyword': 'ii,'},
#   'The Exception'),
#  ({'first_keyword': 'psychological',
#    'second_keyword': 'thriller,',
#    'third_keyword': 'painter'},
#   'The Son'),
#  ({'first_keyword': 'stumbling',
#    'second_keyword': 'school',
#    'third_keyword': 'witches,'},
#   'The Worst Witch'),
#  ({'first_keyword': 'massive',
#    'second_keyword': 'alien',
#    'third_keyword': 'artifact'},
#   'Another Life'),
#  ({'first_keyword': 'explore',
#    'second_keyword': 'data',
#    'third_keyword': 'company'},
#   'The Great Hack'),
#  ({'first_keyword': 'singers',
#    'second_keyword': 'europe',
#    'third_keyword': 'represent'},
#   'Eurovision Song Contest'),
#  ({'first_keyword': 'developing',
#    'second_keyword': '"infidelity',
#    'third_keyword': 'formula"'},
#   'The Competition'),
#  ({'first_keyword': 'jewish',
#    'second_keyword': 'cinema',
#    'third_keyword': 'owner'},
#   'Inglourious Basterds'),
#  ({'first_keyword': 'couples',
#    'second_keyword': 'compete',
#    'third_keyword': 'see'},
#   'My Hotter Half'),
#  ({'first_keyword': 'canada,',
#    'second_keyword': 'colorful',
#    'third_keyword': 'collection'},
#   'Storage Wars: Northern Treasures'),
#  ({'first_keyword': 'wife',
#    'second_keyword': 'terminally',
#    'third_keyword': 'ill,'},
#   'Unfinished Song'),
#  ({'first_keyword': 'songs',
#    'second_keyword': 'made',
#    'third_keyword': 'famous'},
#   'Beat Bugs'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'woman',
#    'third_keyword': 'faces'},
#   'Bewafaa'),
#  ({'first_keyword': 'remake',
#    'second_keyword': '"cellular,"',
#    'third_keyword': 'debt'},
#   'Connected'),
#  ({'first_keyword': 'd.l.',
#    'second_keyword': 'hughley',
#    'third_keyword': 'riffs'},
#   'D.L. Hughley: Contrarian'),
#  ({'first_keyword': 'signature',
#    'second_keyword': 'one-liners',
#    'third_keyword': 'drawings,'},
#   'Demetri Martin: The Overthinker'),
#  ({'first_keyword': 'feeling',
#    'second_keyword': 'guilty',
#    'third_keyword': 'high-speed'},
#   'The Beast Stalker'),
#  ({'first_keyword': 'debt',
#    'second_keyword': 'collector',
#    'third_keyword': 'takes'},
#   'The Midas Touch'),
#  ({'first_keyword': 'empress',
#    'second_keyword': 'rules',
#    'third_keyword': 'land'},
#   'The Twins Effect II'),
#  ({'first_keyword': 'retrieve',
#    'second_keyword': 'healing',
#    'third_keyword': 'bead'},
#   'Twins Mission'),
#  ({'first_keyword': "man's",
#    'second_keyword': 'inability',
#    'third_keyword': 'conquer'},
#   'May You Prosper'),
#  ({'first_keyword': 'bustling',
#    'second_keyword': 'center',
#    'third_keyword': 'hong'},
#   'Sexy Central'),
#  ({'first_keyword': 'estranged',
#    'second_keyword': 'mother',
#    'third_keyword': 'suddenly'},
#   '¡Ay, mi madre!'),
#  ({'first_keyword': 'jerry',
#    'second_keyword': "seinfeld's",
#    'third_keyword': 'roving'},
#   'Comedians in Cars Getting Coffee'),
#  ({'first_keyword': 'record-setting',
#    'second_keyword': 'triathlete',
#    'third_keyword': 'dares'},
#   'Iron Cowboy: The Story of the 50.50.50'),
#  ({'first_keyword': 'eight',
#    'second_keyword': 'thieves',
#    'third_keyword': 'take'},
#   'La casa de papel'),
#  ({'first_keyword': 'docuseries',
#    'second_keyword': 'set',
#    'third_keyword': 'one'},
#   'Last Chance U'),
#  ({'first_keyword': 'all-new',
#    'second_keyword': '“fab',
#    'third_keyword': 'five”'},
#   'Queer Eye'),
#  ({'first_keyword': 'seiya',
#    'second_keyword': 'knights',
#    'third_keyword': 'zodiac'},
#   '\u200bSAINT SEIYA: Knights of the Zodiac'),
#  ({'first_keyword': 'fourth-grade',
#    'second_keyword': 'friends',
#    'third_keyword': 'george'},
#   'The Epic Tales of Captain Underpants'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'young',
#    'third_keyword': 'friends'},
#   'Typewriter'),
#  ({'first_keyword': 'free',
#    'second_keyword': 'spirit',
#    'third_keyword': 'goo'},
#   'Rookie Historian Goo Hae-Ryung'),
#  ({'first_keyword': 'jennifer',
#    'second_keyword': 'wakes',
#    'third_keyword': 'amnesia'},
#   'Secret Obsession'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'charge',
#    'third_keyword': 'foster'},
#   'Short Term 12'),
#  ({'first_keyword': 'unconventional',
#    'second_keyword': 'police',
#    'third_keyword': 'officer'},
#   'Mauli'),
#  ({'first_keyword': 'pinky',
#    'second_keyword': 'malinky',
#    'third_keyword': 'sees'},
#   'Pinky Malinky'),
#  ({'first_keyword': 'complicated,',
#    'second_keyword': 'one-sided',
#    'third_keyword': 'secret'},
#   'Unrequited Love'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'dancer',
#    'third_keyword': 'accompanies'},
#   'Bogda'),
#  ({'first_keyword': 'actor',
#    'second_keyword': 'david',
#    'third_keyword': 'harbour'},
#   'Frankenstein’s Monster’s Monster, Frankenstein'),
#  ({'first_keyword': 'upon',
#    'second_keyword': 'time,',
#    'third_keyword': 'baseball'},
#   'Jack of all Trades'),
#  ({'first_keyword': 'cohabitating',
#    'second_keyword': 'couple',
#    'third_keyword': 'gary'},
#   'The Break-Up'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'orleans',
#    'third_keyword': 'jazz'},
#   'The Princess and the Frog'),
#  ({'first_keyword': 'divorced',
#    'second_keyword': 'professor',
#    'third_keyword': 'shares'},
#   'We Belong Together'),
#  ({'first_keyword': 'outcast',
#    'second_keyword': 'descendant',
#    'third_keyword': 'lawman'},
#   'Wynonna Earp'),
#  ({'first_keyword': 'high',
#    'second_keyword': 'school',
#    'third_keyword': 'way'},
#   'Angel Beats!'),
#  ({'first_keyword': 'teen',
#    'second_keyword': 'haunted',
#    'third_keyword': 'spirit'},
#   'Anohana: The Flower We Saw That Day'),
#  ({'first_keyword': 'enemy',
#    'second_keyword': 'immune',
#    'third_keyword': 'conventional'},
#   'God Eater'),
#  ({'first_keyword': 'world',
#    'second_keyword': 'islands',
#    'third_keyword': 'float'},
#   'GRANBLUE FANTASY the Animation'),
#  ({'first_keyword': 'strong,',
#    'second_keyword': 'whip-smart',
#    'third_keyword': 'grizzy'},
#   'Grizzy et les Lemmings'),
#  ({'first_keyword': 'charming',
#    'second_keyword': 'hitman',
#    'third_keyword': 'questions'},
#   'Love Shot'),
#  ({'first_keyword': 'paris-based',
#    'second_keyword': 'writer',
#    'third_keyword': 'aids'},
#   'Plaire, aimer et courir vite'),
#  ({'first_keyword': 'crash-landing',
#    'second_keyword': 'earth,',
#    'third_keyword': 'two'},
#   '3Below: Tales of Arcadia'),
#  ({'first_keyword': 'hoping',
#    'second_keyword': 'reunite',
#    'third_keyword': 'dying'},
#   '4L'),
#  ({'first_keyword': 'despite',
#    'second_keyword': 'social',
#    'third_keyword': 'backlash'},
#   'Age Gap Love'),
#  ({'first_keyword': 'celebrity',
#    'second_keyword': 'chef',
#    'third_keyword': 'ainsley'},
#   'Ainsley Eats the Streets'),
#  ({'first_keyword': 'low-income',
#    'second_keyword': 'families',
#    'third_keyword': 'move'},
#   'Black & Privileged: Volume 1'),
#  ({'first_keyword': 'ten',
#    'second_keyword': 'master',
#    'third_keyword': 'artists'},
#   'Blown Away'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'couple,',
#    'third_keyword': 'exes'},
#   'Bonus Family'),
#  ({'first_keyword': 'dystopian',
#    'second_keyword': 'tale',
#    'third_keyword': 'unfolding'},
#   'Cities of Last Things'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'series',
#    'third_keyword': 'tries'},
#   'Encounters with Evil'),
#  ({'first_keyword': 'engaged',
#    'second_keyword': 'couple',
#    'third_keyword': 'travels'},
#   'Extreme Engagement'),
#  ({'first_keyword': 'using',
#    'second_keyword': 'previously',
#    'third_keyword': 'unseen'},
#   "History's Greatest Hoaxes"),
#  ({'first_keyword': 'snatched',
#    'second_keyword': 'street',
#    'third_keyword': 'held'},
#   'Kidnapping Stella'),
#  ({'first_keyword': 'series',
#    'second_keyword': 'dramatizes',
#    'third_keyword': 'life'},
#   'Luis Miguel - The Series'),
#  ({'first_keyword': 'visiting',
#    'second_keyword': 'busiest',
#    'third_keyword': 'kitchens'},
#   'Mega Food'),
#  ({'first_keyword': 'reality',
#    'second_keyword': 'ride-along',
#    'third_keyword': 'offers'},
#   'MegaTruckers'),
#  ({'first_keyword': 'aided',
#    'second_keyword': 'designers',
#    'third_keyword': 'craftspeople,'},
#   'Money for Nothing'),
#  ({'first_keyword': 'ongoing',
#    'second_keyword': 'housing',
#    'third_keyword': 'crisis'},
#   'Nightmare Tenants, Slum Landlords'),
#  ({'first_keyword': 'lee',
#    'second_keyword': 'jeong-in',
#    'third_keyword': 'yu'},
#   'One Spring Night'),
#  ({'first_keyword': 'turmoil',
#    'second_keyword': 'looms',
#    'third_keyword': 'martial'},
#   'PILI Fantasy: War of Dragons'),
#  ({'first_keyword': 'save',
#    'second_keyword': 'pregnant',
#    'third_keyword': 'wife,'},
#   'Point Blank'),
#  ({'first_keyword': 'unexpected',
#    'second_keyword': 'romance',
#    'third_keyword': 'surprise'},
#   'Smart People'),
#  ({'first_keyword': 'many',
#    'second_keyword': 'popular',
#    'third_keyword': 'taco'},
#   'Taco Chronicles'),
#  ({'first_keyword': 'farmers,',
#    'second_keyword': 'scientists',
#    'third_keyword': 'industry'},
#   'The Milk System'),
#  ({'first_keyword': 'true',
#    'second_keyword': 'friends',
#    'third_keyword': 'dropping'},
#   'True Tunes'),
#  ({'first_keyword': 'brave,',
#    'second_keyword': 'energetic',
#    'third_keyword': 'little'},
#   'Chhota Bheem'),
#  ({'first_keyword': 'mckellan',
#    'second_keyword': 'family',
#    'third_keyword': 'moves'},
#   'Family Reunion'),
#  ({'first_keyword': 'little',
#    'second_keyword': "singham's",
#    'third_keyword': 'sidekick'},
#   'Little Singham Bandarpur Mein Hu Ha Hu'),
#  ({'first_keyword': "spotlight's",
#    'second_keyword': 'parchís,',
#    'third_keyword': 'record'},
#   'Parchís: the Documentary'),
#  ({'first_keyword': 'comedy',
#    'second_keyword': 'special',
#    'third_keyword': 'directed'},
#   'Aziz Ansari: RIGHT NOW'),
#  ({'first_keyword': '1930s',
#    'second_keyword': 'london,',
#    'third_keyword': 'michael'},
#   'Mary Poppins Returns'),
#  ({'first_keyword': 'playing',
#    'second_keyword': 'pranks',
#    'third_keyword': 'destroying'},
#   'Krishna Balram'),
#  ({'first_keyword': 'margaret',
#    'second_keyword': 'thatcher,',
#    'third_keyword': 'first'},
#   'The Iron Lady'),
#  ({'first_keyword': '15-year-old',
#    'second_keyword': 'la',
#    'third_keyword': 'spends'},
#   'Free Rein'),
#  ({'first_keyword': 'officials',
#    'second_keyword': 'slow',
#    'third_keyword': 'investigate'},
#   'Sicilian Ghost Story'),
#  ({'first_keyword': 'blind',
#    'second_keyword': 'woman',
#    'third_keyword': 'vices'},
#   'In The Dark'),
#  ({'first_keyword': 'experience',
#    'second_keyword': 'highlights',
#    'third_keyword': 'argentine'},
#   'River, el más grande siempre'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'take',
#    'third_keyword': 'classic'},
#   'The Legend of White Snake'),
#  ({'first_keyword': 'short',
#    'second_keyword': 'documentary,',
#    'third_keyword': '37-year-old'},
#   'Cristina'),
#  ({'first_keyword': 'yumeko',
#    'second_keyword': 'jabami',
#    'third_keyword': 'enrolls'},
#   'Kakegurui'),
#  ({'first_keyword': 'capture',
#    'second_keyword': 'crime',
#    'third_keyword': 'lord'},
#   'Skiptrace'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'boy',
#    'third_keyword': 'vanishes,'},
#   'Stranger Things'),
#  ({'first_keyword': 'social',
#    'second_keyword': 'upheaval',
#    'third_keyword': 'sweeps'},
#   'The Last Czars'),
#  ({'first_keyword': 'drama',
#    'second_keyword': 'expectant',
#    'third_keyword': 'mothers'},
#   'Yummy Mummies'),
#  ({'first_keyword': 'kind',
#    'second_keyword': 'computer',
#    'third_keyword': 'repairman'},
#   'Bangkok Love Stories: Objects of Affection'),
#  ({'first_keyword': "bangkok's",
#    'second_keyword': 'chinatown,',
#    'third_keyword': 'spirited'},
#   'Bangkok Love Stories: Plead'),
#  ({'first_keyword': 'national',
#    'second_keyword': 'assembly',
#    'third_keyword': 'suffers'},
#   'Designated Survivor: 60 Days'),
#  ({'first_keyword': 'raising',
#    'second_keyword': 'daughter',
#    'third_keyword': 'small'},
#   'Good Witch'),
#  ({'first_keyword': 'widowed',
#    'second_keyword': 'singer',
#    'third_keyword': 'single'},
#   "Alice Doesn't Live Here Anymore"),
#  ({'first_keyword': 'pair',
#    'second_keyword': 'adventures,',
#    'third_keyword': 'po'},
#   'DreamWorks Kung Fu Panda Awesome Secrets'),
#  ({'first_keyword': 'ordinary',
#    'second_keyword': 'student,',
#    'third_keyword': 'forms'},
#   'Flowering Heart'),
#  ({'first_keyword': 'mohawk',
#    'second_keyword': 'reservation',
#    'third_keyword': 'canadian'},
#   'Frozen River'),
#  ({'first_keyword': 'fun-loving',
#    'second_keyword': 'creatures',
#    'third_keyword': 'hatch'},
#   'Hatchimals | Adventures in Hatchtopia'),
#  ({'first_keyword': 'unbeknownst',
#    'second_keyword': '12-year-old',
#    'third_keyword': 'daughter,'},
#   'Inkheart'),
#  ({'first_keyword': 'mixing',
#    'second_keyword': 'dramatic',
#    'third_keyword': 're-enactments'},
#   'Inside the Mind of a Serial Killer'),
#  ({'first_keyword': 'fresh',
#    'second_keyword': 'tour,',
#    'third_keyword': 'comedian'},
#   'Katherine Ryan: Glitter Room'),
#  ({'first_keyword': 'true',
#    'second_keyword': 'crime',
#    'third_keyword': 'tale'},
#   'Kill the Irishman'),
#  ({'first_keyword': 'apartment',
#    'second_keyword': 'building',
#    'third_keyword': 'manager'},
#   'Lady in the Water'),
#  ({'first_keyword': 'brian',
#    'second_keyword': 'knows',
#    'third_keyword': 'creatures'},
#   'Little Monsters'),
#  ({'first_keyword': 'desperate',
#    'second_keyword': 'start',
#    'third_keyword': 'new'},
#   'Mean Dreams'),
#  ({'first_keyword': 'new',
#    'second_keyword': "york's",
#    'third_keyword': 'little'},
#   'Mean Streets'),
#  ({'first_keyword': 'imaginative,',
#    'second_keyword': 'big-hearted',
#    'third_keyword': 'bunny'},
#   'Molang'),
#  ({'first_keyword': 'las',
#    'second_keyword': 'vegas',
#    'third_keyword': 'magician'},
#   'Next'),
#  ({'first_keyword': 'hurricane',
#    'second_keyword': 'hits',
#    'third_keyword': 'coastal'},
#   'Nights in Rodanthe'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'test',
#    'third_keyword': 'avian'},
#   'NOVA: Bird Brain'),
#  ({'first_keyword': 'astrophysicists',
#    'second_keyword': 'show',
#    'third_keyword': 'black'},
#   'NOVA: Black Hole Apocalypse'),
#  ({'first_keyword': 'thirty',
#    'second_keyword': 'years',
#    'third_keyword': 'chernobyl’s'},
#   "NOVA: Building Chernobyl's MegaTomb"),
#  ({'first_keyword': 'chariot',
#    'second_keyword': 'dominated',
#    'third_keyword': 'chinese'},
#   'NOVA: Chinese Chariot Revealed'),
#  ({'first_keyword': 'drilling',
#    'second_keyword': 'impact',
#    'third_keyword': 'crater'},
#   'NOVA: Day the Dinosaurs Died'),
#  ({'first_keyword': 'decades',
#    'second_keyword': 'amazing',
#    'third_keyword': 'discoveries,'},
#   'NOVA: Death Dive to Saturn'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'investigate',
#    'third_keyword': 'earth’s'},
#   'NOVA: Decoding the Weather Machine'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'reveal',
#    'third_keyword': '2017'},
#   'NOVA: Eclipse Over America'),
#  ({'first_keyword': 'huge',
#    'second_keyword': 'tusks',
#    'third_keyword': 'giant'},
#   'NOVA: Extreme Animal Weapons'),
#  ({'first_keyword': 'risky',
#    'second_keyword': 'expeditions',
#    'third_keyword': 'underwater'},
#   'NOVA: First Face of America'),
#  ({'first_keyword': 'former',
#    'second_keyword': 'nazi',
#    'third_keyword': 'execution'},
#   'NOVA: Holocaust Escape Tunnel'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'search',
#    'third_keyword': 'evidence'},
#   'NOVA: Killer Floods'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'research',
#    'third_keyword': 'world’s'},
#   'NOVA: Killer Hurricanes'),
#  ({'first_keyword': 'evidence',
#    'second_keyword': 'mysterious',
#    'third_keyword': 'medieval'},
#   'NOVA: Killer Volcanoes'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'details',
#    'third_keyword': 'water'},
#   'NOVA: Poisoned Water'),
#  ({'first_keyword': 'science',
#    'second_keyword': 'forecasting',
#    'third_keyword': 'flourishing,'},
#   'NOVA: Prediction by the Numbers'),
#  ({'first_keyword': 'master',
#    'second_keyword': 'armorer',
#    'third_keyword': 'team'},
#   'NOVA: Secrets of the Shining Knight'),
#  ({'first_keyword': 'international',
#    'second_keyword': 'team',
#    'third_keyword': 'rescue'},
#   'NOVA: Thai Cave Rescue'),
#  ...]

# %%
#Shuffling my sets
random.shuffle(featuresets)

# %%
# Working out the 80% of my data

print(f'Features length:  {len(featuresets)}')
split_num = math.floor(len(featuresets)*.8)
print(f'80% split number:  {split_num}')

# split feature sets into training and test sets (here we'll try 80% train, 20% test)
train_set, test_set = featuresets[:split_num], featuresets[split_num+1:]
# Out:
# Features length:  5837
# 80% split number:  4669

# %%
# Printing training set
train_set
# Out:
# [({'first_keyword': 'longtime',
#    'second_keyword': 'mayor',
#    'third_keyword': 'marseille'},
#   'Marseille'),
#  ({'first_keyword': 'middle',
#    'second_keyword': 'schooler',
#    'third_keyword': 'valt'},
#   'Beyblade Burst'),
#  ({'first_keyword': 'old-school',
#    'second_keyword': 'brooklyn',
#    'third_keyword': 'native'},
#   "It's Bruno!"),
#  ({'first_keyword': 'join',
#    'second_keyword': 'historian',
#    'third_keyword': 'dan'},
#   'Secrets of Great British Castles'),
#  ({'first_keyword': 'teens',
#    'second_keyword': 'korean',
#    'third_keyword': 'descent'},
#   'Seoul Searching'),
#  ({'first_keyword': 'obsessed',
#    'second_keyword': 'aspiring',
#    'third_keyword': 'writer,'},
#   'You'),
#  ({'first_keyword': 'intimate',
#    'second_keyword': 'lives',
#    'third_keyword': 'young'},
#   'Hong Kong West Side Stories'),
#  ({'first_keyword': 'future',
#    'second_keyword': 'technology',
#    'third_keyword': 'rendered'},
#   'Anon'),
#  ({'first_keyword': 'successful',
#    'second_keyword': "dj's",
#    'third_keyword': 'bachelor'},
#   'Love Rhythms - Accidental Daddy'),
#  ({'first_keyword': 'kath',
#    'second_keyword': 'prepares',
#    'third_keyword': 'wed'},
#   'Kath and Kim'),
#  ({'first_keyword': 'doubting',
#    'second_keyword': 'future',
#    'third_keyword': 'nun,'},
#   'Tatu'),
#  ({'first_keyword': 'spanning',
#    'second_keyword': '30',
#    'third_keyword': 'years,'},
#   'Together'),
#  ({'first_keyword': 'wide-ranging',
#    'second_keyword': 'documentary',
#    'third_keyword': 'examines'},
#   'What Makes a Psychopath?'),
#  ({'first_keyword': 'team',
#    'second_keyword': 'minstrels,',
#    'third_keyword': 'including'},
#   'Krish Trish and Baltiboy'),
#  ({'first_keyword': 'special',
#    'second_keyword': 'packed',
#    'third_keyword': 'stealthy'},
#   'Hannibal Buress: Comedy Camisado'),
#  ({'first_keyword': 'perfectionist',
#    'second_keyword': 'ad',
#    'third_keyword': 'exec'},
#   'Nappily Ever After'),
#  ({'first_keyword': 'suzu',
#    'second_keyword': 'marries',
#    'third_keyword': 'family'},
#   'In This Corner of the World'),
#  ({'first_keyword': 'sly', 'second_keyword': 'art', 'third_keyword': 'dealer'},
#   'Mi Obra Maestra'),
#  ({'first_keyword': 'rushing',
#    'second_keyword': 'pay',
#    'third_keyword': 'loan'},
#   'Watchman'),
#  ({'first_keyword': 'boozy',
#    'second_keyword': 'ex-cop',
#    'third_keyword': 'turned'},
#   'Happy!'),
#  ({'first_keyword': 'computer-science',
#    'second_keyword': 'major',
#    'third_keyword': 'gets'},
#   'Love O2O'),
#  ({'first_keyword': 'small-town',
#    'second_keyword': 'louisiana',
#    'third_keyword': 'minister'},
#   'Burning Cane'),
#  ({'first_keyword': 'displaced',
#    'second_keyword': 'hurricane',
#    'third_keyword': 'maria,'},
#   'After Maria'),
#  ({'first_keyword': 'aurelio',
#    'second_keyword': 'casillas',
#    'third_keyword': 'can'},
#   'El señor de los Cielos'),
#  ({'first_keyword': 'first', 'second_keyword': 'day', 'third_keyword': 'camp'},
#   'Wet Hot American Summer'),
#  ({'first_keyword': 'kind',
#    'second_keyword': 'computer',
#    'third_keyword': 'repairman'},
#   'Bangkok Love Stories: Objects of Affection'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'man',
#    'third_keyword': 'foster'},
#   'VS.'),
#  ({'first_keyword': 'pedro',
#    'second_keyword': 'marries',
#    'third_keyword': 'sister,'},
#   'Like Water for Chocolate'),
#  ({'first_keyword': 'saved',
#    'second_keyword': 'plane',
#    'third_keyword': 'crash'},
#   "Edgar Rice Burroughs' Tarzan and Jane"),
#  ({'first_keyword': 'furor',
#    'second_keyword': 'addition',
#    'third_keyword': 'two'},
#   'Forever Pure'),
#  ({'first_keyword': 'welcome',
#    'second_keyword': 'irreverent',
#    'third_keyword': 'world'},
#   "Slobby's World"),
#  ({'first_keyword': 'six',
#    'second_keyword': 'intimate',
#    'third_keyword': 'stories'},
#   'Dogs'),
#  ({'first_keyword': 'four',
#    'second_keyword': 'friends',
#    'third_keyword': 'become'},
#   'Loaded'),
#  ({'first_keyword': 'eager',
#    'second_keyword': 'cash,',
#    'third_keyword': 'rajesh'},
#   'Laal Rang'),
#  ({'first_keyword': 'late-night',
#    'second_keyword': 'talk',
#    'third_keyword': 'show'},
#   'Conan Without Borders'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'wealthy',
#    'third_keyword': 'businessmen'},
#   'Intersection'),
#  ({'first_keyword': 'virtual',
#    'second_keyword': 'real',
#    'third_keyword': 'worlds'},
#   'The Underwear'),
#  ({'first_keyword': 'heyday',
#    'second_keyword': 'curtain',
#    'third_keyword': 'call,'},
#   'Monty Python: The Meaning of Live'),
#  ({'first_keyword': 'upon',
#    'second_keyword': 'returning',
#    'third_keyword': 'industrial'},
#   'Udaan'),
#  ({'first_keyword': 'needing',
#    'second_keyword': 'hard',
#    'third_keyword': 'evidence'},
#   'Master'),
#  ({'first_keyword': 'players,',
#    'second_keyword': 'fans',
#    'third_keyword': 'staff'},
#   'Boca Juniors Confidential'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'dancer',
#    'third_keyword': 'accompanies'},
#   'Bogda'),
#  ({'first_keyword': 'self-serving',
#    'second_keyword': 'mythical',
#    'third_keyword': "creature's"},
#   'A Korean Odyssey'),
#  ({'first_keyword': 'adopted',
#    'second_keyword': 'human',
#    'third_keyword': 'rights'},
#   'Black Earth Rising'),
#  ({'first_keyword': 'lorena',
#    'second_keyword': 'ramírez',
#    'third_keyword': "mexico's"},
#   'Lorena, Light-Footed Woman'),
#  ({'first_keyword': 'six',
#    'second_keyword': 'young',
#    'third_keyword': 'women,'},
#   'Waterschool'),
#  ({'first_keyword': 'loyal',
#    'second_keyword': 'sister',
#    'third_keyword': 'struggles'},
#   '6 Balloons'),
#  ({'first_keyword': 'set',
#    'second_keyword': 'chaotic',
#    'third_keyword': 'future,'},
#   'The Rover'),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'eight-time',
#    'third_keyword': 'nba'},
#   'The Carter Effect'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'indonesian',
#    'third_keyword': 'women'},
#   '3 Heroines'),
#  ({'first_keyword': 'teenage',
#    'second_keyword': 'daughter',
#    'third_keyword': 'goes'},
#   'Safe'),
#  ({'first_keyword': 'passionate',
#    'second_keyword': 'love',
#    'third_keyword': 'alien'},
#   'Star-Crossed'),
#  ({'first_keyword': 'young',
#    'second_keyword': "woman's",
#    'third_keyword': 'romantic'},
#   "You're My Destiny"),
#  ({'first_keyword': 'magi',
#    'second_keyword': 'became',
#    'third_keyword': 'high'},
#   'Magi: Adventure of Sinbad'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'comedians',
#    'third_keyword': 'launch'},
#   'Ha Unlimited'),
#  ({'first_keyword': 'iconic',
#    'second_keyword': 'rocker',
#    'third_keyword': 'john'},
#   'John Mellencamp: Plain Spoken'),
#  ({'first_keyword': 'overtaken',
#    'second_keyword': 'death',
#    'third_keyword': 'beloved,'},
#   'Another Forever'),
#  ({'first_keyword': 'british',
#    'second_keyword': 'comedian',
#    'third_keyword': 'jimmy'},
#   'Jimmy Carr: Funny Business'),
#  ({'first_keyword': 'betrayed',
#    'second_keyword': 'loan',
#    'third_keyword': 'shark'},
#   'Avengement'),
#  ({'first_keyword': 'losing',
#    'second_keyword': 'mother,',
#    'third_keyword': 'teenage'},
#   'A.M.I.'),
#  ({'first_keyword': 'millions',
#    'second_keyword': 'people',
#    'third_keyword': 'earth'},
#   'Left Behind'),
#  ({'first_keyword': 'returned',
#    'second_keyword': 'home',
#    'third_keyword': 'cagey'},
#   'The Daughter'),
#  ({'first_keyword': 'years',
#    'second_keyword': 'getting',
#    'third_keyword': 'girlfriend'},
#   'Champions'),
#  ({'first_keyword': 'luxurious',
#    'second_keyword': 'condominium',
#    'third_keyword': 'complex'},
#   'Singles Villa'),
#  ({'first_keyword': 'discovering',
#    'second_keyword': 'secret',
#    'third_keyword': 'military'},
#   'Black Site Delta'),
#  ({'first_keyword': 'newly',
#    'second_keyword': 'single',
#    'third_keyword': 'photographer'},
#   'Loving is Losing'),
#  ({'first_keyword': 'nine',
#    'second_keyword': 'continents',
#    'third_keyword': 'face'},
#   'Once Upon A Time In Lingjian Mountain'),
#  ({'first_keyword': 'igor,',
#    'second_keyword': 'brilliant',
#    'third_keyword': 'deformed'},
#   'Igor'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'pays',
#    'third_keyword': 'tribute'},
#   'Los Niños Héroes de Chapultepec'),
#  ({'first_keyword': 'humdrum',
#    'second_keyword': 'academic',
#    'third_keyword': 'spots'},
#   'Enemy'),
#  ({'first_keyword': 'lalaloopsy',
#    'second_keyword': 'gang',
#    'third_keyword': 'adorable'},
#   "We're Lalaloopsy"),
#  ({'first_keyword': 'repeatedly',
#    'second_keyword': 'opposite',
#    'third_keyword': 'sides'},
#   'Justice in the City'),
#  ({'first_keyword': 'evade',
#    'second_keyword': 'greedy',
#    'third_keyword': 'pharmaceutical'},
#   'Used Goods'),
#  ({'first_keyword': 'made-for-tv',
#    'second_keyword': 'drama',
#    'third_keyword': 'chronicles'},
#   'Lizzie Borden Took an Ax'),
#  ({'first_keyword': 'robo',
#    'second_keyword': 'knight',
#    'third_keyword': 'learns'},
#   'Power Rangers: Megaforce: The Robo Knight Before Christmas'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'turkish',
#    'third_keyword': 'agents'},
#   'Act of Vengeance'),
#  ({'first_keyword': 'vivid',
#    'second_keyword': 'imagination,',
#    'third_keyword': 'simon'},
#   'Simon'),
#  ({'first_keyword': 'back',
#    'second_keyword': 'childhood',
#    'third_keyword': 'home'},
#   'The Influence'),
#  ({'first_keyword': 'singer-songwriter',
#    'second_keyword': 'gen',
#    'third_keyword': 'hoshino'},
#   'GEN HOSHINO STADIUM TOUR “POP VIRUS”'),
#  ({'first_keyword': 'team',
#    'second_keyword': 'launches',
#    'third_keyword': 'new'},
#   'Power Rangers Time Force'),
#  ({'first_keyword': "nate's",
#    'second_keyword': 'special',
#    'third_keyword': 'yo-kai'},
#   'Yo-Kai Watch: The Movie'),
#  ({'first_keyword': 'bill',
#    'second_keyword': 'burr',
#    'third_keyword': 'escapes'},
#   "Bill Burr: I'm Sorry You Feel That Way"),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'follows',
#    'third_keyword': 'police'},
#   'The Force'),
#  ({'first_keyword': 'jealous,',
#    'second_keyword': 'possessive',
#    'third_keyword': 'mother'},
#   'Matichya Chuli'),
#  ({'first_keyword': 'film',
#    'second_keyword': 'television',
#    'third_keyword': 'star'},
#   'Kevin James: Sweat the Small Stuff'),
#  ({'first_keyword': "draculaura's",
#    'second_keyword': 'ghoulfriends',
#    'third_keyword': 'suspicions'},
#   'Monster High: Why Do Ghouls Fall in Love?'),
#  ({'first_keyword': 'king',
#    'second_keyword': 'jungle',
#    'third_keyword': 'ascend'},
#   'Tarzan 2'),
#  ({'first_keyword': 'new-generation',
#    'second_keyword': 'bodybuilding',
#    'third_keyword': 'stars'},
#   'Generation Iron 2'),
#  ({'first_keyword': 'sound',
#    'second_keyword': 'director',
#    'third_keyword': 'suddenly'},
#   'Another Miss Oh'),
#  ({'first_keyword': 'disguised',
#    'second_keyword': 'bodyguard,',
#    'third_keyword': 'special'},
#   'Man to Man'),
#  ({'first_keyword': 'gale',
#    'second_keyword': 'written',
#    'third_keyword': 'best-seller'},
#   'Scream 2'),
#  ({'first_keyword': 'armed',
#    'second_keyword': 'boyish',
#    'third_keyword': 'charm'},
#   'John Mulaney: The Comeback Kid'),
#  ({'first_keyword': 'catalán',
#    'second_keyword': 'prisoner',
#    'third_keyword': 'nazi'},
#   'The Photographer Of Mauthausen'),
#  ({'first_keyword': 'teenager',
#    'second_keyword': 'discovers',
#    'third_keyword': 'really'},
#   'Monster Island'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'grueling',
#    'third_keyword': 'training'},
#   'Froning: The Fittest Man in History'),
#  ({'first_keyword': 'epicureans',
#    'second_keyword': 'experts',
#    'third_keyword': 'trace'},
#   'Food on the Go'),
#  ({'first_keyword': 'unbridled',
#    'second_keyword': 'comic',
#    'third_keyword': 'chris'},
#   "Chris D'Elia: Man on Fire"),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'dissects',
#    'third_keyword': 'case'},
#   'A Gray State'),
#  ({'first_keyword': 'surgeon',
#    'second_keyword': 'claims',
#    'third_keyword': 'remove'},
#   'Patient Seventeen'),
#  ({'first_keyword': 'billionaire',
#    'second_keyword': 'sets',
#    'third_keyword': 'take'},
#   'G-Force'),
#  ({'first_keyword': '32-year-old',
#    'second_keyword': 'romantic',
#    'third_keyword': 'looking'},
#   'What Is Love?'),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'boys',
#    'third_keyword': "johnny's"},
#   'Blazing Transfer Students'),
#  ({'first_keyword': '1981,',
#    'second_keyword': 'imprisoned',
#    'third_keyword': 'irish'},
#   'Bobby Sands: 66 Days'),
#  ({'first_keyword': 'spy',
#    'second_keyword': 'kids',
#    'third_keyword': 'carmen'},
#   'Spy Kids 2: The Island of Lost Dreams'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'nefarious',
#    'third_keyword': 'schemes'},
#   'Nowhere Man'),
#  ({'first_keyword': 'gripping',
#    'second_keyword': 'profile',
#    'third_keyword': 'ben'},
#   'Prosecuting Evil: The Extraordinary World of Ben Ferencz'),
#  ({'first_keyword': "everyone's",
#    'second_keyword': 'favorite',
#    'third_keyword': 'teenage'},
#   'Ninja Turtles: The Next Mutation'),
#  ({'first_keyword': 'r.l.',
#    'second_keyword': "stine's",
#    'third_keyword': 'tales'},
#   'Goosebumps'),
#  ({'first_keyword': 'two-part',
#    'second_keyword': 'tale',
#    'third_keyword': 'delivers'},
#   'The Great Train Robbery'),
#  ({'first_keyword': 'swanky',
#    'second_keyword': 'cruise',
#    'third_keyword': 'veers'},
#   'Monster High: Escape from Skull Shores'),
#  ({'first_keyword': 'undercover',
#    'second_keyword': 'agents',
#    'third_keyword': 'open'},
#   'The Red Sea Diving Resort'),
#  ({'first_keyword': 'fights',
#    'second_keyword': 'tide',
#    'third_keyword': 'violence'},
#   'The Death and Life of Marsha P. Johnson'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'woman',
#    'third_keyword': 'returns'},
#   'Kopitiam'),
#  ({'first_keyword': 'newly',
#    'second_keyword': 'released',
#    'third_keyword': 'kgb'},
#   'Auschwitz: Blueprints of Genocide'),
#  ({'first_keyword': 'epic',
#    'second_keyword': 'documentary,',
#    'third_keyword': 'last-surviving'},
#   'Spitfire: The Plane that Saved the World'),
#  ({'first_keyword': 'two', 'second_keyword': 'years', 'third_keyword': 'hit'},
#   'Ali Wong: Hard Knock Wife'),
#  ({'first_keyword': 'stylish',
#    'second_keyword': 'mix',
#    'third_keyword': 'documentary'},
#   'Roman Empire: Reign of Blood'),
#  ({'first_keyword': 'kath',
#    'second_keyword': "kel's",
#    'third_keyword': 'union'},
#   'Da Kath & Kim Code'),
#  ({'first_keyword': 'shy',
#    'second_keyword': 'natsu',
#    'third_keyword': 'awakens'},
#   '7SEEDS'),
#  ({'first_keyword': 'set', 'second_keyword': 'grey', 'third_keyword': 'city,'},
#   'Berlin, I Love You'),
#  ({'first_keyword': '13',
#    'second_keyword': 'years,',
#    'third_keyword': 'underground'},
#   'The NSU-Complex'),
#  ({'first_keyword': 'fed',
#    'second_keyword': 'dating',
#    'third_keyword': 'debt,'},
#   'The New Romantic'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'chronicles',
#    'third_keyword': 'johnny'},
#   'ReMastered: Tricky Dick & The Man in Black'),
#  ({'first_keyword': 'spirited',
#    'second_keyword': '22-year-old',
#    'third_keyword': 'activist'},
#   'The Journey Is the Destination'),
#  ({'first_keyword': 'evening',
#    'second_keyword': 'apart,',
#    'third_keyword': 'married'},
#   'Last Night'),
#  ({'first_keyword': 'superman',
#    'second_keyword': 'returns',
#    'third_keyword': 'metropolis,'},
#   'Superman Returns'),
#  ({'first_keyword': 'polished',
#    'second_keyword': 'fbi',
#    'third_keyword': 'agent'},
#   'Battle Creek'),
#  ({'first_keyword': 'google',
#    'second_keyword': 'executive',
#    'third_keyword': 'boldly'},
#   '14 Minutes from Earth'),
#  ({'first_keyword': 'cerebral',
#    'second_keyword': 'popular',
#    'third_keyword': 'german'},
#   'Dieter Nuhr: Nuhr in Berlin'),
#  ({'first_keyword': 'jailhouse',
#    'second_keyword': 'interview,',
#    'third_keyword': 'arthur'},
#   'Interview with a Serial Killer'),
#  ({'first_keyword': 'docuseries',
#    'second_keyword': 'examines',
#    'third_keyword': 'decades-old'},
#   'The Keepers'),
#  ({'first_keyword': 'middle-aged',
#    'second_keyword': 'filmmaker',
#    'third_keyword': 'meets'},
#   'X: Past Is Present'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'small',
#    'third_keyword': 'abominable'},
#   'Abominable Christmas'),
#  ({'first_keyword': 'finding',
#    'second_keyword': 'desperate',
#    'third_keyword': 'situation,'},
#   'Beauty and the Bestie'),
#  ({'first_keyword': 'still',
#    'second_keyword': 'desperate',
#    'third_keyword': 'find'},
#   'TE3N'),
#  ({'first_keyword': 'given',
#    'second_keyword': 'just',
#    'third_keyword': 'seven'},
#   '7 Din Mohabbat In'),
#  ({'first_keyword': 'high',
#    'second_keyword': 'schooler',
#    'third_keyword': 'yuta'},
#   'Love, Chunibyo & Other Delusions!'),
#  ({'first_keyword': 'family',
#    'second_keyword': 'parsi',
#    'third_keyword': 'musicians'},
#   'The Human Factor: The Untold Story of the Bombay Film Orchestras'),
#  ({'first_keyword': 'rejected',
#    'second_keyword': 'marines',
#    'third_keyword': 'eager'},
#   'Sun Dogs'),
#  ({'first_keyword': 'dev',
#    'second_keyword': 'tries',
#    'third_keyword': 'jump-start'},
#   'Master of None'),
#  ({'first_keyword': 'lives',
#    'second_keyword': 'mumbai',
#    'third_keyword': 'man'},
#   'One by Two'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'woman',
#    'third_keyword': 'amnesia'},
#   'Tabula Rasa'),
#  ({'first_keyword': 'drivers',
#    'second_keyword': 'exotic',
#    'third_keyword': 'supercars'},
#   'Fastest Car'),
#  ({'first_keyword': 'director',
#    'second_keyword': 'comedian',
#    'third_keyword': 'want'},
#   'Something Huge'),
#  ({'first_keyword': 'journalist',
#    'second_keyword': 'naresh',
#    'third_keyword': 'hired'},
#   'Elaan'),
#  ({'first_keyword': 'ex-con',
#    'second_keyword': 'joris',
#    'third_keyword': 'returns'},
#   'Station Horizon'),
#  ({'first_keyword': 'shunned',
#    'second_keyword': 'country',
#    'third_keyword': 'due'},
#   'Salam - The First ****** Nobel Laureate'),
#  ({'first_keyword': 'dishonorably',
#    'second_keyword': 'discharged',
#    'third_keyword': 'navy'},
#   'W/ Bob & David'),
#  ({'first_keyword': 'disowned',
#    'second_keyword': 'father',
#    'third_keyword': 'boy,'},
#   'Boss'),
#  ({'first_keyword': 'animosity',
#    'second_keyword': 'gives',
#    'third_keyword': 'way'},
#   'Temporada de Caza'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'retraces',
#    'third_keyword': 'footsteps'},
#   'Le serment des Hitler'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'leaps',
#    'third_keyword': 'page'},
#   'My Dear Warrior'),
#  ({'first_keyword': 'college',
#    'second_keyword': 'girl',
#    'third_keyword': 'romping'},
#   'White Girl'),
#  ({'first_keyword': "man's",
#    'second_keyword': 'drunken',
#    'third_keyword': 'romp'},
#   'Pottersville'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'lonely',
#    'third_keyword': 'singles'},
#   'Yours Fatefully'),
#  ({'first_keyword': "something's",
#    'second_keyword': 'wrong',
#    'third_keyword': 'rainbow'},
#   'True and the Rainbow Kingdom'),
#  ({'first_keyword': 'mysterious',
#    'second_keyword': '"time',
#    'third_keyword': 'master"'},
#   "DC's Legends of Tomorrow"),
#  ({'first_keyword': 'take',
#    'second_keyword': 'control',
#    'third_keyword': 'adventure'},
#   'Minecraft: Story Mode'),
#  ({'first_keyword': 'raised',
#    'second_keyword': 'kindly',
#    'third_keyword': 'thief,'},
#   'Aashik Awara'),
#  ({'first_keyword': 'captain',
#    'second_keyword': 'pleasant',
#    'third_keyword': 'cruise'},
#   'The Cruise'),
#  ({'first_keyword': 'soft-spoken',
#    'second_keyword': 'jai',
#    'third_keyword': 'spitfire'},
#   'Jaane Tu... Ya Jaane Na'),
#  ({'first_keyword': 'witty',
#    'second_keyword': 'solo',
#    'third_keyword': 'show,'},
#   "I'm Brent Morin"),
#  ({'first_keyword': 'star',
#    'second_keyword': 'player',
#    'third_keyword': 'dies'},
#   'The Last Whistle'),
#  ({'first_keyword': 'tragic',
#    'second_keyword': 'accident',
#    'third_keyword': 'drives'},
#   'Super Dark Times'),
#  ({'first_keyword': 'zombies',
#    'second_keyword': 'monsters',
#    'third_keyword': 'invade'},
#   'The Last Kids on Earth'),
#  ({'first_keyword': 'journeying',
#    'second_keyword': 'back',
#    'third_keyword': 'small'},
#   'Everybody Knows'),
#  ({'first_keyword': '2006',
#    'second_keyword': 'show,',
#    'third_keyword': 'comic'},
#   'Katt Williams: The Pimp Chronicles: Pt. 1'),
#  ({'first_keyword': 'cameras',
#    'second_keyword': 'follow',
#    'third_keyword': 'police'},
#   'Under Arrest'),
#  ({'first_keyword': 'chhota',
#    'second_keyword': 'bheem',
#    'third_keyword': 'china'},
#   'Chhota Bheem Kungfu Dhamaka'),
#  ({'first_keyword': 'k-pop',
#    'second_keyword': 'star',
#    'third_keyword': 'seungri,'},
#   'YG Future Strategy Office'),
#  ({'first_keyword': 'years',
#    'second_keyword': 'surviving',
#    'third_keyword': 'brutal'},
#   'Dark Places'),
#  ({'first_keyword': 'haunted',
#    'second_keyword': 'terrifying',
#    'third_keyword': 'visions,'},
#   'Munafik 2'),
#  ({'first_keyword': 'condemned',
#    'second_keyword': 'centuries-old',
#    'third_keyword': 'vow'},
#   'Blood & Treasures'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'childhood',
#    'third_keyword': 'friends'},
#   'Raiders!: The Story of the Greatest Fan Film Ever Made'),
#  ({'first_keyword': 'nick',
#    'second_keyword': 'wallis',
#    'third_keyword': 'presents'},
#   'Caught on Camera'),
#  ({'first_keyword': 'commitment-phobe',
#    'second_keyword': 'agrees',
#    'third_keyword': 'marry'},
#   'Pyaar Ke Side Effects'),
#  ({'first_keyword': 'hoping',
#    'second_keyword': 'earn',
#    'third_keyword': 'money'},
#   "Roh's Beauty"),
#  ({'first_keyword': 'quirky',
#    'second_keyword': 'couple',
#    'third_keyword': 'spends'},
#   'Happy Anniversary'),
#  ({'first_keyword': 'using',
#    'second_keyword': 'never-before-heard',
#    'third_keyword': 'recordings,'},
#   'What Happened, Miss Simone?'),
#  ({'first_keyword': 'toprak,',
#    'second_keyword': 'lost',
#    'third_keyword': 'baby,'},
#   'Love Is in the Air'),
#  ({'first_keyword': 'losing',
#    'second_keyword': 'seventh',
#    'third_keyword': 'job'},
#   'Abby Sen'),
#  ({'first_keyword': 'horror',
#    'second_keyword': 'novelist',
#    'third_keyword': 'traumatic'},
#   'All Light Will End'),
#  ({'first_keyword': 'years',
#    'second_keyword': 'wealthy',
#    'third_keyword': 'man'},
#   'Easy Fortune Happy Life'),
#  ({'first_keyword': 'one-night',
#    'second_keyword': 'stand,',
#    'third_keyword': 'holly'},
#   'You Get Me'),
#  ({'first_keyword': 'inspired',
#    'second_keyword': 'true',
#    'third_keyword': 'story,'},
#   'Sin senos no hay paraíso'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'mumbai',
#    'third_keyword': 'up-and-comers'},
#   'Life in a ... Metro'),
#  ({'first_keyword': 'unassuming',
#    'second_keyword': 'high',
#    'third_keyword': 'school'},
#   'Boys Over Flowers'),
#  ({'first_keyword': 'photographer',
#    'second_keyword': 'invites',
#    'third_keyword': 'close-knit'},
#   'Angry Indian Goddesses'),
#  ({'first_keyword': 'explore',
#    'second_keyword': 'history',
#    'third_keyword': 'flavors'},
#   'Raja Rasoi Aur Anya Kahaniyan'),
#  ({'first_keyword': 'equestria',
#    'second_keyword': 'girls,',
#    'third_keyword': 'human'},
#   'My Little Pony Equestria Girls: Legend of Everfree'),
#  ({'first_keyword': 'low-level',
#    'second_keyword': 'drug',
#    'third_keyword': 'dealer'},
#   'Cardboard Gangsters'),
#  ({'first_keyword': 'reality',
#    'second_keyword': 'series',
#    'third_keyword': 'follows'},
#   'Rica, Famosa, Latina'),
#  ({'first_keyword': 'seemingly',
#    'second_keyword': 'idyllic',
#    'third_keyword': 'life'},
#   'A Good Wife'),
#  ({'first_keyword': "mía's",
#    'second_keyword': 'vacation',
#    'third_keyword': 'dad'},
#   'GO! The Unforgettable Party'),
#  ({'first_keyword': 'shy,',
#    'second_keyword': 'brilliant',
#    'third_keyword': 'boy'},
#   'Heartthrob'),
#  ({'first_keyword': 'beloved',
#    'second_keyword': 'sitcom',
#    'third_keyword': 'follows'},
#   "Dad's Army"),
#  ({'first_keyword': 'rampaging',
#    'second_keyword': 'serial',
#    'third_keyword': 'killers'},
#   'Slasher'),
#  ({'first_keyword': '14-year-old',
#    'second_keyword': 'takes',
#    'third_keyword': 'ownership'},
#   'Some Assembly Required'),
#  ({'first_keyword': 'celebrate',
#    'second_keyword': 'carnival,',
#    'third_keyword': 'everyone'},
#   'Pocoyo Carnival'),
#  ({'first_keyword': 'chef',
#    'second_keyword': 'david',
#    'third_keyword': 'chang'},
#   'Breakfast, Lunch & Dinner'),
#  ({'first_keyword': 'ex-con',
#    'second_keyword': 'just',
#    'third_keyword': 'getting'},
#   'American Heist'),
#  ({'first_keyword': 'north',
#    'second_keyword': 'korean',
#    'third_keyword': 'propagandist'},
#   'I Am Sun Mu'),
#  ({'first_keyword': 'nuclear',
#    'second_keyword': 'lake',
#    'third_keyword': 'haunted'},
#   'Dark Tourist'),
#  ({'first_keyword': 'canada,',
#    'second_keyword': 'colorful',
#    'third_keyword': 'collection'},
#   'Storage Wars: Northern Treasures'),
#  ({'first_keyword': 'spending',
#    'second_keyword': 'much',
#    'third_keyword': 'adult'},
#   'The Tenth Man'),
#  ({'first_keyword': 'telling',
#    'second_keyword': 'white',
#    'third_keyword': 'lie'},
#   "Ali's Wedding"),
#  ({'first_keyword': 'powerful',
#    'second_keyword': 'political',
#    'third_keyword': 'epic'},
#   'The West Wing'),
#  ({'first_keyword': 'cash-strapped',
#    'second_keyword': 'videographer',
#    'third_keyword': 'takes'},
#   'Creep'),
#  ({'first_keyword': 'iran-iraq',
#    'second_keyword': 'conflict,',
#    'third_keyword': 'tehran'},
#   'Under the Shadow'),
#  ({'first_keyword': 'pressured',
#    'second_keyword': 'marry',
#    'third_keyword': 'nice'},
#   'The Awakening of Motti Wolkenbruch'),
#  ({'first_keyword': 'thrown',
#    'second_keyword': 'elite',
#    'third_keyword': 'dance'},
#   'ABCD: Any Body Can Dance'),
#  ({'first_keyword': 'number',
#    'second_keyword': 'russian',
#    'third_keyword': 'women'},
#   'Black Rose'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'animal',
#    'third_keyword': 'keepers'},
#   "Naledi: A Baby Elephant's Tale"),
#  ({'first_keyword': 'explore',
#    'second_keyword': 'media',
#    'third_keyword': 'nationalism'},
#   'To Be a Miss'),
#  ({'first_keyword': 'trapped',
#    'second_keyword': 'stagecoach',
#    'third_keyword': 'stop'},
#   'The Hateful Eight: Extended Version'),
#  ({'first_keyword': 'plucky',
#    'second_keyword': 'orphan',
#    'third_keyword': 'whose'},
#   'Anne with an E'),
#  ({'first_keyword': 'ferocious',
#    'second_keyword': 'contagion',
#    'third_keyword': 'sweeps'},
#   'Containment'),
#  ({'first_keyword': 'wife',
#    'second_keyword': 'inexplicably',
#    'third_keyword': 'disappears,'},
#   'Headwinds'),
#  ({'first_keyword': 'interviews',
#    'second_keyword': 'influential',
#    'third_keyword': 'mcs,'},
#   'Hip-Hop Evolution'),
#  ({'first_keyword': 'biggest',
#    'second_keyword': 'foe',
#    'third_keyword': 'seemingly'},
#   'InuYasha: The Movie 2: The Castle Beyond the Looking Glass'),
#  ({'first_keyword': 'four',
#    'second_keyword': 'clever',
#    'third_keyword': 'school'},
#   'The InBESTigators'),
#  ({'first_keyword': 'elderly,',
#    'second_keyword': 'hearing-impaired',
#    'third_keyword': 'indian'},
#   'Radiopetti'),
#  ({'first_keyword': 'beautiful',
#    'second_keyword': 'belly-dancer',
#    'third_keyword': 'moves'},
#   "It's Fine"),
#  ({'first_keyword': 'frustrated',
#    'second_keyword': 'life',
#    'third_keyword': 'boyfriend,'},
#   'Love and Fortune'),
#  ({'first_keyword': "world's",
#    'second_keyword': 'first',
#    'third_keyword': 'family'},
#   'Dawn of the Croods'),
#  ({'first_keyword': 'widow',
#    'second_keyword': 'searches',
#    'third_keyword': 'missing'},
#   'The Wrong Babysitter'),
#  ({'first_keyword': 'civil',
#    'second_keyword': 'war',
#    'third_keyword': 'looming,'},
#   'Vizontele Tuuba'),
#  ({'first_keyword': 'chronicling',
#    'second_keyword': '1980',
#    'third_keyword': 'titan'},
#   'Command and Control'),
#  ({'first_keyword': 'find',
#    'second_keyword': 'fun',
#    'third_keyword': 'adventure'},
#   'Spirit Riding Free: Pony Tales'),
#  ({'first_keyword': 'shapeshifter',
#    'second_keyword': 'kill,',
#    'third_keyword': 'inhabit'},
#   'Lifechanger'),
#  ({'first_keyword': "man's",
#    'second_keyword': 'inability',
#    'third_keyword': 'conquer'},
#   'May You Prosper'),
#  ({'first_keyword': 'jake',
#    'second_keyword': 'returns',
#    'third_keyword': 'kansas'},
#   'Jericho'),
#  ({'first_keyword': 'mistress',
#    'second_keyword': 'wealthy',
#    'third_keyword': 'businessman'},
#   'The Mistress'),
#  ({'first_keyword': 'mind',
#    'second_keyword': 'human',
#    'third_keyword': 'being,'},
#   'YOM'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'young,',
#    'third_keyword': 'aspiring'},
#   'Gabru: Hip Hop Revolution'),
#  ({'first_keyword': 'rebellious',
#    'second_keyword': 'daughter',
#    'third_keyword': 'accompanies'},
#   'Crazy Beautiful You'),
#  ({'first_keyword': 'biopic',
#    'second_keyword': 'profiles',
#    'third_keyword': 'andries'},
#   'Riphagen - The Untouchable'),
#  ({'first_keyword': 'intimate',
#    'second_keyword': 'portrait',
#    'third_keyword': 'sheds'},
#   'Newtown'),
#  ({'first_keyword': 'garfunkel',
#    'second_keyword': 'oates',
#    'third_keyword': 'put'},
#   'Garfunkel and Oates: Trying to be Special'),
#  ({'first_keyword': 'two', 'second_keyword': 'l.a.', 'third_keyword': 'teens'},
#   'Good Burger'),
#  ({'first_keyword': 'years',
#    'second_keyword': 'presumed',
#    'third_keyword': 'death'},
#   'The Water Diviner'),
#  ({'first_keyword': 'john',
#    'second_keyword': 'travolta',
#    'third_keyword': 'olivia'},
#   'Grease'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'struggling',
#    'third_keyword': 'individuals'},
#   'World at Your Feet'),
#  ({'first_keyword': 'delusional',
#    'second_keyword': 'ex-con',
#    'third_keyword': 'rejoins'},
#   'Dog Eat Dog'),
#  ({'first_keyword': 'imprisoned',
#    'second_keyword': 'terrorist',
#    'third_keyword': 'cell'},
#   'Incoming'),
#  ({'first_keyword': 'barry,',
#    'second_keyword': 'worker',
#    'third_keyword': 'bee'},
#   'Bee Movie'),
#  ({'first_keyword': 'armed',
#    'second_keyword': 'powerful',
#    'third_keyword': 'amulet,'},
#   'LEGO Elves: Secrets of Elvendale'),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'never-before-seen',
#    'third_keyword': 'images,'},
#   'Los tiempos de Pablo Escobar'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'teenagers',
#    'third_keyword': 'step'},
#   'Seven in Heaven'),
#  ({'first_keyword': 'confessional',
#    'second_keyword': 'tales',
#    'third_keyword': 'love'},
#   'Club Friday The Series 7'),
#  ({'first_keyword': 'series',
#    'second_keyword': 'looks',
#    'third_keyword': 'seasonal'},
#   "Nature's Great Events (2009)"),
#  ({'first_keyword': 'religion',
#    'second_keyword': 'thwarted',
#    'third_keyword': 'lucas'},
#   'El Clon'),
#  ({'first_keyword': 'part',
#    'second_keyword': 'first',
#    'third_keyword': 'class'},
#   'Transformers Rescue Bots Academy'),
#  ({'first_keyword': 'concert',
#    'second_keyword': 'film,',
#    'third_keyword': 'oscar-winning'},
#   'Hans Zimmer: Live in Prague'),
#  ({'first_keyword': 'ex-con',
#    'second_keyword': 'cal',
#    'third_keyword': "mcteer's"},
#   'Tidelands'),
#  ({'first_keyword': 'world', 'second_keyword': 'war', 'third_keyword': 'ii,'},
#   'The Great Raid'),
#  ({'first_keyword': 'poet',
#    'second_keyword': 'civil',
#    'third_keyword': 'rights'},
#   'Maya Angelou: And Still I Rise'),
#  ({'first_keyword': 'kids',
#    'second_keyword': 'fairy-tale',
#    'third_keyword': 'characters'},
#   'Ever After High'),
#  ({'first_keyword': 'seaside',
#    'second_keyword': 'aguazul,',
#    'third_keyword': 'beautiful'},
#   'Lo que la vida me robó'),
#  ({'first_keyword': 'pressure',
#    'second_keyword': 'parents',
#    'third_keyword': 'settle'},
#   'Tundukkan Playboy Itu'),
#  ({'first_keyword': 'interviews',
#    'second_keyword': 'locals,',
#    'third_keyword': 'documentary'},
#   'Muzaffarnagar Baaqi Hai'),
#  ({'first_keyword': 'hoping',
#    'second_keyword': 'make',
#    'third_keyword': 'bundle'},
#   'Lock, Stock and Two Smoking Barrels'),
#  ({'first_keyword': 'run-in',
#    'second_keyword': 'grizzly',
#    'third_keyword': 'bear'},
#   'Bert Kreischer: The Machine'),
#  ({'first_keyword': 'searching',
#    'second_keyword': 'ex-boyfriend,',
#    'third_keyword': 'young'},
#   'Tallulah'),
#  ({'first_keyword': 'businesswoman',
#    'second_keyword': 'debra',
#    'third_keyword': "newell's"},
#   'Dirty John'),
#  ({'first_keyword': 'master',
#    'second_keyword': 'criminal',
#    'third_keyword': 'helios'},
#   'Helios'),
#  ({'first_keyword': 'trip',
#    'second_keyword': 'church',
#    'third_keyword': 'family'},
#   "Angela's Christmas"),
#  ({'first_keyword': 'collection',
#    'second_keyword': '12',
#    'third_keyword': 'short'},
#   'Walt Disney Animation Studios Short Films Collection'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'friends',
#    'third_keyword': 'reunites'},
#   'Arisan 2'),
#  ({'first_keyword': 'extensive',
#    'second_keyword': 'film',
#    'third_keyword': 'clips'},
#   'An American in Madras'),
#  ({'first_keyword': 'just',
#    'second_keyword': 'thought',
#    'third_keyword': "rangers'"},
#   'Power Rangers Dino Super Charge'),
#  ({'first_keyword': 'jackie',
#    'second_keyword': 'chan',
#    'third_keyword': 'jet'},
#   'The Forbidden Kingdom'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'recounts',
#    'third_keyword': '1994'},
#   'Tyke Elephant Outlaw'),
#  ({'first_keyword': 'death',
#    'second_keyword': 'wife,',
#    'third_keyword': 'teacher'},
#   'The Bachelors'),
#  ({'first_keyword': 'keep',
#    'second_keyword': 'boys',
#    'third_keyword': 'line,'},
#   'Maid-Sama!'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'kingdoms',
#    'third_keyword': 'struggle'},
#   'Shadow'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'profiles',
#    'third_keyword': 'music'},
#   'Quincy'),
#  ({'first_keyword': 'gravity-defying',
#    'second_keyword': 'boy',
#    'third_keyword': 'raised'},
#   'The Man Without Gravity'),
#  ({'first_keyword': 'rainbow',
#    'second_keyword': 'dash,',
#    'third_keyword': 'applejack,'},
#   'My Little Pony Equestria Girls: Rainbow Rocks'),
#  ({'first_keyword': 'dark,',
#    'second_keyword': 'early',
#    'third_keyword': 'days'},
#   'Black Summer'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'teen',
#    'third_keyword': 'prodigies'},
#   'See You Yesterday'),
#  ({'first_keyword': 'adapted',
#    'second_keyword': 'hit',
#    'third_keyword': 'broadway'},
#   'Jersey Boys'),
#  ({'first_keyword': 'iranian',
#    'second_keyword': 'american',
#    'third_keyword': 'comic'},
#   'Maz Jobrani: Immigrant'),
#  ({'first_keyword': 'accident',
#    'second_keyword': 'murder?',
#    'third_keyword': 'mysterious'},
#   'The Staircase'),
#  ({'first_keyword': 'unexceptional',
#    'second_keyword': 'man',
#    'third_keyword': 'becomes'},
#   'Drishyam'),
#  ({'first_keyword': 'series',
#    'second_keyword': 'mysterious',
#    'third_keyword': 'text'},
#   'See You in Time'),
#  ({'first_keyword': 'recently',
#    'second_keyword': 'stationed',
#    'third_keyword': 'air'},
#   'DRAGON PILOT: Hisone & Masotan'),
#  ({'first_keyword': 'moving',
#    'second_keyword': 'new',
#    'third_keyword': 'house'},
#   'Gnome Alone'),
#  ({'first_keyword': 'former',
#    'second_keyword': 'u.s.',
#    'third_keyword': 'labor'},
#   'Inequality for All'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'unsettled',
#    'third_keyword': 'battles'},
#   'Fate/Zero'),
#  ({'first_keyword': 'husband',
#    'second_keyword': 'abruptly',
#    'third_keyword': 'ends'},
#   'Holiday in the Wild'),
#  ({'first_keyword': 'kind-hearted',
#    'second_keyword': 'insurance',
#    'third_keyword': 'agent'},
#   'Bh Se Bhade'),
#  ({'first_keyword': 'witness',
#    'second_keyword': 'origins',
#    'third_keyword': 'master'},
#   'Halo: The Fall of Reach'),
#  ({'first_keyword': 'unwed',
#    'second_keyword': 'pregnant,',
#    'third_keyword': 'young'},
#   'St. Agatha'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'journey',
#    'third_keyword': 'satnam'},
#   'One in a Billion'),
#  ({'first_keyword': 'protect',
#    'second_keyword': 'family,',
#    'third_keyword': 'police'},
#   'Borderliner'),
#  ({'first_keyword': 'ex-cia',
#    'second_keyword': 'agent',
#    'third_keyword': 'john'},
#   'Person of Interest'),
#  ({'first_keyword': 'apartment',
#    'second_keyword': 'building',
#    'third_keyword': 'manager'},
#   'Lady in the Water'),
#  ({'first_keyword': 'expecting',
#    'second_keyword': 'relax',
#    'third_keyword': '"vacation"'},
#   'Tucker and Dale vs. Evil'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'brothers',
#    'third_keyword': 'fall'},
#   'แผนร้ายนายเจ้าเล่ห์'),
#  ({'first_keyword': 'flanked',
#    'second_keyword': 'full',
#    'third_keyword': 'orchestra,'},
#   'Tim Minchin And The Heritage Orchestra Live'),
#  ({'first_keyword': 'things', 'second_keyword': 'go', 'third_keyword': 'way'},
#   'My Only Love Song'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'friends',
#    'third_keyword': 'study'},
#   'V.R. Troopers'),
#  ({'first_keyword': 'comedy',
#    'second_keyword': 'icon',
#    'third_keyword': 'dave'},
#   'Dave Chappelle'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'charts',
#    'third_keyword': '20'},
#   'Les Bleus - Une autre histoire de France, 1996-2016'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'fathers',
#    'third_keyword': 'clashing'},
#   'The Week Of'),
#  ({'first_keyword': 'los',
#    'second_keyword': 'angeles',
#    'third_keyword': 'police'},
#   'A Week in Watts'),
#  ({'first_keyword': 'spanning',
#    'second_keyword': '1970s,',
#    'third_keyword': '‘80s'},
#   'Chaotic Love Poems'),
#  ({'first_keyword': 'teen',
#    'second_keyword': 'haunted',
#    'third_keyword': 'spirit'},
#   'Anohana: The Flower We Saw That Day'),
#  ({'first_keyword': 'shocking',
#    'second_keyword': 'murder',
#    'third_keyword': 'singer'},
#   'ReMastered: Massacre at the Stadium'),
#  ({'first_keyword': 'boy', 'second_keyword': 'band', 'third_keyword': 'beat'},
#   'Be with Me'),
#  ({'first_keyword': 'movie-loving',
#    'second_keyword': '10-year-old',
#    'third_keyword': 'blind'},
#   'Dhanak'),
#  ({'first_keyword': 'graduating,',
#    'second_keyword': 'four',
#    'third_keyword': 'college'},
#   'Kicking and Screaming'),
#  ({'first_keyword': "america's",
#    'second_keyword': 'king',
#    'third_keyword': 'clean'},
#   'Jim Gaffigan: Cinco'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'ulises',
#    'third_keyword': 'falls'},
#   'The Chosen Ones'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'teenagers',
#    'third_keyword': 'print'},
#   'Counterfeiting in Suburbia'),
#  ({'first_keyword': 'harper',
#    'second_keyword': 'sent',
#    'third_keyword': 'spain'},
#   'Ibiza'),
#  ({'first_keyword': 'back',
#    'second_keyword': 'bondi',
#    'third_keyword': 'beach,'},
#   'Deep Water'),
#  ({'first_keyword': 'dynamic',
#    'second_keyword': 'comic',
#    'third_keyword': 'deray'},
#   'DeRay Davis: How to Act Black'),
#  ({'first_keyword': 'whoever',
#    'second_keyword': 'came',
#    'third_keyword': 'term'},
#   'Beak & Brain: Genius Birds From Down Under'),
#  ({'first_keyword': 'narrated',
#    'second_keyword': 'actor',
#    'third_keyword': 'former'},
#   'We, the Marines'),
#  ({'first_keyword': 'circle',
#    'second_keyword': 'young',
#    'third_keyword': 'men'},
#   'Hardy Bucks'),
#  ({'first_keyword': 'couple',
#    'second_keyword': 'sensuous',
#    'third_keyword': 'weekend'},
#   'Ragini MMS'),
#  ({'first_keyword': 'team',
#    'second_keyword': 'skilled',
#    'third_keyword': 'contractors'},
#   'Fix It and Finish It'),
#  ({'first_keyword': 'arnold',
#    'second_keyword': 'crew',
#    'third_keyword': 'win'},
#   'Hey Arnold! The Jungle Movie'),
#  ({'first_keyword': 'troobian',
#    'second_keyword': 'empire',
#    'third_keyword': 'attacks'},
#   'Power Rangers S.P.D.'),
#  ({'first_keyword': 'stories',
#    'second_keyword': 'spiritual',
#    'third_keyword': 'leaders,'},
#   'Heal'),
#  ({'first_keyword': 'agam',
#    'second_keyword': "singh's",
#    'third_keyword': 'brothers'},
#   'Dil Vil Pyaar Vyaar'),
#  ({'first_keyword': 'reboot',
#    'second_keyword': 'tv',
#    'third_keyword': 'classic,'},
#   "Charlie's Angels: Full Throttle"),
#  ({'first_keyword': 'budding',
#    'second_keyword': 'teen',
#    'third_keyword': 'psychopath'},
#   'The End of the F***ing World'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'man',
#    'third_keyword': 'determines'},
#   'Cinta Teruna Kimchi'),
#  ({'first_keyword': 'experience',
#    'second_keyword': 'joy',
#    'third_keyword': 'sacrifice'},
#   'I Dream Of Dance'),
#  ({'first_keyword': 'greatest',
#    'second_keyword': 'fairy',
#    'third_keyword': 'tale'},
#   'Shrek the Musical'),
#  ({'first_keyword': 'extreme',
#    'second_keyword': 'pressure',
#    'third_keyword': 'father'},
#   'Genius'),
#  ({'first_keyword': 'tough',
#    'second_keyword': 'upbringing,',
#    'third_keyword': 'natural-born'},
#   'Stronger Than the World'),
#  ({'first_keyword': 'single',
#    'second_keyword': 'mother',
#    'third_keyword': 'liz'},
#   'Extremely Wicked, Shockingly Evil and Vile'),
#  ({'first_keyword': 'raw',
#    'second_keyword': 'stand-up',
#    'third_keyword': 'comedy'},
#   'Mike Epps: Only One Mike'),
#  ({'first_keyword': 'care',
#    'second_keyword': 'detective',
#    'third_keyword': 'agency,'},
#   'The Liar'),
#  ({'first_keyword': 'diagnosed',
#    'second_keyword': 'hiv-positive,',
#    'third_keyword': 'champion'},
#   'My Brother ... Nikhil'),
#  ({'first_keyword': 'fashion',
#    'second_keyword': 'blogger',
#    'third_keyword': 'falls'},
#   'Love.com'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'take',
#    'third_keyword': 'classic'},
#   'The Legend of White Snake'),
#  ({'first_keyword': 'self-professed',
#    'second_keyword': 'teenage',
#    'third_keyword': '"space'},
#   'The Mars Generation'),
#  ({'first_keyword': 'petty',
#    'second_keyword': 'criminals,',
#    'third_keyword': 'dodgy'},
#   "Chewin' the Fat"),
#  ({'first_keyword': 'uncanny',
#    'second_keyword': 'tales',
#    'third_keyword': 'reveal'},
#   'On Children'),
#  ({'first_keyword': 'go',
#    'second_keyword': 'behind',
#    'third_keyword': 'scenes'},
#   'The Crystal Calls Making the Dark Crystal: Age of Resistance'),
#  ({'first_keyword': 'crisis',
#    'second_keyword': 'threatens',
#    'third_keyword': 'destroy'},
#   'Coin Heist'),
#  ({'first_keyword': 'stranded',
#    'second_keyword': 'transit',
#    'third_keyword': 'station'},
#   'The Similars'),
#  ({'first_keyword': 'experts',
#    'second_keyword': 'examine',
#    'third_keyword': 'ruins'},
#   'Secrets of Underground London'),
#  ({'first_keyword': "family's",
#    'second_keyword': 'frustration,',
#    'third_keyword': 'henry'},
#   'Horrid Henry'),
#  ({'first_keyword': 'indian',
#    'second_keyword': 'village',
#    'third_keyword': 'abuzz'},
#   'Billu'),
#  ({'first_keyword': "cop's",
#    'second_keyword': 'fiancée',
#    'third_keyword': 'jewelry'},
#   'Black Money Love'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'series',
#    'third_keyword': 'explores'},
#   'Origins Collection'),
#  ({'first_keyword': 'part',
#    'second_keyword': 'live-action',
#    'third_keyword': 'part'},
#   'Wartime Portraits'),
#  ({'first_keyword': 'emmy-winning',
#    'second_keyword': 'comedian',
#    'third_keyword': 'dana'},
#   'Dana Carvey: Straight White Male, 60'),
#  ({'first_keyword': 'soon-to-be-retiring',
#    'second_keyword': 'mr.',
#    'third_keyword': 'lino'},
#   'Warehoused'),
#  ({'first_keyword': 'region',
#    'second_keyword': 'ravaged',
#    'third_keyword': 'opioid'},
#   'Recovery Boys'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'explores',
#    'third_keyword': 'challenging,'},
#   'Functional Fitness'),
#  ({'first_keyword': 'six',
#    'second_keyword': 'students',
#    'third_keyword': 'exclusive'},
#   'Rebelde'),
#  ({'first_keyword': 'join',
#    'second_keyword': 'zoologist',
#    'third_keyword': 'dr.'},
#   'Monkey Planet'),
#  ({'first_keyword': 'fast-paced',
#    'second_keyword': 'action',
#    'third_keyword': 'flick'},
#   'Hellboy'),
#  ({'first_keyword': 'losing',
#    'second_keyword': 'world',
#    'third_keyword': 'cup'},
#   'Because of Soccer'),
#  ({'first_keyword': 'seven',
#    'second_keyword': 'deadly',
#    'third_keyword': 'sins'},
#   'The Seven Deadly Sins the Movie: Prisoners of the Sky'),
#  ({'first_keyword': 'mother',
#    'second_keyword': 'daughter',
#    'third_keyword': 'gang-raped'},
#   'Revenge'),
#  ({'first_keyword': 'missing',
#    'second_keyword': 'child',
#    'third_keyword': 'sets'},
#   'Dark'),
#  ({'first_keyword': 'businessman',
#    'second_keyword': 'manav',
#    'third_keyword': 'falls'},
#   'Taal'),
#  ({'first_keyword': 'hand-picked',
#    'second_keyword': 'tiffany',
#    'third_keyword': 'haddish,'},
#   'Tiffany Haddish Presents: They Ready'),
#  ({'first_keyword': '99th',
#    'second_keyword': 'breakup,',
#    'third_keyword': 'career'},
#   'Break Up 100'),
#  ({'first_keyword': 'serving',
#    'second_keyword': 'time',
#    'third_keyword': 'jail,'},
#   "Brother's Shadow"),
#  ({'first_keyword': 'despite',
#    'second_keyword': 'public',
#    'third_keyword': 'humiliation'},
#   'Pad Man'),
#  ({'first_keyword': 'divorce',
#    'second_keyword': 'fatal',
#    'third_keyword': 'career'},
#   'Toast of London'),
#  ({'first_keyword': 'bored',
#    'second_keyword': 'life',
#    'third_keyword': 'inspired'},
#   'Romantik Komedi'),
#  ({'first_keyword': 'suffer',
#    'second_keyword': 'physical',
#    'third_keyword': 'damage'},
#   'Fullmetal Alchemist: Brotherhood'),
#  ({'first_keyword': 'high',
#    'second_keyword': 'school',
#    'third_keyword': 'senior'},
#   'Roonpi Secret Love'),
#  ({'first_keyword': 'elite',
#    'second_keyword': 'real',
#    'third_keyword': 'estate'},
#   'Selling Sunset'),
#  ({'first_keyword': 'realizing',
#    'second_keyword': 'boob',
#    'third_keyword': 'tube'},
#   'Beavis and Butt-head Do America'),
#  ({'first_keyword': 'brother',
#    'second_keyword': 'dies,',
#    'third_keyword': 'wealthy'},
#   'English Babu Desi Mem'),
#  ({'first_keyword': 'lovable',
#    'second_keyword': 'pug',
#    'third_keyword': 'chip'},
#   'Chip and Potato'),
#  ({'first_keyword': 'stand-up',
#    'second_keyword': 'sensation',
#    'third_keyword': 'tackles'},
#   'Iliza Shlesinger: Confirmed Kills'),
#  ({'first_keyword': '"last',
#    'second_keyword': 'comic',
#    'third_keyword': 'standing"'},
#   "Felipe Esparza: They're Not Going to Laugh at You"),
#  ({'first_keyword': 'filming',
#    'second_keyword': 'movie',
#    'third_keyword': 'england,'},
#   'My Week with Marilyn'),
#  ({'first_keyword': 'survivors',
#    'second_keyword': 'first',
#    'third_keyword': 'responders'},
#   'November 13: Attack on Paris'),
#  ({'first_keyword': '14th-century',
#    'second_keyword': 'scotland,',
#    'third_keyword': 'robert'},
#   'Outlaw King'),
#  ({'first_keyword': 'brutal',
#    'second_keyword': 'blacksmith',
#    'third_keyword': 'tortures'},
#   'Errementari: The Blacksmith and the Devil'),
#  ({'first_keyword': 'sean',
#    'second_keyword': 'penn',
#    'third_keyword': 'stars'},
#   'Milk'),
#  ({'first_keyword': 'businessman',
#    'second_keyword': 'falls',
#    'third_keyword': 'asleep'},
#   'When Angels Sleep'),
#  ({'first_keyword': 'short',
#    'second_keyword': 'documentary,',
#    'third_keyword': '37-year-old'},
#   'Cristina'),
#  ({'first_keyword': 'latest',
#    'second_keyword': 'jail',
#    'third_keyword': 'stint,'},
#   'Trailer Park Boys: Countdown to Liquor Day'),
#  ({'first_keyword': 'mikaelsons',
#    'second_keyword': 'move',
#    'third_keyword': 'new'},
#   'The Originals'),
#  ({'first_keyword': 'bachelorette',
#    'second_keyword': 'weekend,',
#    'third_keyword': 'lesbian'},
#   'The Feels'),
#  ({'first_keyword': 'first-ever',
#    'second_keyword': 'stand-up',
#    'third_keyword': 'special,'},
#   'Ken Jeong: You Complete Me, Ho'),
#  ({'first_keyword': 'bridge',
#    'second_keyword': 'construction',
#    'third_keyword': 'collapses'},
#   'Madaari'),
#  ({'first_keyword': 'hardworking',
#    'second_keyword': 'man',
#    'third_keyword': 'thankless'},
#   'The Land of Hypocrisy'),
#  ({'first_keyword': 'notorious',
#    'second_keyword': 'terrorist',
#    'third_keyword': 'manipulates'},
#   'Pukar'),
#  ({'first_keyword': 'curious',
#    'second_keyword': 'pals',
#    'third_keyword': 'splash,'},
#   'Splash and Bubbles'),
#  ({'first_keyword': 'winning',
#    'second_keyword': 'local',
#    'third_keyword': 'talent'},
#   'Beat Bugs: All Together Now'),
#  ({'first_keyword': 'fearless',
#    'second_keyword': 'provocation',
#    'third_keyword': 'fueled'},
#   'All About Nina'),
#  ({'first_keyword': '1930s',
#    'second_keyword': 'london,',
#    'third_keyword': 'michael'},
#   'Mary Poppins Returns'),
#  ({'first_keyword': 'nostalgic',
#    'second_keyword': 'documentary',
#    'third_keyword': 'series'},
#   'The Eighties'),
#  ({'first_keyword': 'trailblazing',
#    'second_keyword': 'series',
#    'third_keyword': 'follows'},
#   'The L Word'),
#  ({'first_keyword': 'actors,',
#    'second_keyword': 'crew',
#    'third_keyword': 'members'},
#   'They’ll Love Me When I’m Dead'),
#  ({'first_keyword': 'school',
#    'second_keyword': 'principal',
#    'third_keyword': 'gets'},
#   'The Massively Mixed-Up Middle School Mystery'),
# ...
#   'Roxanne Roxanne'),
#  ({'first_keyword': 'social',
#    'second_keyword': 'drama',
#    'third_keyword': 'sin'},
#   'The 10 Sins'),
#  ({'first_keyword': 'journalist',
#    'second_keyword': 'piers',
#    'third_keyword': 'morgan'},
#   'Killer Women with Piers Morgan'),
#  ({'first_keyword': '1901',
#    'second_keyword': 'spain,',
#    'third_keyword': 'elisa'},
#   'Elisa & Marcela'),
#  ({'first_keyword': 'ash', 'second_keyword': 'tries', 'third_keyword': 'pick'},
#   'Pokémon the Movie: I Choose You!'),
#  ({'first_keyword': 'star-studded',
#    'second_keyword': 'drama,',
#    'third_keyword': 'six'},
#   'Cloud Atlas'),
#  ({'first_keyword': 'help',
#    'second_keyword': 'friends,',
#    'third_keyword': 'man'},
#   '30 Days of Luxury'),
#  ({'first_keyword': 'sebastian',
#    'second_keyword': 'elephant',
#    'third_keyword': 'feline'},
#   'The Incredible Story of the Giant Pear'),
#  ({'first_keyword': "marine's",
#    'second_keyword': 'mission',
#    'third_keyword': 'goes'},
#   'Mine'),
#  ({'first_keyword': 'cinematic',
#    'second_keyword': 'lovebirds',
#    'third_keyword': 'aishwarya'},
#   'Kyun! Ho Gaya Na'),
#  ({'first_keyword': 'casino',
#    'second_keyword': 'du',
#    'third_keyword': 'liban,'},
#   'Adel Karam: Live from Beirut'),
#  ({'first_keyword': 'couple',
#    'second_keyword': 'must',
#    'third_keyword': 'decide'},
#   'The Box'),
#  ({'first_keyword': 'blend',
#    'second_keyword': 'cultural',
#    'third_keyword': 'nuance'},
#   'Barbecue'),
#  ({'first_keyword': 'returning',
#    'second_keyword': 'ibiza',
#    'third_keyword': 'several'},
#   'White Island'),
#  ({'first_keyword': 'decorating',
#    'second_keyword': 'home',
#    'third_keyword': 'devouring'},
#   'Mighty Little Bheem: Diwali'),
#  ({'first_keyword': 'twinkle,',
#    'second_keyword': 'mia,',
#    'third_keyword': 'jacus'},
#   'Little Baby Bum: Nursery Rhyme Friends'),
#  ({'first_keyword': 'shrek',
#    'second_keyword': 'celebrates',
#    'third_keyword': 'halloween,'},
#   "DreamWorks Shrek's Swamp Stories"),
#  ({'first_keyword': '10',
#    'second_keyword': 'years,',
#    'third_keyword': 'woman'},
#   'Roswell, New Mexico'),
#  ({'first_keyword': 'asylum',
#    'second_keyword': 'patient’s',
#    'third_keyword': 'troubled'},
#   'Rakkhosh'),
#  ({'first_keyword': 'burdened',
#    'second_keyword': 'troubles',
#    'third_keyword': 'life'},
#   'Juanita'),
#  ({'first_keyword': 'promising',
#    'second_keyword': 'student',
#    'third_keyword': 'zurich'},
#   'Burning Sands'),
#  ({'first_keyword': 'washed-up',
#    'second_keyword': 'professional',
#    'third_keyword': 'quarterback'},
#   'The Longest Yard'),
#  ({'first_keyword': 'writer,',
#    'second_keyword': 'director',
#    'third_keyword': 'food'},
#   'The Chef Show'),
#  ({'first_keyword': '15',
#    'second_keyword': 'years',
#    'third_keyword': 'behind'},
#   'The Last O.G.'),
#  ({'first_keyword': 'comedians',
#    'second_keyword': 'steve',
#    'third_keyword': 'coogan'},
#   'The Trip to Spain'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'man',
#    'third_keyword': 'ignores'},
#   'Mr. Virgin'),
#  ({'first_keyword': 'world',
#    'second_keyword': 'learns',
#    'third_keyword': 'truth'},
#   "Girlfriends' Guide to Divorce"),
#  ({'first_keyword': 'crippling',
#    'second_keyword': 'payday',
#    'third_keyword': 'loans'},
#   'Dirty Money'),
#  ({'first_keyword': 'ro', 'second_keyword': 'risks', 'third_keyword': 'life'},
#   'Perfect Stranger'),
#  ({'first_keyword': 'gambler',
#    'second_keyword': 'mired',
#    'third_keyword': 'debt'},
#   'Mississippi Grind'),
#  ({'first_keyword': 'reality',
#    'second_keyword': 'series,',
#    'third_keyword': 'brides-to-be'},
#   'Diva Brides'),
#  ({'first_keyword': 'crafting',
#    'second_keyword': 'grammy-nominated',
#    'third_keyword': 'album'},
#   'Travis Scott: Look Mom I Can Fly'),
#  ({'first_keyword': 'fulfill',
#    'second_keyword': "mother's",
#    'third_keyword': 'dying'},
#   'Humsafar'),
#  ({'first_keyword': 'nerdy',
#    'second_keyword': 'high',
#    'third_keyword': 'schooler'},
#   '#realityhigh'),
#  ({'first_keyword': 'filmmakers',
#    'second_keyword': 'explore',
#    'third_keyword': 'pop'},
#   'Liberated: The New Sexual Revolution'),
#  ({'first_keyword': 'digital',
#    'second_keyword': 'revolution',
#    'third_keyword': 'just'},
#   'Camera Store'),
#  ({'first_keyword': 'grieving',
#    'second_keyword': 'dead',
#    'third_keyword': 'wife'},
#   'Between Worlds'),
#  ({'first_keyword': 'mixing',
#    'second_keyword': 'archival',
#    'third_keyword': 'footage'},
#   'I Am Bolt'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'down-on-their-luck',
#    'third_keyword': 'singers'},
#   "It's Okay, Buddy"),
#  ({'first_keyword': 'four',
#    'second_keyword': 'ordinary',
#    'third_keyword': 'family'},
#   'Show Me the Money'),
#  ({'first_keyword': 'grieving',
#    'second_keyword': 'policeman',
#    'third_keyword': 'rickshaw'},
#   'Insan'),
#  ({'first_keyword': 'monty',
#    'second_keyword': 'python',
#    'third_keyword': 'comedy'},
#   'Monty Python and the Holy Grail'),
#  ({'first_keyword': 'fulfill',
#    'second_keyword': 'dreams',
#    'third_keyword': 'becoming'},
#   'Hunter X Hunter (2011)'),
#  ({'first_keyword': '20', 'second_keyword': 'years', 'third_keyword': 'death'},
#   'The Fear of 13'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'mother',
#    'third_keyword': 'embarks'},
#   'Dukhtar'),
#  ({'first_keyword': 'unscripted',
#    'second_keyword': 'series,',
#    'third_keyword': 'families'},
#   'The Big Family Cooking Showdown'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'young',
#    'third_keyword': 'adults'},
#   'Eeda'),
#  ({'first_keyword': 'bollywood',
#    'second_keyword': 'drama',
#    'third_keyword': 'tells'},
#   'Kai Po Che!'),
#  ({'first_keyword': 'living',
#    'second_keyword': 'best',
#    'third_keyword': 'life'},
#   'Daybreak'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'orphan',
#    'third_keyword': 'kuttappayi'},
#   'Ottaal'),
#  ({'first_keyword': 'amid',
#    'second_keyword': 'growing',
#    'third_keyword': 'tensions'},
#   'Catching Feelings'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'musicians',
#    'third_keyword': '13'},
#   'Satrangi'),
#  ({'first_keyword': 'unconventional',
#    'second_keyword': 'high',
#    'third_keyword': 'school'},
#   'Merlí'),
#  ({'first_keyword': 'groundbreaking',
#    'second_keyword': 'artists',
#    'third_keyword': 'share'},
#   'Rapture'),
#  ({'first_keyword': 'recovering',
#    'second_keyword': 'alcoholic',
#    'third_keyword': 'talal'},
#   'Zinzana'),
#  ({'first_keyword': 'employee',
#    'second_keyword': 'disappears',
#    'third_keyword': 'singapore,'},
#   'Singapore'),
#  ({'first_keyword': 'midst',
#    'second_keyword': 'ann',
#    'third_keyword': 'arduous'},
#   'Pierre Jackson'),
#  ({'first_keyword': "james's",
#    'second_keyword': 'living',
#    'third_keyword': 'situation'},
#   'Exit Strategy'),
#  ({'first_keyword': 'mexico',
#    'second_keyword': 'city',
#    'third_keyword': 'theme'},
#   'El Especial de Alex Fernández, el Especial'),
#  ({'first_keyword': 'ex-cop',
#    'second_keyword': 'becomes',
#    'third_keyword': 'superintendent'},
#   'The Super'),
#  ({'first_keyword': 'four',
#    'second_keyword': 'brothers',
#    'third_keyword': 'learn'},
#   '25 Kille'),
#  ({'first_keyword': 'carnival,',
#    'second_keyword': 'two',
#    'third_keyword': 'teens'},
#   'Jonas'),
#  ({'first_keyword': 'surprise',
#    'second_keyword': 'news',
#    'third_keyword': 'girlfriend'},
#   'Trash Fire'),
#  ({'first_keyword': '4-year-old',
#    'second_keyword': 'son',
#    'third_keyword': 'murdered,'},
#   'Who Killed Little Gregory?'),
#  ({'first_keyword': 'good',
#    'second_keyword': 'deed',
#    'third_keyword': 'unwittingly'},
#   'Resurrection: Ertugrul'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'traces',
#    'third_keyword': 'life'},
#   'The Untold Tales of Armistead Maupin'),
#  ({'first_keyword': 'villagers',
#    'second_keyword': 'kingdom',
#    'third_keyword': 'mahismati'},
#   'Baahubali: The Beginning (Malayalam Version)'),
#  ({'first_keyword': 'aging',
#    'second_keyword': 'father',
#    'third_keyword': 'seeks'},
#   'Aalorukkam'),
#  ({'first_keyword': 'spinning',
#    'second_keyword': 'old-school',
#    'third_keyword': 'beats'},
#   'People Just Do Nothing'),
#  ({'first_keyword': 'star',
#    'second_keyword': 'hunting',
#    'third_keyword': 'videos'},
#   'The Legacy of a Whitetail Deer Hunter'),
#  ({'first_keyword': 'desperate',
#    'second_keyword': 'start',
#    'third_keyword': 'new'},
#   'Mean Dreams'),
#  ({'first_keyword': 'insightful',
#    'second_keyword': 'drama',
#    'third_keyword': 'looks'},
#   'The Squid and the Whale'),
#  ({'first_keyword': 'series',
#    'second_keyword': 'responds',
#    'third_keyword': 'need'},
#   'La Rosa de Guadalupe'),
#  ({'first_keyword': 'famed',
#    'second_keyword': 'horticulturist',
#    'third_keyword': 'alan'},
#   'Love Your Garden'),
#  ({'first_keyword': 'bound',
#    'second_keyword': 'family',
#    'third_keyword': 'rule'},
#   "All's Well, End's Well (2009)"),
#  ({'first_keyword': 'housemates',
#    'second_keyword': 'big',
#    'third_keyword': 'brother'},
#   'Dead Set'),
#  ({'first_keyword': 'bodybuilders',
#    'second_keyword': 'come',
#    'third_keyword': 'together'},
#   'Generation Iron 3'),
#  ({'first_keyword': '"who',
#    'second_keyword': 'killed',
#    'third_keyword': 'laura'},
#   'Twin Peaks'),
#  ({'first_keyword': 'wicked',
#    'second_keyword': 'one-liners',
#    'third_keyword': 'soul-baring'},
#   'Neal Brennan: 3 Mics'),
#  ({'first_keyword': 'singers',
#    'second_keyword': 'europe',
#    'third_keyword': 'represent'},
#   'Eurovision Song Contest'),
#  ({'first_keyword': 'deformed,',
#    'second_keyword': 'disfigured',
#    'third_keyword': 'characters'},
#   'Skins'),
#  ({'first_keyword': 'determined',
#    'second_keyword': 'make',
#    'third_keyword': 'modern'},
#   'Frances Ha'),
#  ({'first_keyword': 'enrolling',
#    'second_keyword': 'college',
#    'third_keyword': 'poetry'},
#   'Love Beats Rhymes'),
#  ({'first_keyword': 'motley',
#    'second_keyword': 'crew',
#    'third_keyword': 'bank'},
#   'Takers'),
#  ({'first_keyword': 'ex-racecar',
#    'second_keyword': 'driver',
#    'third_keyword': 'sent'},
#   'Death Race: Beyond Anarchy'),
#  ({'first_keyword': 'hit',
#    'second_keyword': 'sitcom',
#    'third_keyword': 'follows'},
#   'Friends'),
#  ({'first_keyword': 'mild-mannered',
#    'second_keyword': 'janitor',
#    'third_keyword': 'duped'},
#   'Code Name: The Cleaner'),
#  ({'first_keyword': 'moody',
#    'second_keyword': 'london,',
#    'third_keyword': 'burned-out'},
#   'City of Tiny Lights'),
#  ({'first_keyword': 'runaway',
#    'second_keyword': 'teen',
#    'third_keyword': 'lovers'},
#   'The Innocents'),
#  ({'first_keyword': 'werner',
#    'second_keyword': 'herzog',
#    'third_keyword': 'chronicles'},
#   'From One Second to the Next'),
#  ({'first_keyword': 'teenager',
#    'second_keyword': 'moves',
#    'third_keyword': 'chicago'},
#   'Princess Cyd'),
#  ({'first_keyword': 'lifting',
#    'second_keyword': 'saggy',
#    'third_keyword': 'skin'},
#   'Botched Up Bodies'),
#  ({'first_keyword': 'talented',
#    'second_keyword': 'young',
#    'third_keyword': 'indian'},
#   'Patiala House'),
#  ({'first_keyword': 'confident',
#    'second_keyword': 'college',
#    'third_keyword': 'professor'},
#   'Professor Mack'),
#  ({'first_keyword': '1960s,',
#    'second_keyword': 'israeli',
#    'third_keyword': 'clerk-turned-secret'},
#   'The Spy'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'communities',
#    'third_keyword': 'mumbai'},
#   'Morya'),
#  ({'first_keyword': 'naive',
#    'second_keyword': 'sheltered',
#    'third_keyword': 'young'},
#   'In Search of Fellini'),
#  ({'first_keyword': 'detailed',
#    'second_keyword': 'examination',
#    'third_keyword': '1945'},
#   'Hiroshima: The Real History'),
#  ({'first_keyword': 'ditching',
#    'second_keyword': 'domestic',
#    'third_keyword': 'life'},
#   'Miss Culinary'),
#  ({'first_keyword': 'spanish',
#    'second_keyword': 'con',
#    'third_keyword': 'man'},
#   'Psiconautas'),
#  ({'first_keyword': 'jin',
#    'second_keyword': 'dragon',
#    'third_keyword': 'monster'},
#   'MONKART'),
#  ({'first_keyword': 'brazilian',
#    'second_keyword': 'comedian',
#    'third_keyword': 'edmilson'},
#   'Edmilson Filho: Notas, Comedy about Relationships'),
#  ({'first_keyword': 'havana',
#    'second_keyword': 'slowly',
#    'third_keyword': 'revolves'},
#   'Four Seasons in Havana'),
#  ({'first_keyword': 'bright',
#    'second_keyword': 'spirited',
#    'third_keyword': 'seven-year-old'},
#   'Luo Bao Bei'),
#  ({'first_keyword': 'irreverent',
#    'second_keyword': 'documentary',
#    'third_keyword': 'reveals'},
#   'The Man Who Would Be Polka King'),
#  ({'first_keyword': 'spirit',
#    'second_keyword': 'murdered',
#    'third_keyword': 'woman'},
#   'Lechmi'),
#  ({'first_keyword': 'classmates',
#    'second_keyword': 'aimee',
#    'third_keyword': 'sutter'},
#   'The Spectacular Now'),
#  ({'first_keyword': 'former',
#    'second_keyword': 'con',
#    'third_keyword': 'artist'},
#   'Ghanchakkar'),
#  ({'first_keyword': 'obsession',
#    'second_keyword': 'woman',
#    'third_keyword': 'one-night'},
#   'One Night Stand'),
#  ({'first_keyword': 'local',
#    'second_keyword': 'news',
#    'third_keyword': 'producer'},
#   'Somewhere Between'),
#  ({'first_keyword': 'last',
#    'second_keyword': 'family',
#    'third_keyword': 'line,'},
#   'Schubert In Love'),
#  ({'first_keyword': 'online',
#    'second_keyword': 'community',
#    'third_keyword': 'amateur'},
#   'Ultraviolet'),
#  ({'first_keyword': 'australian',
#    'second_keyword': 'comic',
#    'third_keyword': 'hannah'},
#   'Hannah Gadsby: Nanette'),
#  ({'first_keyword': 'fast-talking',
#    'second_keyword': 'yuppie',
#    'third_keyword': 'forced'},
#   'Rain Man'),
#  ({'first_keyword': 'loyalties',
#    'second_keyword': 'tested',
#    'third_keyword': 'cruelties'},
#   '7 años'),
#  ({'first_keyword': 'partner',
#    'second_keyword': 'cheats',
#    'third_keyword': 'her,'},
#   'In Family I Trust'),
#  ({'first_keyword': 'collecting',
#    'second_keyword': 'highlights',
#    'third_keyword': 'epic'},
#   'Frozen Planet: The Epic Journey'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'reporters',
#    'third_keyword': 'buzzfeed'},
#   'Follow This'),
#  ({'first_keyword': 'trying',
#    'second_keyword': 'buy',
#    'third_keyword': 'wife'},
#   'Odu Raja Odu'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'man',
#    'third_keyword': 'pursues'},
#   'Kaminey'),
#  ({'first_keyword': 'dumped',
#    'second_keyword': 'video',
#    'third_keyword': 'made'},
#   'Blockbuster'),
#  ({'first_keyword': 'wholesome',
#    'second_keyword': 'college',
#    'third_keyword': 'freshman'},
#   'After'),
#  ({'first_keyword': 'new', 'second_keyword': 'tv', 'third_keyword': 'series'},
#   'Scream'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'cuca',
#    'third_keyword': 'leaves'},
#   'Boy and the World'),
#  ({'first_keyword': 'path',
#    'second_keyword': 'becoming',
#    'third_keyword': 'pope'},
#   'Call Me Francis'),
#  ({'first_keyword': 'stuck',
#    'second_keyword': 'liquor',
#    'third_keyword': 'store'},
#   'El Camino Christmas'),
#  ({'first_keyword': "zimbabwe's",
#    'second_keyword': 'disputed',
#    'third_keyword': '2008'},
#   'Democrats'),
#  ({'first_keyword': 'love-challenged',
#    'second_keyword': 'man',
#    'third_keyword': 'woman'},
#   'Our Lovers'),
#  ({'first_keyword': 'drug-trafficking',
#    'second_keyword': 'husband',
#    'third_keyword': 'dies,'},
#   'Señora Acero'),
#  ({'first_keyword': 'student',
#    'second_keyword': 'filmmakers',
#    'third_keyword': 'uncover'},
#   '1st Summoning'),
#  ({'first_keyword': 'soap',
#    'second_keyword': 'opera',
#    'third_keyword': 'producer,'},
#   'You Carry Me'),
#  ({'first_keyword': 'oprah',
#    'second_keyword': 'winfrey',
#    'third_keyword': 'sits'},
#   '13TH: A Conversation with Oprah Winfrey & Ava DuVernay'),
#  ({'first_keyword': 'hypochondriac',
#    'second_keyword': 'confronts',
#    'third_keyword': 'fear'},
#   'Then Came You'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'friends',
#    'third_keyword': 'uncover'},
#   'Monster House'),
#  ({'first_keyword': 'dramatic',
#    'second_keyword': 'documentary',
#    'third_keyword': 'explores'},
#   'Magnus'),
#  ({'first_keyword': 'funky',
#    'second_keyword': 'california',
#    'third_keyword': 'beach'},
#   'Flaked'),
#  ({'first_keyword': 'consequences',
#    'second_keyword': 'trickery',
#    'third_keyword': 'explored'},
#   'Krish Trish and Baltiboy: The Greatest Trick'),
#  ...]

# %%
# build a classifier based on the training set
# note the train_set is a list of tuples where the first item of the tuple is a dictionary of features
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
#Testing the classifier
classifier.classify(movies_features("iconic rockstar"))
# Out:
# 'John Mellencamp: Plain Spoken'

# %%
classifier.classify(movies_features("fun friendship movie"))
# Out:
# 'True: Magical Friends'

# %%
classifier.classify(movies_features("sad lonely tired"))
# Out:
# 'Yours Fatefully'

# %%
#Rounding the AI accuracy and converting it into a string to print it and compare it to the human accuracy

roundedClassifierAccuracy = round(nltk.classify.accuracy(classifier, test_set), 4)
strClassifierAccuracy = str(roundedClassifierAccuracy)

# %%
print('human accuracy: ' + strHumanAccuracy + ' -- vs -- my classifier: ' + strClassifierAccuracy)
# Out:
# human accuracy: 0.0002 -- vs -- my classifier: 0.0009

# %%
classifier.show_most_informative_features(12)
# Out:
# Most Informative Features
#            first_keyword = 'documentary'  #Rucke : Limitl =      1.0 : 1.0
#            first_keyword = 'encountering' At the : The Si =      1.0 : 1.0
#            first_keyword = 'group'        Assimi : Oh My  =      1.0 : 1.0
#            first_keyword = 'possessed'    Fear F : Oh My  =      1.0 : 1.0
#            first_keyword = 'skilled'      Kickbo : Oh My  =      1.0 : 1.0
#            first_keyword = 'world'        Angel  : The Si =      1.0 : 1.0
#           second_keyword = 'attack'       Kuromu : The Si =      1.0 : 1.0
#           second_keyword = 'career'       Hostil : Limitl =      1.0 : 1.0
#           second_keyword = 'follows'      Alt-Ri : Limitl =      1.0 : 1.0
#           second_keyword = 'friends'         5CM : Oh My  =      1.0 : 1.0
#           second_keyword = 'ghost'        Cyborg : Oh My  =      1.0 : 1.0
#           second_keyword = 'musician'     Covere : Limitl =      1.0 : 1.0

# %%
#Trying to improve the accuracy by adding more keywrods. It seems more accurate by somehow the accuracy number has decreased to 0
# Adding more keywords to our classifier, and remove number
# and using nltk stopwords


def movies_features2(movieDescript):
    description = movieDescript.lower()
    words = description.split()
    s_words = stopwords.words('english', 'spanish')
    keywords = [x for x in words if x not in s_words and not x.isdigit()]
    while len(keywords) < 8:
        keywords.append('None')
    return {'first_keyword': keywords[0], 'second_keyword': keywords[1], 'third_keyword': keywords[2], 'fourth_keyword': keywords[3], 'fifth_keyword': keywords[4], 'sixth_keyword': keywords[5],'seventh_keyword': keywords[6], 'eight_keyword': keywords[7]}

movies_features2('I am feeling like a sad christmas movie about love tonight')
# Out:
# {'first_keyword': 'feeling',
#  'second_keyword': 'like',
#  'third_keyword': 'sad',
#  'fourth_keyword': 'christmas',
#  'fifth_keyword': 'movie',
#  'sixth_keyword': 'love',
#  'seventh_keyword': 'tonight',
#  'eight_keyword': 'None'}

# %%
zipped_features2 = zip(movieDescriptions, movieTitles)
featuresets2 = [(movies_features2(x), y) for x, y in zipped_features2 ]
featuresets2
# Out:
# [({'first_keyword': 'brought',
#    'second_keyword': 'together',
#    'third_keyword': 'meaningful',
#    'fourth_keyword': 'meals',
#    'fifth_keyword': 'past',
#    'sixth_keyword': 'present,',
#    'seventh_keyword': 'doctor',
#    'eight_keyword': 'chef'},
#   'Chocolate'),
#  ({'first_keyword': 'sierra',
#    'second_keyword': 'de',
#    'third_keyword': 'las',
#    'fourth_keyword': 'minas',
#    'fifth_keyword': 'esquipulas,',
#    'sixth_keyword': 'explore',
#    'seventh_keyword': "guatemala's",
#    'eight_keyword': 'cultural'},
#   'Guatemala: Heart of the Mayan World'),
#  ({'first_keyword': 'goofy',
#    'second_keyword': 'copywriter',
#    'third_keyword': 'unwittingly',
#    'fourth_keyword': 'convinces',
#    'fifth_keyword': 'indian',
#    'sixth_keyword': 'cricket',
#    'seventh_keyword': 'team',
#    'eight_keyword': 'she’s'},
#   'The Zoya Factor'),
#  ({'first_keyword': 'arranged',
#    'second_keyword': 'marry',
#    'third_keyword': 'rich',
#    'fourth_keyword': 'man,',
#    'fifth_keyword': 'young',
#    'sixth_keyword': 'ada',
#    'seventh_keyword': 'crushed',
#    'eight_keyword': 'true'},
#   'Atlantics'),
#  ({'first_keyword': 'lovable',
#    'second_keyword': 'pug',
#    'third_keyword': 'chip',
#    'fourth_keyword': 'starts',
#    'fifth_keyword': 'kindergarten,',
#    'sixth_keyword': 'makes',
#    'seventh_keyword': 'new',
#    'eight_keyword': 'friends'},
#   'Chip and Potato'),
#  ({'first_keyword': 'nollywood',
#    'second_keyword': 'star',
#    'third_keyword': 'ramsey',
#    'fourth_keyword': 'nouah',
#    'fifth_keyword': 'learns',
#    'sixth_keyword': 'someone',
#    'seventh_keyword': 'impersonating',
#    'eight_keyword': 'breaks'},
#   'Crazy people'),
#  ({'first_keyword': 'romance,',
#    'second_keyword': 'mystery',
#    'third_keyword': 'adventure',
#    'fourth_keyword': 'intertwine',
#    'fifth_keyword': 'young',
#    'sixth_keyword': 'man',
#    'seventh_keyword': 'falls',
#    'eight_keyword': 'love'},
#   'I Lost My Body'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'times',
#    'third_keyword': 'iconic',
#    'fourth_keyword': 'south',
#    'fifth_keyword': 'african',
#    'sixth_keyword': 'liberation',
#    'seventh_keyword': 'fighter',
#    'eight_keyword': 'solomon'},
#   'Kalushi: The Story of Solomon Mahlangu'),
#  ({'first_keyword': 'compelling',
#    'second_keyword': 'show',
#    'third_keyword': 'tells',
#    'fourth_keyword': 'story',
#    'fifth_keyword': 'legendary',
#    'sixth_keyword': 'teresa',
#    'seventh_keyword': 'mendoza,',
#    'eight_keyword': 'courageous'},
#   'La Reina del Sur'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'mooching',
#    'third_keyword': 'friends',
#    'fourth_keyword': 'vie',
#    'fifth_keyword': 'attention',
#    'sixth_keyword': 'wealthy,',
#    'seventh_keyword': 'beautiful',
#    'eight_keyword': 'women'},
#   'Lagos Real Fake Life'),
#  ({'first_keyword': 'expensive',
#    'second_keyword': 'night',
#    'third_keyword': 'out,',
#    'fourth_keyword': 'two',
#    'fifth_keyword': 'flatmates',
#    'sixth_keyword': 'get',
#    'seventh_keyword': 'tangled',
#    'eight_keyword': 'overnight'},
#   'Payday'),
#  ({'first_keyword': 'everything',
#    'second_keyword': 'love',
#    'third_keyword': '"sugar',
#    'fourth_keyword': 'rush"',
#    'fifth_keyword': '–',
#    'sixth_keyword': 'holly',
#    'seventh_keyword': 'jolly',
#    'eight_keyword': 'holiday'},
#   'Sugar Rush Christmas'),
#  ({'first_keyword': 'nursing',
#    'second_keyword': 'broken',
#    'third_keyword': 'heart,',
#    'fourth_keyword': 'specialist',
#    'fifth_keyword': 'moves',
#    'sixth_keyword': 'london',
#    'seventh_keyword': 'audition',
#    'eight_keyword': 'reality'},
#   'The Accidental Spy'),
#  ({'first_keyword': 'quirky',
#    'second_keyword': 'fashion',
#    'third_keyword': 'student',
#    'fourth_keyword': 'becomes',
#    'fifth_keyword': 'nanny',
#    'sixth_keyword': 'handsome',
#    'seventh_keyword': 'widower’s',
#    'eight_keyword': 'three'},
#   'The Charming Stepmom'),
#  ({'first_keyword': 'colonel',
#    'second_keyword': 'uncovers',
#    'third_keyword': 'controversial',
#    'fourth_keyword': 'intel',
#    'fifth_keyword': 'government,',
#    'sixth_keyword': 'makes',
#    'seventh_keyword': 'shocking',
#    'eight_keyword': 'discovery'},
#   'The Island'),
#  ({'first_keyword': 'blockbusters',
#    'second_keyword': 'brought',
#    'third_keyword': 'us',
#    'fourth_keyword': 'together',
#    'fifth_keyword': 'gave',
#    'sixth_keyword': 'us',
#    'seventh_keyword': 'time',
#    'eight_keyword': 'lives.'},
#   'The Movies That Made Us'),
#  ({'first_keyword': 'widowed',
#    'second_keyword': 'radio',
#    'third_keyword': 'dj',
#    'fourth_keyword': 'four',
#    'fifth_keyword': 'spoiled',
#    'sixth_keyword': 'kids',
#    'seventh_keyword': 'need',
#    'eight_keyword': 'tighten'},
#   'Holiday Rush'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'levius',
#    'third_keyword': 'rises',
#    'fourth_keyword': 'ranks',
#    'fifth_keyword': 'brutal',
#    'sixth_keyword': 'world',
#    'seventh_keyword': 'metal',
#    'eight_keyword': 'boxing'},
#   'Levius'),
#  ({'first_keyword': 'four',
#    'second_keyword': 'comedians',
#    'third_keyword': 'brazil',
#    'fourth_keyword': 'riff',
#    'fifth_keyword': 'sexuality,',
#    'sixth_keyword': 'politics,',
#    'seventh_keyword': 'religion',
#    'eight_keyword': 'motherhood'},
#   'Lugar de Mulher'),
#  ({'first_keyword': 'struggling',
#    'second_keyword': 'la',
#    'third_keyword': 'musician',
#    'fourth_keyword': 'tries',
#    'fifth_keyword': 'win',
#    'sixth_keyword': 'new',
#    'seventh_keyword': "girlfriend's",
#    'eight_keyword': 'gruff'},
#   'Merry Happy Whatever'),
#  ({'first_keyword': 'burned',
#    'second_keyword': 'taken',
#    'third_keyword': 'granted,',
#    'fourth_keyword': 'working',
#    'fifth_keyword': 'mom',
#    'sixth_keyword': 'suspects',
#    'seventh_keyword': 'partner',
#    'eight_keyword': 'cheating,'},
#   'Mythomaniac'),
#  ({'first_keyword': 'ready-to-retire',
#    'second_keyword': 'safecracker',
#    'third_keyword': 'nick,',
#    'fourth_keyword': 'flamboyant',
#    'fifth_keyword': 'fence',
#    'sixth_keyword': 'max',
#    'seventh_keyword': 'talented',
#    'eight_keyword': 'volatile'},
#   'The Score'),
#  ({'first_keyword': 'investigative',
#    'second_keyword': 'docuseries',
#    'third_keyword': 'shows',
#    'fourth_keyword': 'negligence',
#    'fifth_keyword': 'deceit',
#    'sixth_keyword': 'production',
#    'seventh_keyword': 'marketing',
#    'eight_keyword': 'popular'},
#   'Broken'),
#  ({'first_keyword': 'action-packed',
#    'second_keyword': 'drama',
#    'third_keyword': 'based',
#    'fourth_keyword': 'extraordinary',
#    'fifth_keyword': 'true',
#    'sixth_keyword': 'story,',
#    'seventh_keyword': 'four',
#    'eight_keyword': 'brothers'},
#   'Defiance'),
#  ({'first_keyword': 'caste',
#    'second_keyword': 'differences',
#    'third_keyword': 'throw',
#    'fourth_keyword': 'wrench',
#    'fifth_keyword': 'otherwise',
#    'sixth_keyword': 'blossoming',
#    'seventh_keyword': 'relationship,',
#    'eight_keyword': 'couple'},
#   'Evvarikee Cheppoddu'),
#  ({'first_keyword': 'journey',
#    'second_keyword': 'back',
#    'third_keyword': 'time',
#    'fourth_keyword': 'ancient',
#    'fifth_keyword': 'city',
#    'sixth_keyword': 'mirchigadh,',
#    'seventh_keyword': 'little',
#    'eight_keyword': 'singham'},
#   'Little Singham: Mahabali'),
#  ({'first_keyword': 'traumatic',
#    'second_keyword': 'event,',
#    'third_keyword': 'two',
#    'fourth_keyword': 'indigenous',
#    'fifth_keyword': 'women',
#    'sixth_keyword': 'vancouver',
#    'seventh_keyword': 'brought',
#    'eight_keyword': 'together'},
#   'The Body Remembers When the World Broke Open'),
#  ({'first_keyword': 'hit',
#    'second_keyword': 'man',
#    'third_keyword': 'frank',
#    'fourth_keyword': 'sheeran',
#    'fifth_keyword': 'looks',
#    'sixth_keyword': 'back',
#    'seventh_keyword': 'secrets',
#    'eight_keyword': 'kept'},
#   'The Irishman'),
#  ({'first_keyword': 'comedian',
#    'second_keyword': 'mike',
#    'third_keyword': 'birbiglia',
#    'fourth_keyword': 'hits',
#    'fifth_keyword': 'broadway',
#    'sixth_keyword': 'hilarious',
#    'seventh_keyword': 'yet',
#    'eight_keyword': 'profound'},
#   'Mike Birbiglia: The New One'),
#  ({'first_keyword': 'christmas',
#    'second_keyword': 'eve',
#    'third_keyword': 'pitchfork',
#    'fourth_keyword': 'pines,',
#    'fifth_keyword': 'super',
#    'sixth_keyword': 'monsters',
#    'seventh_keyword': 'joining',
#    'eight_keyword': 'forces'},
#   'Super Monsters Save Christmas'),
#  ({'first_keyword': 'peaceful',
#    'second_keyword': 'lives',
#    'third_keyword': 'residents',
#    'fourth_keyword': 'inhabiting',
#    'fifth_keyword': 'breathtaking',
#    'sixth_keyword': 'seaside',
#    'seventh_keyword': 'town',
#    'eight_keyword': 'shaken'},
#   'The Crime'),
#  ({'first_keyword': 'ice',
#    'second_keyword': 'crystal',
#    'third_keyword': 'frosty',
#    'fourth_keyword': 'realm',
#    'fifth_keyword': 'freezing',
#    'sixth_keyword': 'everything',
#    'seventh_keyword': 'rainbow',
#    'eight_keyword': 'kingdom,'},
#   'True: Winter Wishes'),
#  ({'first_keyword': 'assortment',
#    'second_keyword': 'talent',
#    'third_keyword': 'takes',
#    'fourth_keyword': 'stage',
#    'fifth_keyword': 'night',
#    'sixth_keyword': 'honest',
#    'seventh_keyword': 'stand-up',
#    'eight_keyword': 'featuring'},
#   'Zona Rosa'),
#  ({'first_keyword': 'businesswoman',
#    'second_keyword': 'debra',
#    'third_keyword': "newell's",
#    'fourth_keyword': 'life',
#    'fifth_keyword': 'unravels',
#    'sixth_keyword': 'falls',
#    'seventh_keyword': 'lies',
#    'eight_keyword': 'manipulation'},
#   'Dirty John'),
#  ({'first_keyword': 'aspiring',
#    'second_keyword': 'fulfill',
#    'third_keyword': 'father’s',
#    'fourth_keyword': 'dream',
#    'fifth_keyword': 'become',
#    'sixth_keyword': 'civil',
#    'seventh_keyword': 'services',
#    'eight_keyword': 'officer,'},
#   'Pranaam'),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'extensive',
#    'third_keyword': 'interviews,',
#    'fourth_keyword': 'documentary',
#    'fifth_keyword': 'takes',
#    'sixth_keyword': 'critical',
#    'seventh_keyword': 'look',
#    'eight_keyword': 'gender'},
#   'What the F* Is Going On?'),
#  ({'first_keyword': 'accident',
#    'second_keyword': 'leaves',
#    'third_keyword': 'recollection',
#    'fourth_keyword': 'is,',
#    'fifth_keyword': 'man',
#    'sixth_keyword': 'becomes',
#    'seventh_keyword': 'prime',
#    'eight_keyword': 'suspect'},
#   'Awake'),
#  ({'first_keyword': 'storm',
#    'second_keyword': 'wrecks',
#    'third_keyword': 'ship,',
#    'fourth_keyword': 'super-strong',
#    'fifth_keyword': 'sailor',
#    'sixth_keyword': 'popeye',
#    'seventh_keyword': 'washes',
#    'eight_keyword': 'ashore'},
#   'Popeye'),
#  ({'first_keyword': 'trying',
#    'second_keyword': 'go',
#    'third_keyword': 'straight,',
#    'fourth_keyword': 'once-successful',
#    'fifth_keyword': 'businessman',
#    'sixth_keyword': 'fresh',
#    'seventh_keyword': 'prison',
#    'eight_keyword': 'forced'},
#   'Shot Caller'),
#  ({'first_keyword': 'born',
#    'second_keyword': 'supernatural',
#    'third_keyword': 'strength,',
#    'fourth_keyword': 'bong-soon',
#    'fifth_keyword': 'fights',
#    'sixth_keyword': 'evil',
#    'seventh_keyword': 'procures',
#    'eight_keyword': 'justice'},
#   'Strong Girl Bong-soon'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'adventures',
#    'third_keyword': 'wilbur',
#    'fourth_keyword': 'pig,',
#    'fifth_keyword': 'templeton',
#    'sixth_keyword': 'rat',
#    'seventh_keyword': 'charlotte',
#    'eight_keyword': 'spider'},
#   "Charlotte's Web"),
#  ({'first_keyword': 'officers',
#    'second_keyword': 'taylor',
#    'third_keyword': 'zavala',
#    'fourth_keyword': 'patrol',
#    'fifth_keyword': 'streets',
#    'sixth_keyword': 'south',
#    'seventh_keyword': 'central',
#    'eight_keyword': 'los'},
#   'End of Watch'),
#  ({'first_keyword': 'vietnam',
#    'second_keyword': "war's",
#    'third_keyword': 'horrors',
#    'fourth_keyword': 'come',
#    'fifth_keyword': 'brutally',
#    'sixth_keyword': 'life',
#    'seventh_keyword': 'eyes',
#    'eight_keyword': 'american'},
#   'Hamburger Hill'),
#  ({'first_keyword': 'nine',
#    'second_keyword': 'continents',
#    'third_keyword': 'face',
#    'fourth_keyword': 'crisis,',
#    'fifth_keyword': 'young',
#    'sixth_keyword': 'disciple',
#    'seventh_keyword': 'joins',
#    'eight_keyword': 'spirit'},
#   'Once Upon A Time In Lingjian Mountain'),
#  ({'first_keyword': 'based',
#    'second_keyword': 'h.g.',
#    'third_keyword': 'wells',
#    'fourth_keyword': 'classic,',
#    'fifth_keyword': 'adventure',
#    'sixth_keyword': 'follows',
#    'seventh_keyword': 'scientist',
#    'eight_keyword': 'inventor'},
#   'The Time Machine'),
#  ({'first_keyword': 'thrust',
#    'second_keyword': 'violent',
#    'third_keyword': 'home',
#    'fourth_keyword': 'brutal',
#    'fifth_keyword': 'custody',
#    'sixth_keyword': 'center,',
#    'seventh_keyword': 'teenager',
#    'eight_keyword': 'learns'},
#   'Brother'),
#  ({'first_keyword': 'gets',
#    'second_keyword': 'angry,',
#    'third_keyword': 'middle',
#    'fourth_keyword': 'schooler',
#    'fifth_keyword': 'naoko',
#    'sixth_keyword': 'turns',
#    'seventh_keyword': 'fierce',
#    'eight_keyword': 'dinosaur'},
#   'Dino Girl Gauko'),
#  ({'first_keyword': 'eight',
#    'second_keyword': 'stories',
#    'third_keyword': 'celebrating',
#    'fourth_keyword': 'family,',
#    'fifth_keyword': 'faith,',
#    'sixth_keyword': 'love',
#    'seventh_keyword': 'forgiveness',
#    'eight_keyword': 'come'},
#   "Dolly Parton's Heartstrings"),
#  ({'first_keyword': 'girls',
#    'second_keyword': 'ōarai',
#    'third_keyword': 'high',
#    'fourth_keyword': 'must',
#    'fifth_keyword': 'face',
#    'sixth_keyword': 'formidable',
#    'seventh_keyword': 'university',
#    'eight_keyword': 'team'},
#   'Girls und Panzer der Film'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'sisters',
#    'third_keyword': 'discover',
#    'fourth_keyword': 'disturbing',
#    'fifth_keyword': 'family',
#    'sixth_keyword': 'secrets',
#    'seventh_keyword': 'string',
#    'eight_keyword': 'mysterious'},
#   'High Seas'),
#  ({'first_keyword': 'mike',
#    'second_keyword': 'birbiglia',
#    'third_keyword': 'performs',
#    'fourth_keyword': 'live',
#    'fifth_keyword': 'concert',
#    'sixth_keyword': 'special',
#    'seventh_keyword': 'features',
#    'eight_keyword': 'riotous'},
#   'Mike Birbiglia: What I Should Have Said Was Nothing: Tales from My Secret Public Journal'),
#  ({'first_keyword': '"nailed',
#    'second_keyword': 'it!"',
#    'third_keyword': 'holiday',
#    'fourth_keyword': 'special',
#    'fifth_keyword': 'waiting',
#    'sixth_keyword': 'for,',
#    'seventh_keyword': 'missing',
#    'eight_keyword': 'ingredients,'},
#   'Nailed It! Holiday!'),
#  ({'first_keyword': 'ride',
#    'second_keyword': 'along',
#    'third_keyword': 'police',
#    'fourth_keyword': 'officers',
#    'fifth_keyword': 'drug',
#    'sixth_keyword': 'smugglers',
#    'seventh_keyword': 'go',
#    'eight_keyword': 'toe-to-toe,'},
#   'Narcoworld: Dope Stories'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'guardian',
#    'third_keyword': '"angelus"',
#    'fourth_keyword': 'uncovers',
#    'fifth_keyword': 'secret',
#    'sixth_keyword': 'behind',
#    'seventh_keyword': 'angelus',
#    'eight_keyword': "system's"},
#   "Nobody's Looking"),
#  ({'first_keyword': 'featuring',
#    'second_keyword': 'interviews',
#    'third_keyword': 'vintage',
#    'fourth_keyword': 'footage,',
#    'fifth_keyword': 'documentary',
#    'sixth_keyword': 'traces',
#    'seventh_keyword': 'american',
#    'eight_keyword': 'icon'},
#   'Shelby American'),
#  ({'first_keyword': 'peer',
#    'second_keyword': 'lives',
#    'third_keyword': 'young',
#    'fourth_keyword': 'singaporeans',
#    'fifth_keyword': 'defy',
#    'sixth_keyword': 'expectations',
#    'seventh_keyword': 'traverse',
#    'eight_keyword': 'tricky'},
#   'Singapore Social'),
#  ({'first_keyword': 'extraordinary',
#    'second_keyword': 'discovery',
#    'third_keyword': 'inspires',
#    'fourth_keyword': 'two',
#    'fifth_keyword': 'human',
#    'sixth_keyword': 'princes',
#    'seventh_keyword': 'elven',
#    'eight_keyword': 'assassin'},
#   'The Dragon Prince'),
#  ({'first_keyword': 'queen',
#    'second_keyword': 'poppy',
#    'third_keyword': 'welcomes',
#    'fourth_keyword': 'new',
#    'fifth_keyword': 'time',
#    'sixth_keyword': 'peace',
#    'seventh_keyword': 'troll',
#    'eight_keyword': 'village'},
#   'Trolls: The Beat Goes On!'),
#  ({'first_keyword': 'board',
#    'second_keyword': "russia's",
#    'third_keyword': 'first',
#    'fourth_keyword': 'nuclear',
#    'fifth_keyword': 'ballistic',
#    'sixth_keyword': 'submarine,',
#    'seventh_keyword': 'capt.',
#    'eight_keyword': 'vostrikov'},
#   'K-19: The Widowmaker'),
#  ({'first_keyword': 'making',
#    'second_keyword': 'deal',
#    'third_keyword': 'supernatural',
#    'fourth_keyword': 'figure,',
#    'fifth_keyword': 'two',
#    'sixth_keyword': 'high',
#    'seventh_keyword': 'schoolers',
#    'eight_keyword': 'emerge'},
#   'Mortel'),
#  ({'first_keyword': 'medieval',
#    'second_keyword': 'magic',
#    'third_keyword': 'sends',
#    'fourth_keyword': '14th-century',
#    'fifth_keyword': 'knight',
#    'sixth_keyword': 'modern-day',
#    'seventh_keyword': 'ohio,',
#    'eight_keyword': 'falls'},
#   'The Knight Before Christmas'),
#  ({'first_keyword': 'lifelong',
#    'second_keyword': 'friends',
#    'third_keyword': 'roz',
#    'fourth_keyword': 'lil',
#    'fifth_keyword': 'fall',
#    'sixth_keyword': 'love',
#    'seventh_keyword': "other's",
#    'eight_keyword': 'teenage'},
#   'Adore'),
#  ({'first_keyword': 'living',
#    'second_keyword': 'roof,',
#    'third_keyword': 'group',
#    'fourth_keyword': 'unabashed',
#    'fifth_keyword': 'friends',
#    'sixth_keyword': 'wrestle',
#    'seventh_keyword': 'everyday',
#    'eight_keyword': 'issues'},
#   'Bangkok Buddies'),
#  ({'first_keyword': 'escape',
#    'second_keyword': 'stress',
#    'third_keyword': 'fame,',
#    'fourth_keyword': 'teen',
#    'fifth_keyword': 'pop',
#    'sixth_keyword': 'star',
#    'seventh_keyword': 'jordan',
#    'eight_keyword': 'goes'},
#   'Be Somebody'),
#  ({'first_keyword': 'realizing',
#    'second_keyword': 'boob',
#    'third_keyword': 'tube',
#    'fourth_keyword': 'gone,',
#    'fifth_keyword': 'beavis',
#    'sixth_keyword': 'butt-head',
#    'seventh_keyword': 'set',
#    'eight_keyword': 'expedition'},
#   'Beavis and Butt-head Do America'),
#  ({'first_keyword': "ladies'",
#    'second_keyword': 'man',
#    'third_keyword': 'robin',
#    'fourth_keyword': 'meets',
#    'fifth_keyword': 'jamika,',
#    'sixth_keyword': 'falls',
#    'seventh_keyword': 'head',
#    'eight_keyword': 'heels,'},
#   "Bebe's Kids"),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'charts',
#    'third_keyword': 'rise',
#    'fourth_keyword': 'fall',
#    'fifth_keyword': 'hot',
#    'sixth_keyword': 'yoga',
#    'seventh_keyword': 'founder',
#    'eight_keyword': 'bikram'},
#   'Bikram: Yogi, Guru, Predator'),
#  ({'first_keyword': 'lazarus',
#    'second_keyword': 'finds',
#    'third_keyword': 'rae',
#    'fourth_keyword': 'beaten',
#    'fifth_keyword': 'near',
#    'sixth_keyword': 'death,',
#    'seventh_keyword': 'acts',
#    'eight_keyword': 'father'},
#   'Black Snake Moan'),
#  ({'first_keyword': 'lethal',
#    'second_keyword': 'virus',
#    'third_keyword': 'spreads',
#    'fourth_keyword': 'globally,',
#    'fifth_keyword': 'four',
#    'sixth_keyword': 'friends',
#    'seventh_keyword': 'seek',
#    'eight_keyword': 'reputed'},
#   'Carriers'),
#  ({'first_keyword': 'village',
#    'second_keyword': "landlord's",
#    'third_keyword': 'daughter',
#    'fourth_keyword': 'educated',
#    'fifth_keyword': 'commoner',
#    'sixth_keyword': 'must',
#    'seventh_keyword': 'decide',
#    'eight_keyword': 'budding'},
#   'Dorasaani'),
#  ({'first_keyword': 'riveting',
#    'second_keyword': 'crime',
#    'third_keyword': 'doc',
#    'fourth_keyword': 'follows',
#    'fifth_keyword': 'bill',
#    'sixth_keyword': 'confronts',
#    'seventh_keyword': "america's",
#    'eight_keyword': 'broken'},
#   'Dream/Killer'),
#  ({'first_keyword': 'two',
#    'second_keyword': 'community',
#    'third_keyword': 'college',
#    'fourth_keyword': 'geology',
#    'fifth_keyword': 'professors',
#    'sixth_keyword': 'discover',
#    'seventh_keyword': 'microscopic',
#    'eight_keyword': 'alien'},
#   'Evolution'),
#  ({'first_keyword': 'grieving',
#    'second_keyword': 'mother',
#    'third_keyword': 'karen',
#    'fourth_keyword': 'mccann',
#    'fifth_keyword': 'takes',
#    'sixth_keyword': 'justice',
#    'seventh_keyword': 'hands',
#    'eight_keyword': 'man'},
#   'Eye for an Eye'),
#  ({'first_keyword': 'christmas',
#    'second_keyword': 'reunion',
#    'third_keyword': 'becomes',
#    'fourth_keyword': 'gateway',
#    'fifth_keyword': 'past',
#    'sixth_keyword': 'three-part',
#    'seventh_keyword': 'series',
#    'eight_keyword': 'explores'},
#   'Holiday Secrets'),
#  ({'first_keyword': 'andy',
#    'second_keyword': 'samberg',
#    'third_keyword': 'stars',
#    'fourth_keyword': 'comedy',
#    'fifth_keyword': 'accident-prone',
#    'sixth_keyword': 'daredevil',
#    'seventh_keyword': "who's",
#    'eight_keyword': 'determined'},
#   'Hot Rod'),
#  ({'first_keyword': 'olsen',
#    'second_keyword': 'twins',
#    'third_keyword': 'put',
#    'fourth_keyword': 'cute',
#    'fifth_keyword': 'new',
#    'sixth_keyword': 'spin',
#    'seventh_keyword': 'mark',
#    'eight_keyword': "twain's"},
#   'It Takes Two'),
#  ({'first_keyword': 'lorena',
#    'second_keyword': 'ramírez',
#    'third_keyword': "mexico's",
#    'fourth_keyword': 'rarámuri',
#    'fifth_keyword': 'community',
#    'sixth_keyword': 'lives',
#    'seventh_keyword': 'pastoral',
#    'eight_keyword': 'life'},
#   'Lorena, Light-Footed Woman'),
#  ({'first_keyword': 'years,',
#    'second_keyword': 'come',
#    'third_keyword': 'go',
#    'fourth_keyword': "other's",
#    'fifth_keyword': 'life,',
#    'sixth_keyword': 'childhood',
#    'seventh_keyword': 'pals',
#    'eight_keyword': 'rosie'},
#   'Love, Rosie'),
#  ({'first_keyword': 'self-trained',
#    'second_keyword': 'engineer',
#    'third_keyword': 'risks',
#    'fourth_keyword': 'debt,',
#    'fifth_keyword': 'love',
#    'sixth_keyword': 'reputation',
#    'seventh_keyword': 'quest',
#    'eight_keyword': 'improve'},
#   'Mallesham'),
#  ({'first_keyword': 'epic',
#    'second_keyword': 'spaghetti',
#    'third_keyword': 'western,',
#    'fourth_keyword': 'flinty',
#    'fifth_keyword': 'gunslinger',
#    'sixth_keyword': 'hired',
#    'seventh_keyword': 'railroad',
#    'eight_keyword': 'tycoon'},
#   'Once Upon a Time in the West'),
#  ({'first_keyword': 'average-guy',
#    'second_keyword': 'kirk',
#    'third_keyword': 'starts',
#    'fourth_keyword': 'dating',
#    'fifth_keyword': 'drop-dead-gorgeous',
#    'sixth_keyword': 'molly,',
#    'seventh_keyword': 'friends',
#    'eight_keyword': 'see'},
#   "She's Out of My League"),
#  ({'first_keyword': 'socially',
#    'second_keyword': 'awkward',
#    'third_keyword': 'catholic',
#    'fourth_keyword': 'schoolgirl',
#    'fifth_keyword': 'vows',
#    'sixth_keyword': 'win',
#    'seventh_keyword': 'dreamy',
#    'eight_keyword': 'classmate’s'},
#   'Superstar'),
#  ({'first_keyword': '3-d',
#    'second_keyword': 'motion',
#    'third_keyword': 'capture',
#    'fourth_keyword': 'adapts',
#    'fifth_keyword': 'georges',
#    'sixth_keyword': "remi's",
#    'seventh_keyword': 'classic',
#    'eight_keyword': 'comic'},
#   'The Adventures of Tintin'),
#  ({'first_keyword': 'spooky',
#    'second_keyword': 'grisly,',
#    'third_keyword': 'thriller',
#    'fourth_keyword': 'follows',
#    'fifth_keyword': "woman's",
#    'sixth_keyword': 'quest',
#    'seventh_keyword': 'find',
#    'eight_keyword': 'truth'},
#   'The Devil Inside'),
#  ({'first_keyword': 'following',
#    'second_keyword': "friend's",
#    'third_keyword': 'suicide',
#    'fourth_keyword': 'husband',
#    'fifth_keyword': 'dumps',
#    'sixth_keyword': 'younger',
#    'seventh_keyword': 'model,',
#    'eight_keyword': 'three'},
#   'The First Wives Club'),
#  ({'first_keyword': 'authorities',
#    'second_keyword': 'find',
#    'third_keyword': 'drowned',
#    'fourth_keyword': "woman's",
#    'fifth_keyword': 'body,',
#    'sixth_keyword': 'small-town',
#    'seventh_keyword': 'psychic',
#    'eight_keyword': 'starts'},
#   'The Gift'),
#  ({'first_keyword': 'hired',
#    'second_keyword': 'rescue',
#    'third_keyword': 'flagging',
#    'fourth_keyword': 'car',
#    'fifth_keyword': 'dealership',
#    'sixth_keyword': 'major',
#    'seventh_keyword': 'sale,',
#    'eight_keyword': 'fast-talking'},
#   'The Goods: Live Hard, Sell Hard'),
#  ({'first_keyword': 'washed-up',
#    'second_keyword': 'professional',
#    'third_keyword': 'quarterback',
#    'fourth_keyword': 'paul',
#    'fifth_keyword': 'crewe',
#    'sixth_keyword': 'sent',
#    'seventh_keyword': 'jail',
#    'eight_keyword': 'forced'},
#   'The Longest Yard'),
#  ({'first_keyword': 'raised',
#    'second_keyword': 'ashram',
#    'third_keyword': 'india,',
#    'fourth_keyword': 'self-styled',
#    'fifth_keyword': 'love',
#    'sixth_keyword': 'guru',
#    'seventh_keyword': 'returns',
#    'eight_keyword': 'native'},
#   'The Love Guru'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'attorney',
#    'third_keyword': 'scrappy',
#    'fourth_keyword': 'paralegal',
#    'fifth_keyword': 'work',
#    'sixth_keyword': 'help',
#    'seventh_keyword': 'parents',
#    'eight_keyword': 'terminally'},
#   'The Rainmaker'),
#  ({'first_keyword': 'backwater',
#    'second_keyword': 'iowa',
#    'third_keyword': 'town,',
#    'fourth_keyword': 'young',
#    'fifth_keyword': 'gilbert',
#    'sixth_keyword': 'torn',
#    'seventh_keyword': 'taking',
#    'eight_keyword': 'care'},
#   "What's Eating Gilbert Grape"),
#  ({'first_keyword': '4-year-old',
#    'second_keyword': 'son',
#    'third_keyword': 'murdered,',
#    'fourth_keyword': 'young',
#    'fifth_keyword': 'couple',
#    'sixth_keyword': 'fights',
#    'seventh_keyword': 'twisting',
#    'eight_keyword': 'arduous'},
#   'Who Killed Little Gregory?'),
#  ({'first_keyword': 'working',
#    'second_keyword': 'treacherous',
#    'third_keyword': 'conditions,',
#    'fourth_keyword': 'army',
#    'fifth_keyword': 'dedicated',
#    'sixth_keyword': 'rescuers',
#    'seventh_keyword': 'struggles',
#    'eight_keyword': 'find'},
#   'World Trade Center'),
#  ({'first_keyword': 'divorced',
#    'second_keyword': 'writer',
#    'third_keyword': 'gets',
#    'fourth_keyword': 'letter',
#    'fifth_keyword': 'old',
#    'sixth_keyword': 'boyfriend',
#    'seventh_keyword': 'announcing',
#    'eight_keyword': "wife's"},
#   'Young Adult'),
#  ({'first_keyword': 'father',
#    'second_keyword': 'eight',
#    'third_keyword': 'mother',
#    'fourth_keyword': 'prepare',
#    'fifth_keyword': 'wed,',
#    'sixth_keyword': "couple's",
#    'seventh_keyword': 'children',
#    'eight_keyword': 'attempt'},
#   'Yours, Mine and Ours'),
#  ({'first_keyword': 'political',
#    'second_keyword': 'cartoonist,',
#    'third_keyword': 'crime',
#    'fourth_keyword': 'reporter',
#    'fifth_keyword': 'pair',
#    'sixth_keyword': 'cops',
#    'seventh_keyword': 'investigate',
#    'eight_keyword': 'san'},
#   'Zodiac'),
#  ({'first_keyword': 'comes',
#    'second_keyword': 'bride,',
#    'third_keyword': 'got',
#    'fourth_keyword': 'plenty',
#    'fifth_keyword': 'say.',
#    'sixth_keyword': 'newlywed',
#    'seventh_keyword': 'iliza',
#    'eight_keyword': 'shlesinger'},
#   'Iliza Shlesinger: Unveiled'),
#  ({'first_keyword': 'ditching',
#    'second_keyword': 'domestic',
#    'third_keyword': 'life',
#    'fourth_keyword': 'become',
#    'fifth_keyword': 'chef,',
#    'sixth_keyword': 'clueless',
#    'seventh_keyword': 'maid',
#    'eight_keyword': 'crosses'},
#   'Miss Culinary'),
#  ({'first_keyword': 'follow',
#    'second_keyword': 'santiago',
#    'third_keyword': 'artemis,',
#    'fourth_keyword': 'buenos',
#    'fifth_keyword': 'aires',
#    'sixth_keyword': 'fashion',
#    'seventh_keyword': 'dynamo,',
#    'eight_keyword': 'makes'},
#   'No Time for Shame'),
#  ({'first_keyword': 'wardrobe',
#    'second_keyword': 'malfunction',
#    'third_keyword': 'goes',
#    'fourth_keyword': 'viral,',
#    'fifth_keyword': 'bubbly',
#    'sixth_keyword': 'live',
#    'seventh_keyword': 'streamer',
#    'eight_keyword': 'struggles'},
#   'Candy Online'),
#  ({'first_keyword': 'drama',
#    'second_keyword': 'follows',
#    'third_keyword': 'political',
#    'fourth_keyword': 'rivalries',
#    'fifth_keyword': 'romance',
#    'sixth_keyword': 'queen',
#    'seventh_keyword': 'elizabeth',
#    'eight_keyword': "ii's"},
#   'The Crown'),
#  ({'first_keyword': 'hollywood',
#    'second_keyword': 'stuntman',
#    'third_keyword': 'getaway',
#    'fourth_keyword': 'driver',
#    'fifth_keyword': 'lured',
#    'sixth_keyword': 'isolated',
#    'seventh_keyword': 'life',
#    'eight_keyword': 'lovely'},
#   'Drive'),
#  ({'first_keyword': 'decades',
#    'second_keyword': 'nuclear',
#    'third_keyword': 'war,',
#    'fourth_keyword': 'survivors',
#    'fifth_keyword': 'moon',
#    'sixth_keyword': 'revisit',
#    'seventh_keyword': 'earth',
#    'eight_keyword': 'locate'},
#   'Iron Sky: The Coming Race'),
#  ({'first_keyword': "america's",
#    'second_keyword': 'beloved',
#    'third_keyword': 'ventriloquist',
#    'fourth_keyword': 'hits',
#    'fifth_keyword': 'road,',
#    'sixth_keyword': 'bringing',
#    'seventh_keyword': 'along',
#    'eight_keyword': 'popular'},
#   'Jeff Dunham: All Over the Map'),
#  ({'first_keyword': 'beginning',
#    'second_keyword': '20th',
#    'third_keyword': 'century,',
#    'fourth_keyword': 'circumstances',
#    'fifth_keyword': 'drive',
#    'sixth_keyword': 'young,',
#    'seventh_keyword': 'idealistic',
#    'eight_keyword': 'suffragette'},
#   'Suffragette'),
#  ({'first_keyword': 'determined',
#    'second_keyword': 'save',
#    'third_keyword': 'amazon',
#    'fourth_keyword': 'tribe',
#    'fifth_keyword': 'squeezed',
#    'sixth_keyword': 'logging,',
#    'seventh_keyword': 'group',
#    'eight_keyword': 'students'},
#   'The Green Inferno'),
#  ({'first_keyword': 'encountering',
#    'second_keyword': 'long',
#    'third_keyword': 'separation,',
#    'fourth_keyword': 'two',
#    'fifth_keyword': 'childhood',
#    'sixth_keyword': 'friends',
#    'seventh_keyword': 'orphanage',
#    'eight_keyword': 'must'},
#   'At the Dolphin Bay'),
#  ({'first_keyword': '1980s',
#    'second_keyword': 'tokyo,',
#    'third_keyword': 'enigmatic',
#    'fourth_keyword': 'expat',
#    'fifth_keyword': 'suspected',
#    'sixth_keyword': 'killing',
#    'seventh_keyword': 'friend,',
#    'eight_keyword': "who's"},
#   'Earthquake Bird'),
#  ({'first_keyword': 'remote',
#    'second_keyword': 'areas',
#    'third_keyword': 'amazon',
#    'fourth_keyword': 'jungle,',
#    'fifth_keyword': 'writer',
#    'sixth_keyword': 'anthropologist',
#    'seventh_keyword': 'friend',
#    'eight_keyword': 'meet'},
#   'El sendero de la anaconda'),
#  ({'first_keyword': "mía's",
#    'second_keyword': 'vacation',
#    'third_keyword': 'dad',
#    'fourth_keyword': 'disrupted',
#    'fifth_keyword': 'surprise',
#    'sixth_keyword': 'arrival',
#    'seventh_keyword': 'lupe,',
#    'eight_keyword': 'mercedes,'},
#   'GO! The Unforgettable Party'),
#  ({'first_keyword': 'pampered',
#    'second_keyword': 'kind-hearted',
#    'third_keyword': 'average',
#    'fourth_keyword': 'joe',
#    'fifth_keyword': 'ditches',
#    'sixth_keyword': 'romancing',
#    'seventh_keyword': 'peacekeeping',
#    'eight_keyword': 'ways'},
#   'Guna 369'),
#  ({'first_keyword': 'world-weary',
#    'second_keyword': 'man’s',
#    'third_keyword': 'self-imposed',
#    'fourth_keyword': 'home',
#    'fifth_keyword': 'confinement',
#    'sixth_keyword': 'becomes',
#    'seventh_keyword': 'comedy',
#    'eight_keyword': 'errors'},
#   'House Arrest'),
#  ({'first_keyword': 'unfiltered,',
#    'second_keyword': 'intimate',
#    'third_keyword': 'docuseries,',
#    'fourth_keyword': 'pop',
#    'fifth_keyword': 'star',
#    'sixth_keyword': 'mentor',
#    'seventh_keyword': 'charli',
#    'eight_keyword': 'xcx'},
#   "I'm with the Band: Nasty Cherry"),
#  ({'first_keyword': 'chance',
#    'second_keyword': 'encounter',
#    'third_keyword': 'la,',
#    'fourth_keyword': 'two',
#    'fifth_keyword': 'teens',
#    'sixth_keyword': 'different',
#    'seventh_keyword': 'social',
#    'eight_keyword': 'backgrounds'},
#   'Inheritors'),
#  ({'first_keyword': "they're",
#    'second_keyword': 'gorging',
#    'third_keyword': 'sugary',
#    'fourth_keyword': 'snacks,',
#    'fifth_keyword': 'four',
#    'sixth_keyword': 'aspiring',
#    'seventh_keyword': 'high',
#    'eight_keyword': 'school'},
#   'K-On!'),
#  ({'first_keyword': 'seniors',
#    'second_keyword': 'sakuragaoka',
#    'third_keyword': 'high',
#    'fourth_keyword': "school's",
#    'fifth_keyword': 'music',
#    'sixth_keyword': 'club',
#    'seventh_keyword': 'live',
#    'eight_keyword': 'graduation'},
#   'K-on! the movie'),
#  ({'first_keyword': 'selfish',
#    'second_keyword': 'postman',
#    'third_keyword': 'reclusive',
#    'fourth_keyword': 'toymaker',
#    'fifth_keyword': 'form',
#    'sixth_keyword': 'unlikely',
#    'seventh_keyword': 'friendship,',
#    'eight_keyword': 'delivering'},
#   'Klaus'),
#  ({'first_keyword': 'chance',
#    'second_keyword': 'encounter',
#    'third_keyword': 'ends',
#    'fourth_keyword': 'bad',
#    'fifth_keyword': 'terms,',
#    'sixth_keyword': 'two',
#    'seventh_keyword': 'clashing',
#    'eight_keyword': 'strangers'},
#   'La Robe De Mariee Des Cieux'),
#  ({'first_keyword': 'anna',
#    'second_keyword': 'chooses',
#    'third_keyword': 'february',
#    'fourth_keyword': 'propose',
#    'fifth_keyword': 'marriage',
#    'sixth_keyword': 'boyfriend,',
#    'seventh_keyword': 'meeting',
#    'eight_keyword': 'charming'},
#   'Leap Year'),
#  ({'first_keyword': 'beloved',
#    'second_keyword': "children's",
#    'third_keyword': 'book',
#    'fourth_keyword': 'character',
#    'fifth_keyword': 'llama',
#    'sixth_keyword': 'llama',
#    'seventh_keyword': 'springs',
#    'eight_keyword': 'life'},
#   'Llama Llama'),
#  ({'first_keyword': 'unfortunate',
#    'second_keyword': 'accident',
#    'third_keyword': 'alters',
#    'fourth_keyword': 'life',
#    'fifth_keyword': 'high',
#    'sixth_keyword': 'school',
#    'seventh_keyword': 'basketball',
#    'eight_keyword': 'prodigy,'},
#   'My MVP Valentine'),
#  ({'first_keyword': 'refined',
#    'second_keyword': 'young',
#    'third_keyword': 'joseon',
#    'fourth_keyword': "scholar's",
#    'fifth_keyword': 'life',
#    'sixth_keyword': 'turns',
#    'seventh_keyword': 'upside',
#    'eight_keyword': 'rescues'},
#   'My Sassy Girl'),
#  ({'first_keyword': 'trio',
#    'second_keyword': 'filmmakers',
#    'third_keyword': 'treks',
#    'fourth_keyword': 'across',
#    'fifth_keyword': 'india',
#    'sixth_keyword': 'explore',
#    'seventh_keyword': 'correlation',
#    'eight_keyword': 'vanishing'},
#   'SunGanges'),
#  ({'first_keyword': 'intense',
#    'second_keyword': 'rivalry',
#    'third_keyword': 'henry',
#    'fourth_keyword': 'ford',
#    'fifth_keyword': 'ii',
#    'sixth_keyword': 'ford',
#    'seventh_keyword': 'motor',
#    'eight_keyword': 'company'},
#   'The 24 Hour War'),
#  ({'first_keyword': 'band',
#    'second_keyword': 'misfit',
#    'third_keyword': 'rich',
#    'fourth_keyword': 'kids',
#    'fifth_keyword': 'mexico',
#    'sixth_keyword': 'strike',
#    'seventh_keyword': 'selling',
#    'eight_keyword': 'mdma'},
#   'The Club'),
#  ({'first_keyword': 'lonely',
#    'second_keyword': 'teenager',
#    'third_keyword': 'skips',
#    'fourth_keyword': 'morning',
#    'fifth_keyword': 'classes',
#    'sixth_keyword': 'sit',
#    'seventh_keyword': 'lovely',
#    'eight_keyword': 'garden,'},
#   'The Garden of Words'),
#  ({'first_keyword': 'trapped',
#    'second_keyword': 'island',
#    'third_keyword': 'destroyed',
#    'fourth_keyword': 'tsunami,',
#    'fifth_keyword': 'students',
#    'sixth_keyword': 'elite',
#    'seventh_keyword': 'school',
#    'eight_keyword': 'try'},
#   'The Stranded'),
#  ({'first_keyword': 'minds',
#    'second_keyword': 'behind',
#    'third_keyword': "history's",
#    'fourth_keyword': 'iconic',
#    'fifth_keyword': 'toy',
#    'sixth_keyword': 'franchises',
#    'seventh_keyword': 'discuss',
#    'eight_keyword': 'rise'},
#   'The Toys That Made Us'),
#  ({'first_keyword': 'fateful',
#    'second_keyword': 'domestic',
#    'third_keyword': 'clash,',
#    'fourth_keyword': 'devoted',
#    'fifth_keyword': 'mother',
#    'sixth_keyword': 'finds',
#    'seventh_keyword': 'prison',
#    'eight_keyword': 'fighting'},
#   'The Yard'),
#  ({'first_keyword': 'spirited',
#    'second_keyword': 'high',
#    'third_keyword': 'school',
#    'fourth_keyword': 'misfits',
#    'fifth_keyword': 'hearts',
#    'sixth_keyword': 'gold',
#    'seventh_keyword': 'begin',
#    'eight_keyword': 'journeys'},
#   'Westside Story'),
#  ({'first_keyword': 'intimate',
#    'second_keyword': 'documentary',
#    'third_keyword': 'follows',
#    'fourth_keyword': 'life',
#    'fifth_keyword': 'legendary',
#    'sixth_keyword': 'saxophonist',
#    'seventh_keyword': 'clarence',
#    'eight_keyword': 'clemons'},
#   'Clarence Clemons: Who Do I Think I Am?'),
#  ({'first_keyword': 'irrepressible',
#    'second_keyword': 'french',
#    'third_keyword': 'comedian',
#    'fourth_keyword': 'fadily',
#    'fifth_keyword': 'camara',
#    'sixth_keyword': 'weaves',
#    'seventh_keyword': 'jokes,',
#    'eight_keyword': 'vivid'},
#   'Fadily Camara : La plus drôle de tes copines'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'leaps',
#    'third_keyword': 'page',
#    'fourth_keyword': 'astronomer',
#    'fifth_keyword': 'magically',
#    'sixth_keyword': 'meets',
#    'seventh_keyword': 'comic',
#    'eight_keyword': 'book'},
#   'My Dear Warrior'),
#  ({'first_keyword': 'docuseries,',
#    'second_keyword': 'soccer',
#    'third_keyword': 'great',
#    'fourth_keyword': 'diego',
#    'fifth_keyword': 'maradona',
#    'sixth_keyword': 'comes',
#    'seventh_keyword': 'culiacán,',
#    'eight_keyword': 'heart'},
#   'Maradona in Mexico'),
#  ({'first_keyword': 'chief',
#    'second_keyword': 'staff',
#    'third_keyword': 'national',
#    'fourth_keyword': 'assembly,',
#    'fifth_keyword': 'jang',
#    'sixth_keyword': 'tae-jun',
#    'seventh_keyword': 'influences',
#    'eight_keyword': 'power'},
#   'Chief of Staff'),
#  ({'first_keyword': 'kids',
#    'second_keyword': 'rule',
#    'third_keyword': 'place',
#    'fourth_keyword': 'called',
#    'fifth_keyword': 'harvey',
#    'sixth_keyword': 'street,',
#    'seventh_keyword': 'trio',
#    'eight_keyword': 'girls'},
#   'Harvey Street Kids'),
#  ({'first_keyword': 'comedian',
#    'second_keyword': 'jeff',
#    'third_keyword': 'garlin',
#    'fourth_keyword': '(unintentionally)',
#    'fifth_keyword': 'celebrates',
#    'sixth_keyword': '37th',
#    'seventh_keyword': 'year',
#    'eight_keyword': 'stand-up'},
#   'Jeff Garlin: Our Man In Chicago'),
#  ({'first_keyword': 'stream-of-consciousness',
#    'second_keyword': 'drama',
#    'third_keyword': 'centers',
#    'fourth_keyword': 'day',
#    'fifth_keyword': 'life',
#    'sixth_keyword': 'gay',
#    'seventh_keyword': 'college',
#    'eight_keyword': 'professor'},
#   'A Single Man'),
#  ({'first_keyword': 'cusp',
#    'second_keyword': 'graduation,',
#    'third_keyword': 'accounting',
#    'fourth_keyword': 'major',
#    'fifth_keyword': 'searching',
#    'sixth_keyword': 'career',
#    'seventh_keyword': 'winds',
#    'eight_keyword': 'living'},
#   'Put Your Head on My Shoulder'),
#  ({'first_keyword': 'near-death',
#    'second_keyword': 'trip',
#    'third_keyword': 'home,',
#    'fourth_keyword': 'marine',
#    'fifth_keyword': 'looking',
#    'sixth_keyword': 'help',
#    'seventh_keyword': 'comrade',
#    'eight_keyword': 'survive'},
#   'Submission'),
#  ({'first_keyword': 'traumatized',
#    'second_keyword': 'combat,',
#    'third_keyword': 'newly',
#    'fourth_keyword': 'returned',
#    'fifth_keyword': 'war',
#    'sixth_keyword': 'veterans',
#    'seventh_keyword': 'find',
#    'eight_keyword': 'solace'},
#   'To Be of Service'),
#  ({'first_keyword': 'every',
#    'second_keyword': 'sunday,',
#    'third_keyword': 'hasan',
#    'fourth_keyword': 'minhaj',
#    'fifth_keyword': 'brings',
#    'sixth_keyword': 'incisive',
#    'seventh_keyword': 'nuanced',
#    'eight_keyword': 'perspective'},
#   'Patriot Act with Hasan Minhaj'),
#  ({'first_keyword': 'cohabiting',
#    'second_keyword': 'couple',
#    'third_keyword': '20s',
#    'fourth_keyword': 'navigate',
#    'fifth_keyword': 'ups',
#    'sixth_keyword': 'downs',
#    'seventh_keyword': 'work,',
#    'eight_keyword': 'modern-day'},
#   'Little Things'),
#  ({'first_keyword': 'tackling',
#    'second_keyword': 'different',
#    'third_keyword': 'mysteries',
#    'fourth_keyword': 'episode',
#    'fifth_keyword': 'game',
#    'sixth_keyword': 'show,',
#    'seventh_keyword': 'seven',
#    'eight_keyword': 'sleuths'},
#   'Busted!'),
#  ({'first_keyword': 'attack',
#    'second_keyword': 'pearl',
#    'third_keyword': 'harbor',
#    'fourth_keyword': 'd-day,',
#    'fifth_keyword': 'pivotal',
#    'sixth_keyword': 'events',
#    'seventh_keyword': 'world',
#    'eight_keyword': 'war'},
#   'Greatest Events of WWII in Colour'),
#  ({'first_keyword': 'road',
#    'second_keyword': 'trip',
#    'third_keyword': 'save',
#    'fourth_keyword': 'endangered',
#    'fifth_keyword': 'animal,',
#    'sixth_keyword': 'polar',
#    'seventh_keyword': 'opposites',
#    'eight_keyword': 'guy'},
#   'Green Eggs and Ham'),
#  ({'first_keyword': 'determined',
#    'second_keyword': 'get',
#    'third_keyword': 'fiancée',
#    'fourth_keyword': 'l.a.',
#    'fifth_keyword': 'take',
#    'sixth_keyword': 'advantage',
#    'seventh_keyword': 'amazing',
#    'eight_keyword': 'opportunity,'},
#   'Hit & Run'),
#  ({'first_keyword': 'snowstorm',
#    'second_keyword': 'hits',
#    'third_keyword': 'small',
#    'fourth_keyword': 'town',
#    'fifth_keyword': 'cold',
#    'sixth_keyword': 'christmas',
#    'seventh_keyword': 'eve,',
#    'eight_keyword': 'affecting'},
#   'Let It Snow'),
#  ({'first_keyword': 'mehdi',
#    'second_keyword': 'gets',
#    'third_keyword': 'prison,',
#    'fourth_keyword': 'planning',
#    'fifth_keyword': 'settle',
#    'sixth_keyword': 'old',
#    'seventh_keyword': 'scores.',
#    'eight_keyword': 'first,'},
#   'Paradise Beach'),
#  ({'first_keyword': 'deck',
#    'second_keyword': 'halls',
#    'third_keyword': 'sugar,',
#    'fourth_keyword': 'butter',
#    'fifth_keyword': 'chocolate',
#    'sixth_keyword': 'competitors',
#    'seventh_keyword': 'past',
#    'eight_keyword': 'seasons'},
#   'The Great British Baking Show: Holidays'),
#  ({'first_keyword': 'surrendering',
#    'second_keyword': 'bogotá',
#    'third_keyword': 'police,',
#    'fourth_keyword': 'ex-guerrilla',
#    'fifth_keyword': 'avoids',
#    'sixth_keyword': 'prison',
#    'seventh_keyword': 'working',
#    'eight_keyword': 'undercover'},
#   'Wild District'),
#  ({'first_keyword': 'reporter',
#    'second_keyword': 'must',
#    'third_keyword': 'hunt',
#    'fourth_keyword': 'truth',
#    'fifth_keyword': 'behind',
#    'sixth_keyword': 'strange',
#    'seventh_keyword': 'murder',
#    'eight_keyword': 'crosses'},
#   'U Turn'),
#  ({'first_keyword': 'small-town',
#    'second_keyword': 'louisiana',
#    'third_keyword': 'minister',
#    'fourth_keyword': 'one',
#    'fifth_keyword': 'parishioners',
#    'sixth_keyword': 'cope',
#    'seventh_keyword': 'grief,',
#    'eight_keyword': 'alcoholism'},
#   'Burning Cane'),
#  ({'first_keyword': 'hit',
#    'second_keyword': 'hard',
#    'third_keyword': 'lehman',
#    'fourth_keyword': 'shock,',
#    'fifth_keyword': 'well-meaning',
#    'sixth_keyword': 'young',
#    'seventh_keyword': 'man',
#    'eight_keyword': 'joins'},
#   'SCAMS'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'kingdoms',
#    'third_keyword': 'struggle',
#    'fourth_keyword': 'control',
#    'fifth_keyword': 'walled',
#    'sixth_keyword': 'city,',
#    'seventh_keyword': 'figure',
#    'eight_keyword': 'rare'},
#   'Shadow'),
#  ({'first_keyword': 'luccas',
#    'second_keyword': 'gi',
#    'third_keyword': 'heading',
#    'fourth_keyword': 'world',
#    'fifth_keyword': 'famous',
#    'sixth_keyword': 'gymkhana',
#    'seventh_keyword': 'camp.',
#    'eight_keyword': 'problem:'},
#   'Luccas Neto in: Summer Camp'),
#  ({'first_keyword': 'group',
#    'second_keyword': 'millennials',
#    'third_keyword': 'copes',
#    'fourth_keyword': 'pressures',
#    'fifth_keyword': 'adulting',
#    'sixth_keyword': 'tackling',
#    'seventh_keyword': 'diverse',
#    'eight_keyword': 'set'},
#   'Millennials'),
#  ({'first_keyword': 'earn',
#    'second_keyword': 'cash,',
#    'third_keyword': 'roommates',
#    'fourth_keyword': 'sam',
#    'fifth_keyword': 'cat',
#    'sixth_keyword': 'start',
#    'seventh_keyword': 'baby-sitting',
#    'eight_keyword': 'service'},
#   'Sam & Cat'),
#  ({'first_keyword': 'snl',
#    'second_keyword': 'alumnus',
#    'third_keyword': 'subversive',
#    'fourth_keyword': 'master',
#    'fifth_keyword': 'late-night',
#    'sixth_keyword': 'tv',
#    'seventh_keyword': 'seth',
#    'eight_keyword': 'meyers'},
#   'Seth Meyers: Lobby Baby'),
#  ({'first_keyword': 'soldier',
#    'second_keyword': 'adora',
#    'third_keyword': 'finds',
#    'fourth_keyword': 'magic',
#    'fifth_keyword': 'sword',
#    'sixth_keyword': '–',
#    'seventh_keyword': 'identity',
#    'eight_keyword': 'legendary'},
#   'She-Ra and the Princesses of Power'),
#  ({'first_keyword': 'budding',
#    'second_keyword': 'teen',
#    'third_keyword': 'psychopath',
#    'fourth_keyword': 'rebel',
#    'fifth_keyword': 'hungry',
#    'sixth_keyword': 'adventure',
#    'seventh_keyword': 'embark',
#    'eight_keyword': 'star-crossed'},
#   'The End of the F***ing World'),
#  ({'first_keyword': 'verge',
#    'second_keyword': 'divorce,',
#    'third_keyword': 'middle-aged',
#    'fourth_keyword': 'couple,',
#    'fifth_keyword': 'involved',
#    'sixth_keyword': 'serious',
#    'seventh_keyword': 'affair,',
#    'eight_keyword': 'rethink'},
#   'The Lovers'),
#  ({'first_keyword': 'student',
#    'second_keyword': 'reticent',
#    'third_keyword': 'teen',
#    'fourth_keyword': 'first',
#    'fifth_keyword': 'meet',
#    'sixth_keyword': 'bakery',
#    'seventh_keyword': '1990s',
#    'eight_keyword': 'try'},
#   'Tune in for Love'),
#  ({'first_keyword': 'beloved',
#    'second_keyword': 'secret',
#    'third_keyword': 'agent',
#    'fourth_keyword': 'falls',
#    'fifth_keyword': 'deep',
#    'sixth_keyword': 'coma,',
#    'seventh_keyword': 'bumbling',
#    'eight_keyword': 'brother'},
#   'Undercover Brother 2'),
#  ({'first_keyword': 'remake',
#    'second_keyword': 'korean',
#    'third_keyword': 'thriller,',
#    'fourth_keyword': 'esteemed',
#    'fifth_keyword': 'detective',
#    'sixth_keyword': 'talented',
#    'seventh_keyword': 'cop',
#    'eight_keyword': 'join'},
#   'Voice'),
#  ({'first_keyword': "hilary's",
#    'second_keyword': 'plan',
#    'third_keyword': 'hire',
#    'fourth_keyword': 'good-looking',
#    'fifth_keyword': 'guy',
#    'sixth_keyword': 'act',
#    'seventh_keyword': 'boyfriend',
#    'eight_keyword': 'backfires'},
#   'A Holiday Engagement'),
#  ({'first_keyword': 'twentysomething',
#    'second_keyword': 'georgia',
#    'third_keyword': 'pines',
#    'fourth_keyword': 'old',
#    'fifth_keyword': 'boyfriend',
#    'sixth_keyword': 'thrilled',
#    'seventh_keyword': 'second',
#    'eight_keyword': 'chance'},
#   'Christmas Crush'),
#  ({'first_keyword': 'finding',
#    'second_keyword': 'letter',
#    'third_keyword': 'mailed',
#    'fourth_keyword': 'santa',
#    'fifth_keyword': 'girl',
#    'sixth_keyword': 'asking',
#    'seventh_keyword': 'new',
#    'eight_keyword': 'wife'},
#   'Dear Santa'),
#  ({'first_keyword': 'years',
#    'second_keyword': 'segregation',
#    'third_keyword': 'forced',
#    'fourth_keyword': 'labor,',
#    'fifth_keyword': 'race',
#    'sixth_keyword': 'stranded',
#    'seventh_keyword': 'aliens',
#    'eight_keyword': 'enlists'},
#   'District 9'),
#  ({'first_keyword': 'graduating,',
#    'second_keyword': 'four',
#    'third_keyword': 'college',
#    'fourth_keyword': 'roomies',
#    'fifth_keyword': '–',
#    'sixth_keyword': 'petrified',
#    'seventh_keyword': 'prospect',
#    'eight_keyword': 'facing'},
#   'Kicking and Screaming'),
#  ({'first_keyword': 'south',
#    'second_keyword': 'london,',
#    'third_keyword': 'tradition',
#    'fourth_keyword': 'clashes',
#    'fifth_keyword': 'culture',
#    'sixth_keyword': 'nigerian',
#    'seventh_keyword': 'father',
#    'eight_keyword': 'tries'},
#   'Meet the Adebanjos'),
#  ({'first_keyword': 'people',
#    'second_keyword': 'dedicated',
#    'third_keyword': 'rejecting',
#    'fourth_keyword': 'american',
#    'fifth_keyword': 'ideal',
#    'sixth_keyword': 'things',
#    'seventh_keyword': 'bring',
#    'eight_keyword': 'happiness'},
#   'Minimalism: A Documentary About the Important Things'),
#  ({'first_keyword': 'taken',
#    'second_keyword': 'custody,',
#    'third_keyword': 'murder',
#    'fourth_keyword': "suspect's",
#    'fifth_keyword': 'theatrical',
#    'sixth_keyword': 'explanations',
#    'seventh_keyword': 'peculiar',
#    'eight_keyword': 'modus'},
#   'Oththa Seruppu Size 7'),
#  ({'first_keyword': 'cleveland',
#    'second_keyword': 'grandfather',
#    'third_keyword': 'brought',
#    'fourth_keyword': 'trial',
#    'fifth_keyword': 'israel,',
#    'sixth_keyword': 'accused',
#    'seventh_keyword': 'infamous',
#    'eight_keyword': 'nazi'},
#   'The Devil Next Door'),
#  ({'first_keyword': 'motley',
#    'second_keyword': 'crew',
#    'third_keyword': 'bank',
#    'fourth_keyword': 'robbers',
#    'fifth_keyword': 'plans',
#    'sixth_keyword': 'next',
#    'seventh_keyword': 'heist',
#    'eight_keyword': 'former'},
#   'Takers'),
#  ({'first_keyword': 'led',
#    'second_keyword': 'seventh-grader',
# ...
#  ({'first_keyword': 'brave,',
#    'second_keyword': 'energetic',
#    'third_keyword': 'little',
#    'fourth_keyword': 'boy',
#    'fifth_keyword': 'superhuman',
#    'sixth_keyword': 'powers',
#    'seventh_keyword': 'leads',
#    'eight_keyword': 'friends'},
#   'Chhota Bheem'),
#  ({'first_keyword': 'mckellan',
#    'second_keyword': 'family',
#    'third_keyword': 'moves',
#    'fourth_keyword': 'seattle',
#    'fifth_keyword': 'small-town',
#    'sixth_keyword': 'georgia,',
#    'seventh_keyword': 'life',
#    'eight_keyword': 'south'},
#   'Family Reunion'),
#  ({'first_keyword': 'little',
#    'second_keyword': "singham's",
#    'third_keyword': 'sidekick',
#    'fourth_keyword': 'monkey,',
#    'fifth_keyword': 'chikki,',
#    'sixth_keyword': 'stuck',
#    'seventh_keyword': 'magical',
#    'eight_keyword': 'land'},
#   'Little Singham Bandarpur Mein Hu Ha Hu'),
#  ({'first_keyword': "spotlight's",
#    'second_keyword': 'parchís,',
#    'third_keyword': 'record',
#    'fourth_keyword': 'company-created',
#    'fifth_keyword': 'spanish',
#    'sixth_keyword': 'boy/girl',
#    'seventh_keyword': 'band',
#    'eight_keyword': 'unprecedented'},
#   'Parchís: the Documentary'),
#  ({'first_keyword': 'comedy',
#    'second_keyword': 'special',
#    'third_keyword': 'directed',
#    'fourth_keyword': 'spike',
#    'fifth_keyword': 'jonze,',
#    'sixth_keyword': 'aziz',
#    'seventh_keyword': 'ansari',
#    'eight_keyword': 'shares'},
#   'Aziz Ansari: RIGHT NOW'),
#  ({'first_keyword': '1930s',
#    'second_keyword': 'london,',
#    'third_keyword': 'michael',
#    'fourth_keyword': 'banks',
#    'fifth_keyword': 'three',
#    'sixth_keyword': 'children',
#    'seventh_keyword': 'get',
#    'eight_keyword': 'help'},
#   'Mary Poppins Returns'),
#  ({'first_keyword': 'playing',
#    'second_keyword': 'pranks',
#    'third_keyword': 'destroying',
#    'fourth_keyword': 'demons,',
#    'fifth_keyword': 'lord',
#    'sixth_keyword': 'krishna',
#    'seventh_keyword': 'brother',
#    'eight_keyword': "balaram's"},
#   'Krishna Balram'),
#  ({'first_keyword': 'margaret',
#    'second_keyword': 'thatcher,',
#    'third_keyword': 'first',
#    'fourth_keyword': 'female',
#    'fifth_keyword': 'prime',
#    'sixth_keyword': 'minister',
#    'seventh_keyword': 'britain,',
#    'eight_keyword': 'navigates'},
#   'The Iron Lady'),
#  ({'first_keyword': '15-year-old',
#    'second_keyword': 'la',
#    'third_keyword': 'spends',
#    'fourth_keyword': 'summer',
#    'fifth_keyword': "mom's",
#    'sixth_keyword': 'childhood',
#    'seventh_keyword': 'home',
#    'eight_keyword': 'island'},
#   'Free Rein'),
#  ({'first_keyword': 'officials',
#    'second_keyword': 'slow',
#    'third_keyword': 'investigate',
#    'fourth_keyword': 'mysterious',
#    'fifth_keyword': 'disappearance,',
#    'sixth_keyword': 'teen',
#    'seventh_keyword': 'girl',
#    'eight_keyword': 'searches'},
#   'Sicilian Ghost Story'),
#  ({'first_keyword': 'blind',
#    'second_keyword': 'woman',
#    'third_keyword': 'vices',
#    'fourth_keyword': 'finds',
#    'fifth_keyword': 'middle',
#    'sixth_keyword': 'murder',
#    'seventh_keyword': 'investigation',
#    'eight_keyword': 'best'},
#   'In The Dark'),
#  ({'first_keyword': 'experience',
#    'second_keyword': 'highlights',
#    'third_keyword': 'argentine',
#    'fourth_keyword': 'soccer',
#    'fifth_keyword': 'team',
#    'sixth_keyword': 'club',
#    'seventh_keyword': 'atlético',
#    'eight_keyword': 'river'},
#   'River, el más grande siempre'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'take',
#    'third_keyword': 'classic',
#    'fourth_keyword': 'tale,',
#    'fifth_keyword': 'ancient',
#    'sixth_keyword': 'snake',
#    'seventh_keyword': 'spirit',
#    'eight_keyword': 'transforms'},
#   'The Legend of White Snake'),
#  ({'first_keyword': 'short',
#    'second_keyword': 'documentary,',
#    'third_keyword': '37-year-old',
#    'fourth_keyword': 'cristina',
#    'fifth_keyword': 'valiantly',
#    'sixth_keyword': 'battles',
#    'seventh_keyword': 'cancer',
#    'eight_keyword': 'encourage'},
#   'Cristina'),
#  ({'first_keyword': 'yumeko',
#    'second_keyword': 'jabami',
#    'third_keyword': 'enrolls',
#    'fourth_keyword': 'hyakkaou',
#    'fifth_keyword': 'private',
#    'sixth_keyword': 'academy,',
#    'seventh_keyword': 'students',
#    'eight_keyword': 'ranked'},
#   'Kakegurui'),
#  ({'first_keyword': 'capture',
#    'second_keyword': 'crime',
#    'third_keyword': 'lord',
#    'fourth_keyword': 'killed',
#    'fifth_keyword': 'partner',
#    'sixth_keyword': 'kidnapped',
#    'seventh_keyword': "partner's",
#    'eight_keyword': 'daughter,'},
#   'Skiptrace'),
#  ({'first_keyword': 'young',
#    'second_keyword': 'boy',
#    'third_keyword': 'vanishes,',
#    'fourth_keyword': 'small',
#    'fifth_keyword': 'town',
#    'sixth_keyword': 'uncovers',
#    'seventh_keyword': 'mystery',
#    'eight_keyword': 'involving'},
#   'Stranger Things'),
#  ({'first_keyword': 'social',
#    'second_keyword': 'upheaval',
#    'third_keyword': 'sweeps',
#    'fourth_keyword': 'russia',
#    'fifth_keyword': 'early',
#    'sixth_keyword': '20th',
#    'seventh_keyword': 'century,',
#    'eight_keyword': 'czar'},
#   'The Last Czars'),
#  ({'first_keyword': 'drama',
#    'second_keyword': 'expectant',
#    'third_keyword': 'mothers',
#    'fourth_keyword': 'model',
#    'fifth_keyword': 'good',
#    'sixth_keyword': 'looks',
#    'seventh_keyword': 'lavish',
#    'eight_keyword': 'lifestyles'},
#   'Yummy Mummies'),
#  ({'first_keyword': 'kind',
#    'second_keyword': 'computer',
#    'third_keyword': 'repairman',
#    'fourth_keyword': 'falls',
#    'fifth_keyword': 'street-smart',
#    'sixth_keyword': 'graffiti',
#    'seventh_keyword': 'artist',
#    'eight_keyword': 'whose'},
#   'Bangkok Love Stories: Objects of Affection'),
#  ({'first_keyword': "bangkok's",
#    'second_keyword': 'chinatown,',
#    'third_keyword': 'spirited',
#    'fourth_keyword': 'digital',
#    'fifth_keyword': 'marketing',
#    'sixth_keyword': 'expert',
#    'seventh_keyword': 'falls',
#    'eight_keyword': 'blind'},
#   'Bangkok Love Stories: Plead'),
#  ({'first_keyword': 'national',
#    'second_keyword': 'assembly',
#    'third_keyword': 'suffers',
#    'fourth_keyword': 'catastrophic',
#    'fifth_keyword': 'attack,',
#    'sixth_keyword': 'minister',
#    'seventh_keyword': 'environment',
#    'eight_keyword': 'park'},
#   'Designated Survivor: 60 Days'),
#  ({'first_keyword': 'raising',
#    'second_keyword': 'daughter',
#    'third_keyword': 'small',
#    'fourth_keyword': 'town,',
#    'fifth_keyword': 'enchanting',
#    'sixth_keyword': 'widow',
#    'seventh_keyword': 'magical',
#    'eight_keyword': 'powers'},
#   'Good Witch'),
#  ({'first_keyword': 'widowed',
#    'second_keyword': 'singer',
#    'third_keyword': 'single',
#    'fourth_keyword': 'mother',
#    'fifth_keyword': 'starts',
#    'sixth_keyword': 'diner',
#    'seventh_keyword': 'waitress',
#    'eight_keyword': 'arizona,'},
#   "Alice Doesn't Live Here Anymore"),
#  ({'first_keyword': 'pair',
#    'second_keyword': 'adventures,',
#    'third_keyword': 'po',
#    'fourth_keyword': 'tells',
#    'fifth_keyword': 'story',
#    'sixth_keyword': 'masters',
#    'seventh_keyword': 'thundering',
#    'eight_keyword': 'rhino,'},
#   'DreamWorks Kung Fu Panda Awesome Secrets'),
#  ({'first_keyword': 'ordinary',
#    'second_keyword': 'student,',
#    'third_keyword': 'forms',
#    'fourth_keyword': 'advice',
#    'fifth_keyword': 'club',
#    'sixth_keyword': 'friends',
#    'seventh_keyword': 'help',
#    'eight_keyword': 'others,'},
#   'Flowering Heart'),
#  ({'first_keyword': 'mohawk',
#    'second_keyword': 'reservation',
#    'third_keyword': 'canadian',
#    'fourth_keyword': 'border,',
#    'fifth_keyword': 'ray',
#    'sixth_keyword': 'eddy',
#    'seventh_keyword': 'teams',
#    'eight_keyword': 'widowed'},
#   'Frozen River'),
#  ({'first_keyword': 'fun-loving',
#    'second_keyword': 'creatures',
#    'third_keyword': 'hatch',
#    'fourth_keyword': 'shells',
#    'fifth_keyword': 'spread',
#    'sixth_keyword': 'friendship,',
#    'seventh_keyword': 'laughter',
#    'eight_keyword': 'life'},
#   'Hatchimals | Adventures in Hatchtopia'),
#  ({'first_keyword': 'unbeknownst',
#    'second_keyword': '12-year-old',
#    'third_keyword': 'daughter,',
#    'fourth_keyword': 'bookbinder',
#    'fifth_keyword': 'secret',
#    'sixth_keyword': 'ability',
#    'seventh_keyword': 'bring',
#    'eight_keyword': 'characters'},
#   'Inkheart'),
#  ({'first_keyword': 'mixing',
#    'second_keyword': 'dramatic',
#    'third_keyword': 're-enactments',
#    'fourth_keyword': 'real-life',
#    'fifth_keyword': 'footage,',
#    'sixth_keyword': 'series',
#    'seventh_keyword': 'delves',
#    'eight_keyword': 'tormented'},
#   'Inside the Mind of a Serial Killer'),
#  ({'first_keyword': 'fresh',
#    'second_keyword': 'tour,',
#    'third_keyword': 'comedian',
#    'fourth_keyword': 'katherine',
#    'fifth_keyword': 'ryan',
#    'sixth_keyword': 'shares',
#    'seventh_keyword': 'shrewd',
#    'eight_keyword': 'observations'},
#   'Katherine Ryan: Glitter Room'),
#  ({'first_keyword': 'true',
#    'second_keyword': 'crime',
#    'third_keyword': 'tale',
#    'fourth_keyword': 'charts',
#    'fifth_keyword': 'rise',
#    'sixth_keyword': 'fall',
#    'seventh_keyword': 'mobster',
#    'eight_keyword': 'danny'},
#   'Kill the Irishman'),
#  ({'first_keyword': 'apartment',
#    'second_keyword': 'building',
#    'third_keyword': 'manager',
#    'fourth_keyword': 'discovers',
#    'fifth_keyword': 'water',
#    'sixth_keyword': 'nymph',
#    'seventh_keyword': "complex's",
#    'eight_keyword': 'swimming'},
#   'Lady in the Water'),
#  ({'first_keyword': 'brian',
#    'second_keyword': 'knows',
#    'third_keyword': 'creatures',
#    'fourth_keyword': 'bed.',
#    'fifth_keyword': 'faces',
#    'sixth_keyword': 'fears',
#    'seventh_keyword': 'confronts',
#    'eight_keyword': 'them,'},
#   'Little Monsters'),
#  ({'first_keyword': 'desperate',
#    'second_keyword': 'start',
#    'third_keyword': 'new',
#    'fourth_keyword': 'life',
#    'fifth_keyword': 'girlfriend,',
#    'sixth_keyword': 'teenage',
#    'seventh_keyword': 'boy',
#    'eight_keyword': 'steals'},
#   'Mean Dreams'),
#  ({'first_keyword': 'new',
#    'second_keyword': "york's",
#    'third_keyword': 'little',
#    'fourth_keyword': 'italy,',
#    'fifth_keyword': 'low-level',
#    'sixth_keyword': 'hoodlum',
#    'seventh_keyword': 'wrestles',
#    'eight_keyword': 'loyalty'},
#   'Mean Streets'),
#  ({'first_keyword': 'imaginative,',
#    'second_keyword': 'big-hearted',
#    'third_keyword': 'bunny',
#    'fourth_keyword': 'friend,',
#    'fifth_keyword': 'shy',
#    'sixth_keyword': 'chick,',
#    'seventh_keyword': 'explore',
#    'eight_keyword': 'everyday'},
#   'Molang'),
#  ({'first_keyword': 'las',
#    'second_keyword': 'vegas',
#    'third_keyword': 'magician',
#    'fourth_keyword': 'cris',
#    'fifth_keyword': 'see',
#    'sixth_keyword': 'minutes',
#    'seventh_keyword': 'future',
#    'eight_keyword': 'fbi'},
#   'Next'),
#  ({'first_keyword': 'hurricane',
#    'second_keyword': 'hits',
#    'third_keyword': 'coastal',
#    'fourth_keyword': 'north',
#    'fifth_keyword': 'carolina',
#    'sixth_keyword': 'inn',
#    'seventh_keyword': 'strands',
#    'eight_keyword': 'guest,'},
#   'Nights in Rodanthe'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'test',
#    'third_keyword': 'avian',
#    'fourth_keyword': 'aptitude',
#    'fifth_keyword': 'challenge',
#    'sixth_keyword': 'concepts',
#    'seventh_keyword': 'intelligence',
#    'eight_keyword': 'examples'},
#   'NOVA: Bird Brain'),
#  ({'first_keyword': 'astrophysicists',
#    'second_keyword': 'show',
#    'third_keyword': 'black',
#    'fourth_keyword': 'holes',
#    'fifth_keyword': 'might',
#    'sixth_keyword': 'hold',
#    'seventh_keyword': 'answers',
#    'eight_keyword': 'universe'},
#   'NOVA: Black Hole Apocalypse'),
#  ({'first_keyword': 'thirty',
#    'second_keyword': 'years',
#    'third_keyword': 'chernobyl’s',
#    'fourth_keyword': 'nuclear',
#    'fifth_keyword': 'disaster,',
#    'sixth_keyword': 'engineers',
#    'seventh_keyword': 'race',
#    'eight_keyword': 'time'},
#   "NOVA: Building Chernobyl's MegaTomb"),
#  ({'first_keyword': 'chariot',
#    'second_keyword': 'dominated',
#    'third_keyword': 'chinese',
#    'fourth_keyword': 'warfare',
#    'fifth_keyword': 'millennia.',
#    'sixth_keyword': 'now,',
#    'seventh_keyword': 'team',
#    'eight_keyword': 'experts'},
#   'NOVA: Chinese Chariot Revealed'),
#  ({'first_keyword': 'drilling',
#    'second_keyword': 'impact',
#    'third_keyword': 'crater',
#    'fourth_keyword': 'asteroid',
#    'fifth_keyword': 'wiped',
#    'sixth_keyword': 'dinosaurs,',
#    'seventh_keyword': 'group',
#    'eight_keyword': 'scientists'},
#   'NOVA: Day the Dinosaurs Died'),
#  ({'first_keyword': 'decades',
#    'second_keyword': 'amazing',
#    'third_keyword': 'discoveries,',
#    'fourth_keyword': 'spacecraft',
#    'fifth_keyword': 'cassini',
#    'sixth_keyword': 'embarks',
#    'seventh_keyword': 'final',
#    'eight_keyword': '–'},
#   'NOVA: Death Dive to Saturn'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'investigate',
#    'third_keyword': 'earth’s',
#    'fourth_keyword': 'climate',
#    'fifth_keyword': 'machine,',
#    'sixth_keyword': 'looking',
#    'seventh_keyword': 'clues',
#    'eight_keyword': 'across'},
#   'NOVA: Decoding the Weather Machine'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'reveal',
#    'third_keyword': 'solar',
#    'fourth_keyword': 'eclipse',
#    'fifth_keyword': 'provided',
#    'sixth_keyword': 'new',
#    'seventh_keyword': 'clues',
#    'eight_keyword': 'sun'},
#   'NOVA: Eclipse Over America'),
#  ({'first_keyword': 'huge',
#    'second_keyword': 'tusks',
#    'third_keyword': 'giant',
#    'fourth_keyword': 'horns,',
#    'fifth_keyword': 'animals',
#    'sixth_keyword': 'sport',
#    'seventh_keyword': 'weaponry',
#    'eight_keyword': 'that’s'},
#   'NOVA: Extreme Animal Weapons'),
#  ({'first_keyword': 'risky',
#    'second_keyword': 'expeditions',
#    'third_keyword': 'underwater',
#    'fourth_keyword': 'cave,',
#    'fifth_keyword': 'scientists',
#    'sixth_keyword': 'unearth',
#    'seventh_keyword': '13,000-year-old',
#    'eight_keyword': 'skeleton'},
#   'NOVA: First Face of America'),
#  ({'first_keyword': 'former',
#    'second_keyword': 'nazi',
#    'third_keyword': 'execution',
#    'fourth_keyword': 'site',
#    'fifth_keyword': 'lithuania,',
#    'sixth_keyword': 'international',
#    'seventh_keyword': 'team',
#    'eight_keyword': 'archaeologists'},
#   'NOVA: Holocaust Escape Tunnel'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'search',
#    'third_keyword': 'evidence',
#    'fourth_keyword': 'left',
#    'fifth_keyword': 'behind',
#    'sixth_keyword': 'world’s',
#    'seventh_keyword': 'greatest',
#    'eight_keyword': 'floods'},
#   'NOVA: Killer Floods'),
#  ({'first_keyword': 'scientists',
#    'second_keyword': 'research',
#    'third_keyword': 'world’s',
#    'fourth_keyword': 'deadliest',
#    'fifth_keyword': 'hurricane,',
#    'sixth_keyword': 'trying',
#    'seventh_keyword': 'understand',
#    'eight_keyword': '18th-century'},
#   'NOVA: Killer Hurricanes'),
#  ({'first_keyword': 'evidence',
#    'second_keyword': 'mysterious',
#    'third_keyword': 'medieval',
#    'fourth_keyword': 'famine',
#    'fifth_keyword': 'leads',
#    'sixth_keyword': 'researchers',
#    'seventh_keyword': 'quest',
#    'eight_keyword': 'one'},
#   'NOVA: Killer Volcanoes'),
#  ({'first_keyword': 'documentary',
#    'second_keyword': 'details',
#    'third_keyword': 'water',
#    'fourth_keyword': 'disaster',
#    'fifth_keyword': 'flint,',
#    'sixth_keyword': 'michigan',
#    'seventh_keyword': 'happened,',
#    'eight_keyword': 'lasting'},
#   'NOVA: Poisoned Water'),
#  ({'first_keyword': 'science',
#    'second_keyword': 'forecasting',
#    'third_keyword': 'flourishing,',
#    'fourth_keyword': 'documentary',
#    'fifth_keyword': 'explores',
#    'sixth_keyword': 'predictions',
#    'seventh_keyword': 'inform',
#    'eight_keyword': 'lives'},
#   'NOVA: Prediction by the Numbers'),
#  ({'first_keyword': 'master',
#    'second_keyword': 'armorer',
#    'third_keyword': 'team',
#    'fourth_keyword': 'recreate',
#    'fifth_keyword': 'parts',
#    'sixth_keyword': "knight's",
#    'seventh_keyword': 'medieval',
#    'eight_keyword': 'armor'},
#   'NOVA: Secrets of the Shining Knight'),
#  ({'first_keyword': 'international',
#    'second_keyword': 'team',
#    'third_keyword': 'rescue',
#    'fourth_keyword': 'workers',
#    'fifth_keyword': 'race',
#    'sixth_keyword': 'save',
#    'seventh_keyword': 'young',
#    'eight_keyword': 'soccer'},
#   'NOVA: Thai Cave Rescue'),
#  ...]

# %%
random.shuffle(featuresets2)

# %%
split_num2 = math.floor(len(featuresets2)*.8)
print(split_num2)

# split feature sets into training and test sets (here we'll try 80% train, 20% test)
train_set2, test_set2 = featuresets2[:split_num2], featuresets2[split_num2+1:]

print('improved train set: ' + str(len(train_set2)) + ' & improved test set: ' + str(len(test_set2)))
# Out:
# 4669
# improved train set: 4669 & improved test set: 1167

# %%
classifier2 = nltk.NaiveBayesClassifier.train(train_set2)

# %%
classifier2.classify(movies_features2("a movie about caste differences thro wrench blossoming relationship couple"))
# Out:
# 'Evvarikee Cheppoddu'

# %%
print(nltk.classify.accuracy(classifier2, test_set2))
# Out:
# 0.0

# %%
classifier2.show_most_informative_features(30)
# Out:
# Most Informative Features
#           fourth_keyword = 'expose'       Sarkar : The Re =      1.7 : 1.0
#            third_keyword = 'mission'      Sarkar : Valor  =      1.7 : 1.0
#            sixth_keyword = 'fraud'        Sarkar : The Ad =      1.7 : 1.0
#          seventh_keyword = 'brings'       Sarkar : Bob Ro =      1.7 : 1.0
#            first_keyword = 'documentary'  100 Ye : Limitl =      1.0 : 1.0
#            first_keyword = 'encountering' At the : The Si =      1.0 : 1.0
#            first_keyword = 'failed'       Outlaw : Limitl =      1.0 : 1.0
#            first_keyword = 'man'          100 Me : Love   =      1.0 : 1.0
#            first_keyword = 'rebellious'   Crazy  : Love   =      1.0 : 1.0
#            first_keyword = 'world'        Angel  : The Si =      1.0 : 1.0
#           second_keyword = 'attack'       Kuromu : The Si =      1.0 : 1.0
#           second_keyword = 'career'       Hostil : Limitl =      1.0 : 1.0
#           second_keyword = 'five'         Chupan : Love   =      1.0 : 1.0
#           second_keyword = 'follows'        Bolt : Limitl =      1.0 : 1.0
#           second_keyword = 'musician'     Expedi : Limitl =      1.0 : 1.0
#          seventh_keyword = 'attack'       Design : The Si =      1.0 : 1.0
#          seventh_keyword = 'life'         An Int : Limitl =      1.0 : 1.0
#          seventh_keyword = 'new'          Aggret : Limitl =      1.0 : 1.0
#          seventh_keyword = 'past'         Rebel  : Love   =      1.0 : 1.0
#          seventh_keyword = 'teen'         Barely : The Si =      1.0 : 1.0
#            eight_keyword = 'different'    Dhobi  : Love   =      1.0 : 1.0
#            eight_keyword = 'drug'         The La : Limitl =      1.0 : 1.0
#            eight_keyword = 'family'       Bad Bl : The Si =      1.0 : 1.0
#            eight_keyword = 'modern'         Easy : Love   =      1.0 : 1.0
#            eight_keyword = 'relationship' Club F : Love   =      1.0 : 1.0
#            eight_keyword = 'turning'      Band A : Limitl =      1.0 : 1.0
#            sixth_keyword = 'finds'        14 Cam : Limitl =      1.0 : 1.0
#            sixth_keyword = 'forced'       2307:  : The Si =      1.0 : 1.0
#            sixth_keyword = 'powers'       Chhota : Limitl =      1.0 : 1.0
#            sixth_keyword = 'struggle'     A Hous : Limitl =      1.0 : 1.0
